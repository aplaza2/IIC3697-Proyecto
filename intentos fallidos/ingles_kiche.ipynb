# %% [markdown]
# <a href="https://colab.research.google.com/github/aplaza2/IIC3697-Proyecto/blob/main/ingles_kiche.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Traducción Inglés -> Kiche

# %%
import nbformat
import os
from google.colab import drive


notebook_path = "/content/drive/MyDrive/Colab Notebooks/ingles_kiche.ipynb"


try:
    # Read the notebook
    nb = nbformat.read(notebook_path, as_version=4)

    # Check if 'widgets' metadata exists and delete it
    if "widgets" in nb["metadata"]:
        del nb["metadata"]["widgets"]
        print("✅ Se eliminó la sección 'widgets' de los metadatos.")
    else:
        print("ℹ️ La sección 'widgets' no se encontró en los metadatos. No se requiere limpieza.")

    # Write the modified notebook back to the same path
    nbformat.write(nb, notebook_path)
    print(f"✅ Limpieza completada para: {notebook_path}")

except FileNotFoundError:
    print(f"❌ Error: No se encontró el archivo en la ruta especificada: {notebook_path}")
    print("Asegúrate de que la ruta del cuaderno sea correcta y que esté montado tu Google Drive si es necesario.")
except Exception as e:
    print(f"❌ Ocurrió un error: {e}")
# Out:
# ℹ️ La sección 'widgets' no se encontró en los metadatos. No se requiere limpieza.
# ✅ Limpieza completada para: /content/drive/MyDrive/Colab Notebooks/ingles_kiche.ipynb

# %% [markdown]
# ## Configuración inicial

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ===================================================================
# CELDA DE CONFIGURACIÓN CENTRAL DEL PROYECTO
# ===================================================================
# Para cambiar de experimento, solo necesitan modificar esta celda.

import os

# --- 1. Definición de la Tarea de Traducción ---
# Idioma de origen (el que no es español)
SOURCE_LANG_NAME = "Inglés"
SOURCE_LANG_CODE = "eng_Latn"

# Idioma de destino (la lengua maya que están estudiando)
TARGET_LANG_NAME = "K'iche'"
TARGET_LANG_CODE = "quc_Latn" # Código correcto para K'iche'
TARGET_LANG_SHORT_CODE = "quc" # Código del dataset MayanV

# Idioma pivote (el que se usa como puente)
PIVOT_LANG_NAME = "Español"
PIVOT_LANG_CODE = "spa_Latn"
PIVOT_LANG_SHORT_CODE = "es" # Código del dataset MayanV

# --- 2. Parámetros del Modelo y Entrenamiento ---
BASE_MODEL_ID = "facebook/nllb-200-distilled-600M"

# --- 3. Rutas para Guardar en Google Drive ---
# Asegúrate de que esta carpeta exista en tu Google Drive
DRIVE_PATH = "/content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion"
ES_QUC_DATASET_PATH = f"{DRIVE_PATH}/es_quc_dataset"
MAYANV_REPO_PATH = f"{DRIVE_PATH}/mayanv"
EN_QUC_DATASET_FILES_PATH = f"{DRIVE_PATH}/en_quc_dataset_files"
os.makedirs(DRIVE_PATH, exist_ok=True) # Crea la carpeta si no existe

# Nombres de los modelos que se guardarán
FINETUNED_PIVOT_MODEL_PATH = f"{DRIVE_PATH}/nllb_finetuned_{PIVOT_LANG_SHORT_CODE}_{TARGET_LANG_SHORT_CODE}"
FINETUNED_SYNTHETIC_MODEL_PATH = f"{DRIVE_PATH}/nllb_finetuned_{SOURCE_LANG_NAME.lower()}_{TARGET_LANG_SHORT_CODE}"

print(f"✅ Configuración cargada para la tarea: {SOURCE_LANG_NAME} -> {TARGET_LANG_NAME}")
print(f"Los modelos se guardarán en: {DRIVE_PATH}")
# Out:
# ✅ Configuración cargada para la tarea: Inglés -> K'iche'
# Los modelos se guardarán en: /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion

# %% [markdown]
# ### Funciones comunes

# %%
def translate_text(model, tokenizer, text, src_lang, tgt_lang):
    tokenizer.src_lang = src_lang
    forced_bos_id = tokenizer.convert_tokens_to_ids(tgt_lang)
    inputs = tokenizer(text, return_tensors="pt", truncation=True)
    outputs = model.generate(**inputs, forced_bos_token_id=forced_bos_id)
    return tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]

# %%
def generate_dataset(language, train_folder="train", test_folder="test", base_path=MAYANV_REPO_PATH): # Use MAYANV_REPO_PATH from config
    """
    Generates a dataset from text files within the mayanv repository.

    Args:
        language (str): The language code (e.g., "quc").
        train_folder (str): The name of the training data folder within the language directory.
        test_folder (str): The name of the testing data folder within the language directory.
        base_path (str): The base path to the cloned mayanv repository in Google Drive.

    Returns:
        DatasetDict: A DatasetDict containing the train and test splits.
    """
    # Construct paths to the text files within the mayanv repository in Drive
    mayanv_language_path = os.path.join(base_path, "MayanV", language)
    train_lang_path = os.path.join(mayanv_language_path, train_folder, f"data.{language}")
    test_lang_path = os.path.join(mayanv_language_path, test_folder, f"data.{language}")

    train_es_path = os.path.join(mayanv_language_path, train_folder, "data.es")
    test_es_path = os.path.join(mayanv_language_path, test_folder, "data.es")

    print(f"Attempting to load train split from: {train_es_path} and {train_lang_path}")
    print(f"Attempting to load test split from: {test_es_path} and {test_lang_path}")


    # Carga manual de archivos
    def load_lines(path):
        if not os.path.exists(path):
            print(f"❌ Error: File not found at {path}")
            return None
        with open(path, encoding="utf-8") as f:
            return [line.strip() for line in f if line.strip()] # Filter out empty lines


    train_src = load_lines(train_lang_path)
    train_tgt = load_lines(train_es_path)

    test_src = load_lines(test_lang_path)
    test_tgt = load_lines(test_es_path)

    # Check if loading was successful
    if train_src is None or train_tgt is None or test_src is None or test_tgt is None:
        return None

    # Crea datasets
    train_dataset = Dataset.from_dict({"input": train_src, "target": train_tgt})
    test_dataset = Dataset.from_dict({"input": test_src, "target": test_tgt})

    return DatasetDict({
        "train": train_dataset,
        "test": test_dataset,
    })

# %% [markdown]
# ## Librerías

# %%
from IPython.display import clear_output
# !pip install -U bitsandbytes accelerate peft transformers sentencepiece datasets
# !pip install evaluate
# !pip install rouge_score
clear_output()

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Trainer, TrainingArguments, BitsAndBytesConfig
from peft import LoraConfig, get_peft_model, TaskType
from datasets import load_dataset, DatasetDict, Dataset
import evaluate
from tqdm import tqdm
import csv
import torch

# %%
from peft import PeftModel

# %%
# !git clone https://github.com/transducens/mayanv.git
# Out:
# fatal: destination path 'mayanv' already exists and is not an empty directory.

# %% [markdown]
# ## Load from Google Drive

# %% [markdown]
# #### Load English Kiche Zero-Shot Model

# %%
model_name = "facebook/nllb-200-distilled-600M"
zeroshot_tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
zeroshot_model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

zeroshot_tokenizer.src_lang = "eng_Latn"
forced_bos_id = zeroshot_tokenizer.convert_tokens_to_ids("quc_Latn")

# %% [markdown]
# #### Load Spanish Kiche Model

# %%
def load_models_and_tokenizers_espanol_kiche(drive_path: str, base_model_id: str):
    """
    Loads the fine-tuned Español-K'iche' QLoRA model and tokenizer.

    Args:
        drive_path (str): Base path to your Google Drive.
        base_model_id (str): Identifier for the base model (e.g., "facebook/nllb-200-distilled-600M").

    Returns:
        tuple: A tuple containing reloaded_finetune_model and reloaded_finetune_tokenizer.
               Returns (None, None) if loading fails.
    """
    reloaded_finetune_model = None
    reloaded_finetune_tokenizer = None
    save_path_es_quc = f"{drive_path}/qlora_finetuned_es_quc_nllb"

    if os.path.exists(save_path_es_quc):
        print(f"✅ Found fine-tuned model directory at {save_path_es_quc}")
        try:
            # Load the base model first (needed for QLoRA)
            reloaded_base_model = AutoModelForSeq2SeqLM.from_pretrained(base_model_id)

            # Load the QLoRA adapter weights on top of the base model
            reloaded_finetune_model = PeftModel.from_pretrained(reloaded_base_model, save_path_es_quc)

            # Load the tokenizer
            reloaded_finetune_tokenizer = AutoTokenizer.from_pretrained(save_path_es_quc)

            print(f"✅ Model and tokenizer reloaded successfully from {save_path_es_quc}")
        except Exception as e:
            print(f"❌ Error reloading fine-tuned model: {e}")
    else:
        print(f"❌ Fine-tuned model directory not found at {save_path_es_quc}")
        print("Please ensure the model was saved correctly.")

    return reloaded_finetune_model, reloaded_finetune_tokenizer

# %%
# Load models and tokenizers
espanol_kiche_finetune_model, espanol_kiche_finetune_tokenizer = load_models_and_tokenizers_espanol_kiche(DRIVE_PATH, BASE_MODEL_ID)
es_quc_model = espanol_kiche_finetune_model
es_quc_tokenizer = espanol_kiche_finetune_tokenizer
# Out:
# ✅ Found fine-tuned model directory at /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/qlora_finetuned_es_quc_nllb
# ❌ Error reloading fine-tuned model: Error(s) in loading state_dict for PeftModelForSeq2SeqLM:
# 	size mismatch for base_model.model.model.shared.weight: copying a param with shape torch.Size([256205, 1024]) from checkpoint, the shape in current model is torch.Size([256206, 1024]).
# 	size mismatch for base_model.model.lm_head.weight: copying a param with shape torch.Size([256205, 1024]) from checkpoint, the shape in current model is torch.Size([256206, 1024]).

# %%
import torch
from tqdm import tqdm

# --- 1. CARGAR TU MODELO FINE-TUNED DESDE GOOGLE DRIVE ---
# Esta es la celda que me proporcionaste.
print("Cargando tu modelo fine-tuned Español -> K'iche' desde Google Drive...")
try:
    # Usamos la función que ya tienes para cargar el modelo y el tokenizador
    es_quc_model, es_quc_tokenizer = load_models_and_tokenizers_espanol_kiche(DRIVE_PATH, BASE_MODEL_ID)

    if es_quc_model is None or es_quc_tokenizer is None:
        raise ValueError("La carga del modelo falló. Revisa los logs de la función de carga.")

    # Movemos el modelo a la GPU si está disponible
    device = "cuda" if torch.cuda.is_available() else "cpu"
    es_quc_model.to(device)
    print(f"✅ Modelo fine-tuned cargado exitosamente en el dispositivo: {device}")

except Exception as e:
    print(f"❌ Error: No se pudo cargar el modelo. Asegúrate de que la ruta '{DRIVE_PATH}/qlora_finetuned_es_quc_nllb' sea correcta y que el modelo se haya guardado bien. Error: {e}")

# --- 2. CONFIGURACIÓN DE LA PRUEBA ---
# Ahora la fuente es Español, no Inglés.
SOURCE_LANG_CODE_TEST = "spa_Latn"
TARGET_LANG_CODE_TEST = "quc_Latn" # El objetivo sigue siendo K'iche'

# --- 3. FUNCIÓN DE PREDICCIÓN (la misma de antes, pero la incluimos por claridad) ---
def generate_predictions_finetuned(model_to_test, tokenizer_to_use, dataset_to_test, n_examples=10):
    predictions = []
    references = []

    if model_to_test is None:
        print("El modelo no está cargado, no se puede continuar.")
        return None, None

    model_to_test.eval()
    device = model_to_test.device

    # Configuramos los idiomas en el tokenizador
    tokenizer_to_use.src_lang = SOURCE_LANG_CODE_TEST
    forced_bos_id = tokenizer_to_use.convert_tokens_to_ids(TARGET_LANG_CODE_TEST)

    print(f"\nIniciando predicciones con el modelo fine-tuned de '{SOURCE_LANG_CODE_TEST}' a '{TARGET_LANG_CODE_TEST}'...")
    num_samples = min(n_examples, len(dataset_to_test))

    for i in tqdm(range(num_samples)):
        # El dataset es_quc tiene 'input' (k'iche') y 'target' (español).
        # Para probar Español -> K'iche', invertimos los papeles.
        input_text = dataset_to_test[i]["target"]  # La entrada es el Español
        reference = dataset_to_test[i]["input"]   # La referencia es el K'iche'

        inputs = tokenizer_to_use(input_text, return_tensors="pt", truncation=True, max_length=128).to(device)

        with torch.no_grad():
            outputs = model_to_test.generate(
                **inputs,
                forced_bos_token_id=forced_bos_id,
                max_length=128
            )

        pred = tokenizer_to_use.batch_decode(outputs, skip_special_tokens=True)[0]

        predictions.append(pred)
        references.append(reference)

    return predictions, references

# --- 4. EJECUCIÓN DE LA PRUEBA ---
# Usamos el dataset de prueba de Español-K'iche'
# Asegúrate de que la variable 'es_quc_dataset' exista
if 'es_quc_dataset' in locals() and es_quc_model is not None:
    test_dataset = es_quc_dataset["test"]

    predictions_ft, references_ft = generate_predictions_finetuned(
        model_to_test=es_quc_model,
        tokenizer_to_use=es_quc_tokenizer,
        dataset_to_test=test_dataset,
        n_examples=10
    )

    # --- 5. IMPRESIÓN DE RESULTADOS ---
    if predictions_ft:
        print("\n=== Ejemplos de Traducción (Tu Modelo Fine-Tuned) ===")
        for i in range(len(predictions_ft)):
            print(f"\nEntrada (Español):   {test_dataset[i]['target']}")
            print(f"Referencia (K'iche'):  {references_ft[i]}")
            print(f"Predicción (Tu Modelo): {predictions_ft[i]}")
else:
    print("\n⚠️ No se pudo ejecutar la prueba. Asegúrate de que el modelo se cargó y que 'es_quc_dataset' está definido.")
# Out:
# Cargando tu modelo fine-tuned Español -> K'iche' desde Google Drive...
# ✅ Found fine-tuned model directory at /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/qlora_finetuned_es_quc_nllb
# ❌ Error reloading fine-tuned model: Error(s) in loading state_dict for PeftModelForSeq2SeqLM:
# 	size mismatch for base_model.model.model.shared.weight: copying a param with shape torch.Size([256205, 1024]) from checkpoint, the shape in current model is torch.Size([256206, 1024]).
# 	size mismatch for base_model.model.lm_head.weight: copying a param with shape torch.Size([256205, 1024]) from checkpoint, the shape in current model is torch.Size([256206, 1024]).
# ❌ Error: No se pudo cargar el modelo. Asegúrate de que la ruta '/content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/qlora_finetuned_es_quc_nllb' sea correcta y que el modelo se haya guardado bien. Error: La carga del modelo falló. Revisa los logs de la función de carga.
#
# ⚠️ No se pudo ejecutar la prueba. Asegúrate de que el modelo se cargó y que 'es_quc_dataset' está definido.

# %% [markdown]
# #### Load English Kiche Model

# %%
from peft import PeftModel
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM # Import AutoModelForSeq2SeqLM

def load_finetuned_english_kiche_model(drive_path: str, base_model_id: str):
    """
    Loads the fine-tuned English-K'iche' model and tokenizer from Google Drive.

    Args:
        drive_path (str): Base path to your Google Drive where the model is saved.
        base_model_id (str): Identifier for the base model (e.g., "facebook/nllb-200-distilled-600M").

    Returns:
        tuple: A tuple containing reloaded_model and reloaded_tokenizer.
               Returns (None, None) if loading fails.
    """
    reloaded_model = None
    reloaded_tokenizer = None
    save_path = f"{drive_path}/finetuned_en_quc_nllb"

    if os.path.exists(save_path):
        print(f"✅ Found fine-tuned model directory at {save_path}")
        try:
            # Load the fine-tuned model directly
            reloaded_model = AutoModelForSeq2SeqLM.from_pretrained(save_path)

            # Load the tokenizer
            reloaded_tokenizer = AutoTokenizer.from_pretrained(save_path)

            print(f"✅ Model and tokenizer reloaded successfully from {save_path}")
        except Exception as e:
            print(f"❌ Error reloading fine-tuned model: {e}")
            reloaded_model = None
            reloaded_tokenizer = None
    else:
        print(f"❌ Fine-tuned model directory not found at {save_path}")
        print("Please ensure the model was saved correctly.")

    return reloaded_model, reloaded_tokenizer

# Example usage (you can run this cell to test loading)
# en_quc_finetuned_model, en_quc_finetuned_tokenizer = load_finetuned_english_kiche_model(DRIVE_PATH, BASE_MODEL_ID)

# %%
english_kiche_finetuned_model, english_kiche_finetuned_tokenizer = load_finetuned_english_kiche_model(DRIVE_PATH, BASE_MODEL_ID)
en_quc_model = english_kiche_finetuned_model
en_quc_tokenizer = english_kiche_finetuned_tokenizer
# Out:
# ✅ Found fine-tuned model directory at /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/finetuned_en_quc_nllb
# ✅ Model and tokenizer reloaded successfully from /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/finetuned_en_quc_nllb

# %% [markdown]
# #### Load Spanish-Kiche and English-Kiche datasets

# %%
def load_datasets(es_quc_dataset_path: str, en_quc_dataset_files_path: str, mayanv_repo_path: str):
    """
    Carga ambos datasets desde sus respectivas carpetas guardadas en Google Drive.
    """
    loaded_es_quc_dataset = None
    en_quc_dataset = None

    # --- 1. Cargar el dataset Español-K'iche' desde su carpeta guardada ---
    # Se mantiene tu lógica original de cargar desde el disco.
    print(f"\n--- Intentando cargar es_quc_dataset desde: {es_quc_dataset_path} ---")
    try:
        loaded_es_quc_dataset = DatasetDict.load_from_disk(es_quc_dataset_path)
        print("✅ Dataset Español-K'iche' cargado exitosamente desde el disco.")
        print(loaded_es_quc_dataset)
    except Exception as e:
        print(f"❌ Error al cargar es_quc_dataset desde el disco: {e}")
        print("Asegúrate de haber ejecutado la celda que lo guarda con 'save_to_disk' primero.")

    # --- 2. Cargar el dataset sintético Inglés-K'iche' desde archivos de texto ---
    # Aquí aplicamos la corrección para que se cargue como un dataset paralelo.
    print(f"\n--- Cargando dataset sintético desde: {en_quc_dataset_files_path} ---")

    def load_parallel_corpus_from_files(split_name):
        """Función interna para leer los archivos .en y .quc y unirlos."""
        source_path = f"{en_quc_dataset_files_path}/{split_name}.en"
        target_path = f"{en_quc_dataset_files_path}/{split_name}.quc"

        if not os.path.exists(source_path) or not os.path.exists(target_path):
            print(f"ADVERTENCIA: Archivos para el split '{split_name}' no encontrados en la ruta.")
            return None

        with open(source_path, "r", encoding="utf-8") as f:
            source_lines = [line.strip() for line in f.readlines()]
        with open(target_path, "r", encoding="utf-8") as f:
            target_lines = [line.strip() for line in f.readlines()]

        if len(source_lines) != len(target_lines):
            raise ValueError(f"Archivos del split '{split_name}' no tienen el mismo número de líneas.")

        # Devolvemos un Dataset con las columnas "input" y "target"
        return Dataset.from_dict({"input": source_lines, "target": target_lines})

    train_split = load_parallel_corpus_from_files("train")
    test_split = load_parallel_corpus_from_files("test")

    if train_split and test_split:
        en_quc_dataset = DatasetDict({"train": train_split, "test": test_split})
        print("✅ Dataset sintético Inglés-K'iche' cargado correctamente con 2 columnas.")
    else:
        print("❌ Fallo al cargar el dataset sintético.")
        en_quc_dataset = None

    return loaded_es_quc_dataset, en_quc_dataset

# %%
# Load datasets and verify repository
espanol_kiche_dataset, english_kiche_dataset = load_datasets(ES_QUC_DATASET_PATH, EN_QUC_DATASET_FILES_PATH, MAYANV_REPO_PATH)
es_quc_dataset = espanol_kiche_dataset
en_quc_dataset = english_kiche_dataset
# Out:
# --- Intentando cargar es_quc_dataset desde: /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/es_quc_dataset ---
# ✅ Dataset Español-K'iche' cargado exitosamente desde el disco.
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'target'],
#         num_rows: 624
#     })
#     test: Dataset({
#         features: ['input', 'target'],
#         num_rows: 1000
#     })
# })
#
# --- Cargando dataset sintético desde: /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/en_quc_dataset_files ---
# ✅ Dataset sintético Inglés-K'iche' cargado correctamente con 2 columnas.

# %%
for i in range(0, 20):
    print(f"> Input:     {es_quc_dataset['test'][i]['input']}")
    print(f"> Target:  {es_quc_dataset['test'][i]['target']}")
    print("-")
# Out:
# > Input:     Kqʼulqʼut ri apam
# > Target:  #quc# Tienes indigestión
# -
# > Input:     Xanimaj bʼik ri kuk
# > Target:  #quc# La ardilla se escapó
# -
# > Input:     Tajin kamuxan ri awecham
# > Target:  #quc# Tu cuñado está nadando
# -
# > Input:     Xinriq raxtew pa taqʼaj
# > Target:  #quc# En la costa me contagié de paludismo
# -
# > Input:     Xinpe rukʼ chech ubʼanik siʼ, pa ri juyubʼ
# > Target:  #quc# Vengo con él para hacer leña en la montaña
# -
# > Input:     Kʼo kʼaqat chi raqan ri tataʼ
# > Target:  #quc# El señor tiene picazón en los pies
# -
# > Input:     Rajwaxik kawetaʼmaj pa uwiʼ ri chʼajchʼojisanem
# > Target:  #quc# Necesitas aprender acerca el aseo
# -
# > Input:     Nim ri qʼoqʼ
# > Target:  #quc# El chilacayote es grande
# -
# > Input:     Chqʼalajisaj awibʼ chi kiwach ri tinamit
# > Target:  #quc# Aclárate ante el pueblo
# -
# > Input:     Kakowij che ri apatan
# > Target:  #quc# Te apuras a tus tareas
# -
# > Input:     Ri abʼaj yatzalik
# > Target:  #quc# La piedra es liviana
# -
# > Input:     Pa juyubʼ Sibʼalaj raqan neʼ kʼolik
# > Target:  #quc# En la montaña hay muchos pies de niños
# -
# > Input:     Man kʼo ta jun nukʼubʼal chak Amaqʼ
# > Target:  #quc# No tenemos una currícula nacional
# -
# > Input:     Sibʼalaj xinkʼaʼnarik
# > Target:  #quc# Me enoje mucho
# -
# > Input:     Kinwaj katinqʼaluj
# > Target:  #quc# Quisiera abrazarte
# -
# > Input:     Chsoloʼ rij taq saqwach
# > Target:  #quc# Hay que pelar las papas
# -
# > Input:     Ri kʼel kutij aj
# > Target:  #quc# El chocoyo come elotes
# -
# > Input:     Kinbʼan na jun tzʼaq chi riʼ
# > Target:  #quc# Tengo que hacer una construcción aquí
# -
# > Input:     Su xabʼij chi wech?
# > Target:  #quc# ¿ ¿Qué fue lo que me dijiste?
# -
# > Input:     Paqal rajil ri taq etzʼabʼaʼl
# > Target:  #quc# Los juguetes están muy caros
# -

# %%
for i in range(0, 20):
    print(f"> Input:     {en_quc_dataset['test'][i]['input']}")
    print(f"> Target:  {en_quc_dataset['test'][i]['target']}")
    print("-")
# Out:
# > Input:     You have indigestion
# > Target:  Kqʼulqʼut ri apam
# -
# > Input:     The squirrel escaped
# > Target:  Xanimaj bʼik ri kuk
# -
# > Input:     # What's up? # Your brother-in-law is swimming
# > Target:  Tajin kamuxan ri awecham
# -
# > Input:     #quc# On the coast I got malaria
# > Target:  Xinriq raxtew pa taqʼaj
# -
# > Input:     #quc# I'm coming with him to make wood in the mountain
# > Target:  Xinpe rukʼ chech ubʼanik siʼ, pa ri juyubʼ
# -
# > Input:     The gentleman has itching feet
# > Target:  Kʼo kʼaqat chi raqan ri tataʼ
# -
# > Input:     #quc# You need to learn about the toilet
# > Target:  Rajwaxik kawetaʼmaj pa uwiʼ ri chʼajchʼojisanem
# -
# > Input:     The chilacayote is big
# > Target:  Nim ri qʼoqʼ
# -
# > Input:     # Quc # Clear yourself up to the people
# > Target:  Chqʼalajisaj awibʼ chi kiwach ri tinamit
# -
# > Input:     # Quc# You rush to your homework
# > Target:  Kakowij che ri apatan
# -
# > Input:     ♪ The stone is light ♪
# > Target:  Ri abʼaj yatzalik
# -
# > Input:     # Quc # In the mountains there are many children's feet
# > Target:  Pa juyubʼ Sibʼalaj raqan neʼ kʼolik
# -
# > Input:     #quc# We don't have a national curriculum
# > Target:  Man kʼo ta jun nukʼubʼal chak Amaqʼ
# -
# > Input:     I'm very angry
# > Target:  Sibʼalaj xinkʼaʼnarik
# -
# > Input:     # What # I'd like to hug you
# > Target:  Kinwaj katinqʼaluj
# -
# > Input:     # Quc # You gotta peel the potatoes
# > Target:  Chsoloʼ rij taq saqwach
# -
# > Input:     # What's that? # The chocoo eats elots
# > Target:  Ri kʼel kutij aj
# -
# > Input:     I have to make a construction here
# > Target:  Kinbʼan na jun tzʼaq chi riʼ
# -
# > Input:     What did you say to me?
# > Target:  Su xabʼij chi wech?
# -
# > Input:     Toys are too expensive
# > Target:  Paqal rajil ri taq etzʼabʼaʼl
# -

# %%
en_quc_dataset["test"][1]
# Out:
# {'input': 'The squirrel escaped', 'target': 'Xanimaj bʼik ri kuk'}

# %% [markdown]
# #### Clean Up

# %% [markdown]
# ##### Clean Up English Input from quc tags

# %%
import re

def clean_english_input(example):
    """
    Toma un ejemplo del dataset y limpia únicamente la columna 'input' (inglés),
    eliminando los artefactos y etiquetas no deseadas.
    """
    # Patrones a eliminar: #quc# (y variantes), #, ♪
    dirty_text = example["input"]

    # Usamos expresiones regulares para una limpieza robusta
    # Elimina #quc#, # quc #, # Quc #, etc. ignorando mayúsculas/minúsculas y espacios
    clean_text = re.sub(r'#\s*quc\s*#', '', dirty_text, flags=re.IGNORECASE)
    # Elimina el símbolo ♪
    clean_text = re.sub(r'♪', '', clean_text)
    # Elimina cualquier caracter # que haya quedado suelto
    clean_text = clean_text.replace('#', '')

    # Elimina espacios extra al principio o al final
    example["input"] = clean_text.strip()

    return example

# --- Aplicar la función de limpieza a todo el dataset ---
# .map() es una forma muy eficiente de aplicar una función a cada fila
print("🧼 Limpiando el dataset sintético 'en_quc_dataset'...")

cleaned_en_quc_dataset = en_quc_dataset.map(
    clean_english_input,
    desc="Limpiando columna 'input'"
)

print("\n✅ Limpieza completada.")

# --- Verificación ---
# Imprimamos un par de ejemplos para ver el ANTES y el DESPUÉS.
print("\n--- Verificando la limpieza ---")

# Ejemplo problemático ANTES de la limpieza
original_example = en_quc_dataset["test"][2]
print(f"Original \t> Entrada: {original_example['input']}")
print(f"\t\t> Referencia: {original_example['target']}")

# Mismo ejemplo DESPUÉS de la limpieza
cleaned_example = cleaned_en_quc_dataset["test"][2]
print(f"Limpiado \t> Entrada: {cleaned_example['input']}")
print(f"\t\t> Referencia: {cleaned_example['target']}")

# Otro ejemplo
original_example_2 = en_quc_dataset["test"][3]
print(f"\nOriginal \t> Entrada: {original_example_2['input']}")
print(f"\t\t> Referencia: {original_example_2['target']}")

cleaned_example_2 = cleaned_en_quc_dataset["test"][3]
print(f"Limpiado \t> Entrada: {cleaned_example_2['input']}")
print(f"\t\t> Referencia: {cleaned_example_2['target']}")
# Out:
# 🧼 Limpiando el dataset sintético 'en_quc_dataset'...
# Limpiando columna 'input':   0%|          | 0/624 [00:00<?, ? examples/s]
# Limpiando columna 'input':   0%|          | 0/1000 [00:00<?, ? examples/s]
# ✅ Limpieza completada.
#
# --- Verificando la limpieza ---
# Original 	> Entrada: What's up?  Your brother-in-law is swimming
# 		> Referencia: Tajin kamuxan ri awecham
# Limpiado 	> Entrada: What's up?  Your brother-in-law is swimming
# 		> Referencia: Tajin kamuxan ri awecham
#
# Original 	> Entrada: On the coast I got malaria
# 		> Referencia: Xinriq raxtew pa taqʼaj
# Limpiado 	> Entrada: On the coast I got malaria
# 		> Referencia: Xinriq raxtew pa taqʼaj

# %%
for i in range(1000):
    print("//")
    print(f"> Entrada:     {cleaned_en_quc_dataset['test'][i]['input']}")
    print(f"> Referencia:  {cleaned_en_quc_dataset['test'][i]['target']}")
    print("--")
# Out:
# //
# > Entrada:     You have indigestion
# > Referencia:  Kqʼulqʼut ri apam
# --
# //
# > Entrada:     The squirrel escaped
# > Referencia:  Xanimaj bʼik ri kuk
# --
# //
# > Entrada:     What's up?  Your brother-in-law is swimming
# > Referencia:  Tajin kamuxan ri awecham
# --
# //
# > Entrada:     On the coast I got malaria
# > Referencia:  Xinriq raxtew pa taqʼaj
# --
# //
# > Entrada:     I'm coming with him to make wood in the mountain
# > Referencia:  Xinpe rukʼ chech ubʼanik siʼ, pa ri juyubʼ
# --
# //
# > Entrada:     The gentleman has itching feet
# > Referencia:  Kʼo kʼaqat chi raqan ri tataʼ
# --
# //
# > Entrada:     You need to learn about the toilet
# > Referencia:  Rajwaxik kawetaʼmaj pa uwiʼ ri chʼajchʼojisanem
# --
# //
# > Entrada:     The chilacayote is big
# > Referencia:  Nim ri qʼoqʼ
# --
# //
# > Entrada:     Clear yourself up to the people
# > Referencia:  Chqʼalajisaj awibʼ chi kiwach ri tinamit
# --
# //
# > Entrada:     You rush to your homework
# > Referencia:  Kakowij che ri apatan
# --
# //
# > Entrada:     The stone is light
# > Referencia:  Ri abʼaj yatzalik
# --
# //
# > Entrada:     In the mountains there are many children's feet
# > Referencia:  Pa juyubʼ Sibʼalaj raqan neʼ kʼolik
# --
# //
# > Entrada:     We don't have a national curriculum
# > Referencia:  Man kʼo ta jun nukʼubʼal chak Amaqʼ
# --
# //
# > Entrada:     I'm very angry
# > Referencia:  Sibʼalaj xinkʼaʼnarik
# --
# //
# > Entrada:     What  I'd like to hug you
# > Referencia:  Kinwaj katinqʼaluj
# --
# //
# > Entrada:     You gotta peel the potatoes
# > Referencia:  Chsoloʼ rij taq saqwach
# --
# //
# > Entrada:     What's that?  The chocoo eats elots
# > Referencia:  Ri kʼel kutij aj
# --
# //
# > Entrada:     I have to make a construction here
# > Referencia:  Kinbʼan na jun tzʼaq chi riʼ
# --
# //
# > Entrada:     What did you say to me?
# > Referencia:  Su xabʼij chi wech?
# --
# //
# > Entrada:     Toys are too expensive
# > Referencia:  Paqal rajil ri taq etzʼabʼaʼl
# --
# //
# > Entrada:     What  My partner is happy
# > Referencia:  Kkiʼkot ri nukʼulaj
# --
# //
# > Entrada:     You're careful when you walk down the street
# > Referencia:  Kachajij awibʼ pa taq uqʼabʼ uxoʼl bʼe
# --
# //
# > Entrada:     The middle-cincan wild plant cured me
# > Referencia:  Xukunaj nupam ri ojolom ikox
# --
# //
# > Entrada:     The membrane is very acidic
# > Referencia:  Sibʼalaj chʼam ri amprino
# --
# //
# > Entrada:     The heat makes me very thirsty
# > Referencia:  Ri qʼaqʼ kuya chaqiʼj chiʼ chi wech
# --
# //
# > Entrada:     The lady
# > Referencia:  Ri ixoq bʼenaq rukʼ ri ajkun rumal che kqʼaxow ri uchuch upam
# --
# //
# > Entrada:     I sold the pig for 220 quetzal
# > Referencia:  Xinkʼayij bʼik ri aq rukʼ julajkʼal qʼuqʼ
# --
# //
# > Entrada:     Francis went too far
# > Referencia:  Naj xbʼe wi ri a Siʼs
# --
# //
# > Entrada:     My axe was returned
# > Referencia:  Xkitzalij ri wikaj
# --
# //
# > Entrada:     It's too thick the tip of the stick
# > Referencia:  Sorosik ubʼanom ri uwiʼ le cheʼ
# --
# //
# > Entrada:     the ring got lost in the zacate
# > Referencia:  Xtzaqik ri mulqʼabʼ pa ri qʼayes
# --
# //
# > Entrada:     The man is naked
# > Referencia:  Chʼanal ri achi
# --
# //
# > Entrada:     There are stars in the sky
# > Referencia:  Kʼo chʼumil chi uwach ri kaj
# --
# //
# > Entrada:     The bait is good for hand cracks
# > Referencia:  Ri xepu utz kkoj che ri pixnaq qʼabʼaj
# --
# //
# > Entrada:     My sister is learning typography
# > Referencia:  Tajin karetaʼmaj aninaq tzʼibʼ ri wanabʼ
# --
# //
# > Entrada:     The girl is crazy
# > Referencia:  Sibʼalaj mox ri ali
# --
# //
# > Entrada:     What's your son-in-law's name?
# > Referencia:  ¿Jas ubʼiʼ ri ajiʼatz?
# --
# //
# > Entrada:     The wood I left blown up in the hallway
# > Referencia:  Xintun kan ri siʼ pa raqan ja
# --
# //
# > Entrada:     When you see twins give them money, because your clothes are stitched
# > Referencia:  We keʼawil yoʼx chasipaj kirajil we man kasipaj, kkibʼan kʼax che ri awatzʼiyaq
# --
# //
# > Entrada:     The cook cook prepared the meat very well
# > Referencia:  Sibʼalaj jeʼlik xel ri tiʼj rumal ri bʼanal wa
# --
# //
# > Entrada:     There's a celebration in the village
# > Referencia:  Pa ri tinamit kʼo nimaqʼijem
# --
# //
# > Entrada:     My uncle traveled to Asia
# > Referencia:  Ri wikan bʼenaq qʼanamaqʼ
# --
# //
# > Entrada:     The achote is expensive
# > Referencia:  Paqal rajil ri kʼoxobʼ
# --
# //
# > Entrada:     You need to get married publicly
# > Referencia:  Rajawaxik chisaqrisaj ri ikʼulanem
# --
# //
# > Entrada:     My aunt uses the fire plow
# > Referencia:  Ri nuchʼutinan kukoj ri piʼq pa ri qʼaqʼ
# --
# //
# > Entrada:     The weaving instrument has been with me for a long time
# > Referencia:  We tzʼulubʼ riʼ ojer chik kʼo wukʼ
# --
# //
# > Entrada:     Nicholas divided his land in three
# > Referencia:  Ri a Kulax kubʼan pa oxibʼ ri rulew
# --
# //
# > Entrada:     The tizz that's on the roof is pretty thick
# > Referencia:  Pim ri xaq kʼo chi uxe awiʼ ja
# --
# //
# > Entrada:     Tomorrow I'll take him
# > Referencia:  Kinkʼam na bʼik chweʼq
# --
# //
# > Entrada:     The brooch is too narrow so it doesn't look good
# > Referencia:  Nitzʼ uwach ri tzʼajibʼal rumal riʼ man utz taj ktzʼajnik
# --
# //
# > Entrada:     The cow belongs to Lucia
# > Referencia:  Ri wakax rech ri Luʼs
# --
# //
# > Entrada:     The snow burned the seed
# > Referencia:  Ri saqtew xukʼat ri tikoʼn
# --
# //
# > Entrada:     When you come, bring your mom too
# > Referencia:  Are chiʼ katpetik xuqujeʼ kakʼam loq ri anan
# --
# //
# > Entrada:     It's necessary to divide the land between the children
# > Referencia:  Rajawaxik kabʼan ri jachanem ulew chi kech ri alkʼwaʼlixelabʼ
# --
# //
# > Entrada:     What  You always wear the lighter because you're a smoker
# > Referencia:  Awukʼaʼm junalik ri tzijbʼal rumal katubʼaj ri sikʼ
# --
# //
# > Entrada:     Antonia is naked
# > Referencia:  Chʼiychʼik uwiʼ ri ali Toʼn
# --
# //
# > Entrada:     What  My stepson loves me
# > Referencia:  Kinraj ri nukʼojolabʼal
# --
# //
# > Entrada:     Tell me anything you think
# > Referencia:  Ja such kuchomaj kubʼij chi we
# --
# //
# > Entrada:     Tomorrow I'll tell you what I thought
# > Referencia:  Kintzijobʼej chi awe chweʼq jas xinchomaj
# --
# //
# > Entrada:     The raven took the chicken
# > Referencia:  Ri joj xukʼam bʼik ri akʼ
# --
# //
# > Entrada:     Let's do our job
# > Referencia:  Chqabʼana ri qachak
# --
# //
# > Entrada:     This year I planted beans
# > Referencia:  Che we junabʼ xintik jawux
# --
# //
# > Entrada:     All workers carry their tools
# > Referencia:  Konojel ri ajchakibʼ kikʼam bʼik kichakubʼal
# --
# //
# > Entrada:     I gave the kids a huge swing
# > Referencia:  Xinbʼan jun nim kitzaybʼal ri akʼalabʼ
# --
# //
# > Entrada:     Everyone applauded what she said
# > Referencia:  Xpaqʼpaqapaʼ kiqʼabʼ chech xubʼij ri ali
# --
# //
# > Entrada:     I grow cotton seed on the milp
# > Referencia:  Xkiy le tux pa le abʼix
# --
# //
# > Entrada:     I need the shovel
# > Referencia:  Kinkoj ri jokbʼal ulew
# --
# //
# > Entrada:     I'll be back here until the seventeenth day
# > Referencia:  Pa uwuqlajuj qʼij kintzalij loq waral
# --
# //
# > Entrada:     The lime splattered my palm
# > Referencia:  Ri chun xuya salkʼam pa ri nuqʼabʼ
# --
# //
# > Entrada:     Not very common red pine
# > Referencia:  Man kʼi taj ri kaq chaj
# --
# //
# > Entrada:     Will you come with us tomorrow?
# > Referencia:  ¿La katpe qukʼ chweʼq?
# --
# //
# > Entrada:     The leg swelling is already better
# > Referencia:  Ri sipojem kʼo chech ri raqan utz chik
# --
# //
# > Entrada:     In the cave there is water
# > Referencia:  Chi upam ri pek kʼo jaʼ
# --
# //
# > Entrada:     Tomás is from Canilla
# > Referencia:  Ri Max are aj qʼan iyaʼ
# --
# //
# > Entrada:     Write the refrain you know
# > Referencia:  chtzʼibʼaj janipa noʼjibʼal tzij awetaʼm
# --
# //
# > Entrada:     What  The dancers dance
# > Referencia:  Kexojow ri ajxojolobʼ
# --
# //
# > Entrada:     The doctor lives on the edge of the Triangle
# > Referencia:  Ri ajkun kel chuchiʼ ri oxtzalaj
# --
# //
# > Entrada:     There's still a little bit in the pot
# > Referencia:  Kʼo juchʼin chi upam ri tʼuʼy
# --
# //
# > Entrada:     The turkey is eating the wheat
# > Referencia:  Ri tukumux tajin kutij ri triko
# --
# //
# > Entrada:     The drawer is closed so it doesn't get into white sand
# > Referencia:  Tzʼapim uwiʼ ri kaxon rech man kok ta poqlaj chi upam
# --
# //
# > Entrada:     Now they don't use bows or arrows anymore
# > Referencia:  Kamik man kkoj ta chik ri chʼabʼ
# --
# //
# > Entrada:     Miguel left the board ready to sow
# > Referencia:  Xubʼan kanoq ri lochʼoj rech tikonijik ri a Kel
# --
# //
# > Entrada:     The horse tail is medicinal
# > Referencia:  Kunabʼal ri kʼibʼ
# --
# //
# > Entrada:     My mom forgave me
# > Referencia:  Xusach numak ri nunan
# --
# //
# > Entrada:     The kidnapper took my money
# > Referencia:  Ri majanel xumaj nurajil
# --
# //
# > Entrada:     I'm the fourth brother of my mom's kids
# > Referencia:  In ukaj achalal chi kixoʼl ral ri nunan
# --
# //
# > Entrada:     He wrote his resignation
# > Referencia:  Xutzʼibʼaj ri uwuj rech resabʼal ibʼ
# --
# //
# > Entrada:     It's nice to stay at your house
# > Referencia:  Jeʼl kʼolem chi awachoch
# --
# //
# > Entrada:     You know the color is canary
# > Referencia:  Awilom jas rij ri tzʼikin ubʼiʼ chowix
# --
# //
# > Entrada:     He got tired of his ass sitting
# > Referencia:  Xqʼiʼtaj ri rachaq che ri tʼuyalem
# --
# //
# > Entrada:     My back hurts because I'm crouching
# > Referencia:  Kʼax wij rumal in pachalik
# --
# //
# > Entrada:     I lay down to do my job
# > Referencia:  Kinchʼukiʼk chech ubʼanik nuchak
# --
# //
# > Entrada:     The basket weighs a lot
# > Referencia:  Al ri chakach
# --
# //
# > Entrada:     The whistleblower recognized the thief
# > Referencia:  Ri tzujunel xuchʼobʼ uwach ri elaqʼom
# --
# //
# > Entrada:     There's still a leftover
# > Referencia:  Xkanaj na kanoq ri chʼaqaʼp
# --
# //
# > Entrada:     Dry fish is very salty
# > Referencia:  Ri chaqiʼj kar sibʼalaj ratzʼamil
# --
# //
# > Entrada:     In the community of Panimaché lives Don Pedro Tz'alam
# > Referencia:  Luʼ Tzʼalam ubʼiʼ ri achi kel Pa nim Cheʼ
# --
# //
# > Entrada:     About the petate on the brink of fire
# > Referencia:  Chaqibʼisaj ri sepalibʼal chi uchiʼ ri qʼaqʼ
# --
# //
# > Entrada:     When I travel to other places I have to pay for accommodation
# > Referencia:  Are chiʼ kinbʼek pa jun tinamit chik kintoj ri nuwarbʼal ja
# --
# //
# > Entrada:     Leave it like that, that's enough
# > Referencia:  Chyaʼ kan je laʼ, rukʼ laʼ
# --
# //
# > Entrada:     We know that food sustains us
# > Referencia:  Qetaʼm che ri qawa kujutoʼo
# --
# //
# > Entrada:     Pascuala is the housekeeper at her grandfather's house
# > Referencia:  Suʼnel pa ri rachoch ri umam, Kwal
# --
# //
# > Entrada:     It's very important to disclose all agreements
# > Referencia:  Rajawaxik kajubʼux ronojel ri taqanik
# --
# //
# > Entrada:     We were talking when we saw the fire vibration
# > Referencia:  Tajin kujtzijon are chi xqil jun ubʼirowem
# --
# //
# > Entrada:     In our village still practice orders
# > Referencia:  Kkoj na ri tzʼonoj qukʼ pa ri qatinamit
# --
# //
# > Entrada:     The thread is added
# > Referencia:  Tiqatal ri bʼatzʼ
# --
# //
# > Entrada:     They let the sheep go
# > Referencia:  Xetzoqpitaj ri chij
# --
# //
# > Entrada:     White pine leaves are short
# > Referencia:  Ri uxaq ri paʼchaj e koʼlik
# --
# //
# > Entrada:     I'm afraid of the tiger
# > Referencia:  Kinxeʼj wibʼ chech ri bʼalam
# --
# //
# > Entrada:     They left a while ago
# > Referencia:  Joqʼtaj xebʼe bʼik
# --
# //
# > Entrada:     I planted salted corn, this year
# > Referencia:  Xintik saqpoʼr ixim che we junabʼ
# --
# //
# > Entrada:     The bread costs a quetzal
# > Referencia:  Jun qʼuʼq rajil ri kaxlaʼn wa
# --
# //
# > Entrada:     Sunday is from a place called Chojojche'
# > Referencia:  Ajchojojcheʼ ri a Kuʼ
# --
# //
# > Entrada:     Cows like to be in the swamp
# > Referencia:  Utz kkinaʼ ri wakax kekʼojiʼ pa ri suq
# --
# //
# > Entrada:     The lady's belt is loose
# > Referencia:  Choʼl ri upas ri ixoq
# --
# //
# > Entrada:     The lightning scares me so much
# > Referencia:  Kinxeʼj wibʼ che ri kaypaʼ
# --
# //
# > Entrada:     The baby is white tethel
# > Referencia:  Saq utzʼumal ri neʼ
# --
# //
# > Entrada:     I'm going to stick the beans
# > Referencia:  Kinchaʼ uwach le kinaqʼ
# --
# //
# > Entrada:     Inside the troje is mouse dung
# > Referencia:  Chi upam ri kʼuja kʼo kachaq chʼo
# --
# //
# > Entrada:     The tips of the milpa are cut off
# > Referencia:  Setom ri uwiʼ ri abʼix
# --
# //
# > Entrada:     I had nightmares last night
# > Referencia:  Chaqʼabʼ xinwachikʼaj jun itzel achikʼ
# --
# //
# > Entrada:     The girl's cut is tight
# > Referencia:  Titzʼ ruq le ali
# --
# //
# > Entrada:     The lamb is black
# > Referencia:  Qʼeq rij ri amaʼ chij
# --
# //
# > Entrada:     The price of the dog is one hundred and sixty quetzal
# > Referencia:  Ri rajilal ri tzʼiʼ areʼ wajxaqkʼal
# --
# //
# > Entrada:     They're the same age
# > Referencia:  Junam kijunabʼ
# --
# //
# > Entrada:     The highest authority is the United Nations
# > Referencia:  Ri nim qʼatbʼal tzij areʼ ri Junamil Amaqʼ
# --
# //
# > Entrada:     With the fruit of the sauce, they make jelly
# > Referencia:  Rukʼ ri uwach ri tzʼaloj kbʼan ri kabʼ
# --
# //
# > Entrada:     Many people claim to have seen the whistling lizard
# > Referencia:  Kʼi winaq kibʼim che ri witzitzil kilom uwach
# --
# //
# > Entrada:     The door is torn to pieces
# > Referencia:  Muchum ubʼanom kanoq ri uchiʼ ja
# --
# //
# > Entrada:     The Zopilot eats a dead dog
# > Referencia:  Kutij kamanaq tzʼiʼ ri kʼuch
# --
# //
# > Entrada:     Catalina has a newborn
# > Referencia:  Kʼo ulochʼ ri Talin
# --
# //
# > Entrada:     The fire of corn is black
# > Referencia:  Qʼeq ri chʼajachʼ
# --
# //
# > Entrada:     Now I have company
# > Referencia:  Kʼo chi wachiʼl chanim
# --
# //
# > Entrada:     It was decided what to do with Dona Rosa
# > Referencia:  26 Xchomataj jas kbʼan rukʼ ri nan Roʼs
# --
# //
# > Entrada:     The wildcat is looking for chickens behind the house
# > Referencia:  Ri yak kutzukuj akʼ chi rij taq ja
# --
# //
# > Entrada:     The worm is eating the corn seed
# > Referencia:  Ri xjut kutij rijaʼ abʼix
# --
# //
# > Entrada:     What's up?  The daughter-in-law works
# > Referencia:  Kachakun ri alibʼatz
# --
# //
# > Entrada:     I've got my necklace on
# > Referencia:  Nukojom nuchachal
# --
# //
# > Entrada:     Three years ago my father was alive
# > Referencia:  Jetaq waʼ oxbʼir kʼasal na ri nutat
# --
# //
# > Entrada:     Juan is getting old
# > Referencia:  Tajin krijobʼ, ri Xwan
# --
# //
# > Entrada:     Diego hugs the boy
# > Referencia:  Umatzem ri akʼal ri Teʼk
# --
# //
# > Entrada:     Our village is small in geographical extent
# > Referencia:  Ri qatinamit laj unimal rulewal
# --
# //
# > Entrada:     The blood from his nose clotted
# > Referencia:  Tʼorotʼik ubʼanom ri kikʼ xel pa utzaʼm
# --
# //
# > Entrada:     My daughter is 18
# > Referencia:  Wajxaqlajuj ujunabʼ ri numiʼal
# --
# //
# > Entrada:     They invited Peter to the talk.
# > Referencia:  Ri a Luʼ xsikʼital che le tzijonik
# --
# //
# > Entrada:     You take care of yourself on the road, because it's slippery
# > Referencia:  Kachajij awibʼ rumal che kapilil ri bʼe
# --
# //
# > Entrada:     The egg yolk is yellow
# > Referencia:  Qʼan ri uqʼanal ri saqmoʼl
# --
# //
# > Entrada:     I'm gonna charge the gentleman the money he owes me
# > Referencia:  Kinbʼe che utoqʼixik ri nurajil che ri achi
# --
# //
# > Entrada:     We are multilingual because there are 24 languages
# > Referencia:  Uj ukʼiyal tzijobʼal rumal kʼo juwinaq kajibʼ chʼabʼal
# --
# //
# > Entrada:     Chepito is in first grade elementary school
# > Referencia:  Ri alaj a Xep kʼo pa ri nabʼe tijonem
# --
# //
# > Entrada:     Our task is done
# > Referencia:  Xkʼis kanoq ri qachak
# --
# //
# > Entrada:     My sister flew
# > Referencia:  Pa jun roplan xebʼe wi ri wanabʼ
# --
# //
# > Entrada:     The man had to use the hook to fish
# > Referencia:  Ri achi xukoj ri chapabʼal kar chech kichapik kar
# --
# //
# > Entrada:     Juan is a public servant, on holidays he doesn't work
# > Referencia:  Ajchak chiwachil ri Xwan, pa taq ri nimaqʼij man kchukun taj
# --
# //
# > Entrada:     My partner speaks Awakateko
# > Referencia:  Ri wachiʼl kachʼaw pa ri Awakateko
# --
# //
# > Entrada:     The bite of an alacrane kills the person
# > Referencia:  Ri utyobʼal jun ixtexik kukamasaj ri winaqʼ
# --
# //
# > Entrada:     I like to suck all the honey
# > Referencia:  Kintzʼubʼ ronojel ri kabʼ rumal che utz kinaʼo
# --
# //
# > Entrada:     Human rights are for everyone
# > Referencia:  Yaʼtal chech winaq, kech ri konojel
# --
# //
# > Entrada:     I bought a house in the colony
# > Referencia:  Xinloqʼ jun ja pa ri wokaj ja
# --
# //
# > Entrada:     They solve my problem
# > Referencia:  Kikolomaj nukʼaxkʼol
# --
# //
# > Entrada:     The lion ate two deer
# > Referencia:  Kebʼ kej xutij ri koj
# --
# //
# > Entrada:     His arm hair burned, by the fire
# > Referencia:  Xkʼat rismal uqʼabʼ rumal le qʼaqʼ
# --
# //
# > Entrada:     The horn that's on the wood, bit me
# > Referencia:  Xinutiʼ jun kumatz kʼo pa ri siʼ
# --
# //
# > Entrada:     I'll go with you every now and then
# > Referencia:  Junpa taq na kinbʼe iwukʼ
# --
# //
# > Entrada:     I had to find a servant for today
# > Referencia:  Xintzukuj na jun patanel kamik
# --
# //
# > Entrada:     The cricket sings at night behind the house
# > Referencia:  Ri xiʼl kbʼixon chaqʼabʼ chi rij ja
# --
# //
# > Entrada:     There are many animals in the countryside
# > Referencia:  E kʼo kʼi taq chikop chi uwach ri taqʼaj
# --
# //
# > Entrada:     We're offering rest to our family
# > Referencia:  Tajin qachiʼj uxlanem chi ke ri qachalal
# --
# //
# > Entrada:     My little brother is in fifth grade.
# > Referencia:  Ri nuchaqʼ kʼo pa uroʼ qʼatoj tijonik pa ri tijobʼal
# --
# //
# > Entrada:     The pipe has burst
# > Referencia:  Xtʼoqopin ri kʼam
# --
# //
# > Entrada:     I sent the warrant with the boy
# > Referencia:  Xintaq bʼik ri taqkil chech ri akʼal
# --
# //
# > Entrada:     The measuring instrument is used to measure things
# > Referencia:  Ri etanibʼal kapatanaj chech retaxik jastaq
# --
# //
# > Entrada:     I'm getting sick
# > Referencia:  Kʼo muluw kʼuʼx chi wech
# --
# //
# > Entrada:     Fifteenth place is for my son-in-law
# > Referencia:  Ri uroʼlajuj kʼolbʼal rech ri nujiʼ
# --
# //
# > Entrada:     Here's the cilantro
# > Referencia:  Chiʼ kʼo wi ri kulanto
# --
# //
# > Entrada:     The house is big
# > Referencia:  Nim ri ja
# --
# //
# > Entrada:     In the distance you can see it shining
# > Referencia:  Naj kiltaj wi, are che kchupchutik
# --
# //
# > Entrada:     I'm cooking the horse food
# > Referencia:  Tajin kinbʼan le rechaʼ kej
# --
# //
# > Entrada:     Crab's got the hard shell
# > Referencia:  Ko kikʼoʼxal ri top
# --
# //
# > Entrada:     The flower has rusted
# > Referencia:  Ri kotzʼiʼj xbʼulujik
# --
# //
# > Entrada:     The chair is paralyzed
# > Referencia:  Ri tem xchikopirik
# --
# //
# > Entrada:     When are we going to the party?
# > Referencia:  ¿Jampaʼ kujbʼe pa nimaqʼij?
# --
# //
# > Entrada:     The nance is sold for a hand in the market
# > Referencia:  Pa jujun loch kkʼayix wi tapaʼl pa ri kʼayibʼal
# --
# //
# > Entrada:     My sister is very selfish
# > Referencia:  Ri wanabʼ sibʼalaj kisiy
# --
# //
# > Entrada:     I scratched my knee
# > Referencia:  Xinqol ri nuchʼek
# --
# //
# > Entrada:     When I was in another country I saw a countryman
# > Referencia:  Are chiʼ xinkʼojiʼ pa jun amaqʼ chik xinwil uwach jun nuwinaqil
# --
# //
# > Entrada:     What are we gonna take for the walk?
# > Referencia:  ¿Sutaq le kqam bʼik pa bʼinem?
# --
# //
# > Entrada:     The xara sings in the mornings
# > Referencia:  Ri xar kbʼixon uchiʼ aqʼabʼ
# --
# //
# > Entrada:     My mom went to the market
# > Referencia:  Ri nunan xbʼe pa kʼaybʼal
# --
# //
# > Entrada:     You got a bump in your neck
# > Referencia:  Kʼo jun pukpik chi aqul
# --
# //
# > Entrada:     The shadow protects me
# > Referencia:  Kinuchʼuq ri muʼj
# --
# //
# > Entrada:     Miguel is a good person
# > Referencia:  Sibʼalaj utz winaq ri Kel
# --
# //
# > Entrada:     The seed we sowed yesterday was selected
# > Referencia:  Cha´tal ri ijaʼ xqatik iwir
# --
# //
# > Entrada:     My wife is respectful
# > Referencia:  Ajtaqal tzij ri wachalkaʼn
# --
# //
# > Entrada:     The drill bit is working
# > Referencia:  Ri mesonel tajin kchakunik
# --
# //
# > Entrada:     Jose is jakalteko
# > Referencia:  37 Aj-jakalteko ri Xep
# --
# //
# > Entrada:     We are Maya
# > Referencia:  Uj mayabʼ
# --
# //
# > Entrada:     The corn is watered
# > Referencia:  Kirinaq ri ixim
# --
# //
# > Entrada:     In our language there are many fables
# > Referencia:  Pa qatzij kʼo kʼi kʼasubʼal naʼoj
# --
# //
# > Entrada:     Cattle leather is hard
# > Referencia:  Ko ri utzʼum awaj
# --
# //
# > Entrada:     They didn't inherit it
# > Referencia:  Man kʼo taj rechbʼal xyaʼik
# --
# //
# > Entrada:     The horse is not gentle
# > Referencia:  Man mekʼ taj ri kej
# --
# //
# > Entrada:     They mowed my beans
# > Referencia:  Xkeʼx ri nukinaqʼ
# --
# //
# > Entrada:     The hardwood is ripening
# > Referencia:  Kqʼanar ri tikoʼn
# --
# //
# > Entrada:     Geranium has a pleasant scent
# > Referencia:  Jeʼlik ukʼokʼal ri chʼoʼx
# --
# //
# > Entrada:     What's up? My mom's gone the other way.
# > Referencia:  Bʼenaq chʼaqap ri nuchuch
# --
# //
# > Entrada:     The master writes poems well
# > Referencia:  Utz kubʼan che utzʼibʼaxik nabʼalil ri ajtij
# --
# //
# > Entrada:     If you want my help just tell me
# > Referencia:  We kawaj katintoʼo xaq xu wi kabʼij chi we
# --
# //
# > Entrada:     Pay back your loan
# > Referencia:  Chtzelej ri aqajom
# --
# //
# > Entrada:     The corn tortilla is soft
# > Referencia:  Chʼuʼchʼuj ri lej rech ixim
# --
# //
# > Entrada:     I sell kittens
# > Referencia:  Kinkʼayij ri alaj taq sya
# --
# //
# > Entrada:     The whole family plays
# > Referencia:  Konojel ri alaxik keʼetzʼanik
# --
# //
# > Entrada:     Mary is at the basic level
# > Referencia:  Ri ali Mariʼy kʼo pa kaqʼat tijonik
# --
# //
# > Entrada:     The girl couldn't stand her husband and went home
# > Referencia:  Ri ali man xuqʼiy taj rukʼ ri rachijil, xtzalij pa rachoch
# --
# //
# > Entrada:     The dog's leg is bleeding
# > Referencia:  Tajin kel ukikʼel pa raqan ri tzʼiʼ
# --
# //
# > Entrada:     The Public Prosecutor's Office is in town
# > Referencia:  Ri Qʼatbʼal tzij Tinamital kʼo pa tinamit
# --
# //
# > Entrada:     With you, it's who I want to marry
# > Referencia:  Awukʼ kwaj kinkʼuliʼ wi
# --
# //
# > Entrada:     Women sew on the petate
# > Referencia:  Ketʼisoʼman pa uwiʼ ri pop, ri ixoqibʼ
# --
# //
# > Entrada:     Now they don't use the boxes anymore
# > Referencia:  Kamik man kakoj ta chik ri lej xajabʼ
# --
# //
# > Entrada:     There's not much literature
# > Referencia:  Man e kʼi taj ri naʼoj tzʼibʼ
# --
# //
# > Entrada:     Chicken fat is thick
# > Referencia:  Tzatz ri uqʼanil ri akʼ
# --
# //
# > Entrada:     I have three turtles
# > Referencia:  Kʼo oxibʼ nukok
# --
# //
# > Entrada:     Whatc I worked with my grandfather
# > Referencia:  Xinchakun rukʼ ri numam
# --
# //
# > Entrada:     Better save your money
# > Referencia:  Utz we kakʼol ri arajil
# --
# //
# > Entrada:     I dreamed
# > Referencia:  Xinachikʼnik
# --
# //
# > Entrada:     The jacket is lying on the ground
# > Referencia:  Laqʼbʼam kanoq ri kʼul chi uwach ulew
# --
# //
# > Entrada:     Whatc They've financed the men
# > Referencia:  Ri achijabʼ kʼo kipwaqim yaʼo m chi ke
# --
# //
# > Entrada:     Tom highlighted the bull today
# > Referencia:  Ri Max xupil ri uwakax kamik
# --
# //
# > Entrada:     It's pretty stagnant water
# > Referencia:  Sibʼalaj nim ri jaʼ chemalik
# --
# //
# > Entrada:     The Itza' language is spoken in a part of Petén
# > Referencia:  Ri tzijobal Itzaʼ kkikoj nikʼaj pa ri tinamit Petén
# --
# //
# > Entrada:     Toast is rich in salt water
# > Referencia:  Ri wotzʼotz jeʼlik katijow rukʼ ri uwaʼl saqpoʼr
# --
# //
# > Entrada:     The kid cats
# > Referencia:  Ri akʼal kchakanik
# --
# //
# > Entrada:     My grandfather died when I was ninety
# > Referencia:  Ri numam xkamik are taq kʼo jumuchʼ lajuj ujunabʼ
# --
# //
# > Entrada:     Let's buy our shoes at the shoe store
# > Referencia:  Kqaloqʼ ri qaxajabʼ pa kʼayibʼal xajabʼ
# --
# //
# > Entrada:     The boy pinches his little brother
# > Referencia:  Ri akʼal kuxetʼ ri uchaqʼ
# --
# //
# > Entrada:     Mr. Apollonius has grown old
# > Referencia:  Xrijobʼ ri tat Naʼy
# --
# //
# > Entrada:     The pink hen eats the egg she laid
# > Referencia:  Ri xeʼp akʼ kutij ri usaqmoʼl
# --
# //
# > Entrada:     What  The kids look alike
# > Referencia:  Kejunamataj ri akʼalabʼ
# --
# //
# > Entrada:     Today I start working
# > Referencia:  Kamik kinmajij bʼik ri nuchak
# --
# //
# > Entrada:     The lightning is shining
# > Referencia:  Kajuluw ri kuypaʼ
# --
# //
# > Entrada:     The cocoon is coming out
# > Referencia:  Ri xqʼel tajin kel bʼik
# --
# //
# > Entrada:     The guardian takes care of people
# > Referencia:  Kerilij winaq ri chajinel
# --
# //
# > Entrada:     What  Lucia is an aviator
# > Referencia:  Ajxik chʼichʼ ri Luʼs
# --
# //
# > Entrada:     What's up?  Your son is too tall
# > Referencia:  Takʼatik ri akʼojol
# --
# //
# > Entrada:     There are many networks
# > Referencia:  E kʼi ri kʼat kʼolik
# --
# //
# > Entrada:     If you follow the advice of the elders you're wise
# > Referencia:  At ajnoʼj we kataqej kitzij ri tataʼibʼ
# --
# //
# > Entrada:     The kid's stuck
# > Referencia:  Ri akʼal jupulik
# --
# //
# > Entrada:     Now the tomato is expensive
# > Referencia:  Paqal rajil le pix kamik
# --
# //
# > Entrada:     The coals are off
# > Referencia:  Ri rachaq qʼaq xchupik
# --
# //
# > Entrada:     The burner burned the milp's reed
# > Referencia:  Ri tʼiqonel xukʼat bʼi ri patzʼan
# --
# //
# > Entrada:     The waiter does his job
# > Referencia:  Kubʼan uchak ri jachal wa
# --
# //
# > Entrada:     The hardwood is blooming
# > Referencia:  Kasiʼjan ri turaʼs
# --
# //
# > Entrada:     Diego is a sailor
# > Referencia:  Ajqʼojom ri a Te´k
# --
# //
# > Entrada:     The young man speaks the Q'anjob'al language
# > Referencia:  Qʼanjobʼal are utzij ri ala
# --
# //
# > Entrada:     Tomasa Tax is the lady who sells atolls on Saturdays
# > Referencia:  Xiʼn Tax, ubʼiʼ ri ixoq kukʼayij jochʼ pa taq saqʼij
# --
# //
# > Entrada:     Jerónimo is a proper name
# > Referencia:  Xroʼm areʼ jun tukelal bʼiʼaj
# --
# //
# > Entrada:     The roast mushroom is tasty
# > Referencia:  Jeʼlik ri qʼoʼtz are chiʼ kabʼolik
# --
# //
# > Entrada:     I left the whole milpa unattended
# > Referencia:  Xintʼul kanoq ronojel le abʼix
# --
# //
# > Entrada:     My brother bought land
# > Referencia:  Ri wachalal xuloqʼ ulew
# --
# //
# > Entrada:     The wood burns in the fire
# > Referencia:  Kkʼat ri siʼ pa ri qʼaqʼ
# --
# //
# > Entrada:     I bought Anastasia a hundred and forty sugar cane
# > Referencia:  Xinloq wuqkʼal ajij che ri Tax
# --
# //
# > Entrada:     The dog is hairy
# > Referencia:  Paʼtz rij ri tzʼiʼ
# --
# //
# > Entrada:     What's my cat female
# > Referencia:  Atiʼt ri nusya
# --
# //
# > Entrada:     Utatlan is the capital of the village
# > Referencia:  Ri Qʼumaʼrkaj are ujolom qatinamit
# --
# //
# > Entrada:     The creek is clean
# > Referencia:  Sibʼalaj chʼajchʼoj ri bʼinel jaʼ
# --
# //
# > Entrada:     They're chasing the man
# > Referencia:  Tajin katerneʼx ri achi
# --
# //
# > Entrada:     Today is 1 Kan according to the Mayan calendar
# > Referencia:  Kamik jun Kan pa ri mayabʼ Cholbʼal qʼij
# --
# //
# > Entrada:     The air ripped the big tree
# > Referencia:  Xbʼoqotaj bʼik ri nim cheʼ rumal ri kaqiqʼ
# --
# //
# > Entrada:     What  My mom brought you the talpetate
# > Referencia:  Ri xaq xukʼam loq ri nunan awukʼ
# --
# //
# > Entrada:     Sebastian's belt is embroidered
# > Referencia:  Qʼoʼm ri upas ri Poʼx
# --
# //
# > Entrada:     How much does the pot cost?
# > Referencia:  ¿Jampaʼ rajil le tʼuʼyʼ?
# --
# //
# > Entrada:     What's your bar  It's old
# > Referencia:  Qʼeʼl chik ri apachʼubʼal
# --
# //
# > Entrada:     What  Rose bursts a lot
# > Referencia:  Ri Roʼs Sibʼalaj kpolajik
# --
# //
# > Entrada:     Whatc I have smallpox
# > Referencia:  Kʼo loqʼojbʼal chi wech
# --
# //
# > Entrada:     I climbed to the top of the tree
# > Referencia:  Xinbʼan ri aqʼanem pa uwiʼ ri cheʼ
# --
# //
# > Entrada:     The medicine is in liquid state
# > Referencia:  kariqitaj pa ri ja uwach ri kunabʼal
# --
# //
# > Entrada:     My cat is pink
# > Referencia:  Xoloʼp rij ri numeʼs
# --
# //
# > Entrada:     whatc Did you mix the yeast with the flour?
# > Referencia:  ¿Xayujaʼj ri chʼam rukʼ ri kʼaj?
# --
# //
# > Entrada:     The secretary got stained by the leaves
# > Referencia:  Xkitzʼilobʼisaj kanoq ri uwuj ri ajtzʼibʼ
# --
# //
# > Entrada:     What's up?  I got five thorny chickens
# > Referencia:  E kʼo jobʼ chʼil wakʼ
# --
# //
# > Entrada:     Luis has his clothes packed
# > Referencia:  Ri Wix upatzom ronojel ri atzʼyaq
# --
# //
# > Entrada:     It's the eighth time I've told you it's not good for you to fight
# > Referencia:  Uwajxaq mul kinbʼij che man utz taj kichʼay iwibʼ
# --
# //
# > Entrada:     What's up?  Her beard is growing
# > Referencia:  Le rismachiʼ tajin kkʼiyik
# --
# //
# > Entrada:     On Easter, people make bread
# > Referencia:  Kkibʼan kaxlaʼn wa wa ri winaq pa awas qʼij
# --
# //
# > Entrada:     Juan is a volunteer firefighter
# > Referencia:  Ajchupul qʼaqʼ ri Xwan
# --
# //
# > Entrada:     What's up?  Joseph is a wizard
# > Referencia:  Ajitz ri Xep
# --
# //
# > Entrada:     They put a roadblock in the way
# > Referencia:  Xkoj jun qʼatbʼal che we bʼe
# --
# //
# > Entrada:     The moon is round
# > Referencia:  Ketekik ri ikʼ
# --
# //
# > Entrada:     Because how spicy dry chili is, it's harmful to health
# > Referencia:  Rumal upoqonal ri chaqiʼj ik kubʼan kʼax chech ri qachʼakul
# --
# //
# > Entrada:     What's up?  Tom's a dentist
# > Referencia:  Ajware ri Max
# --
# //
# > Entrada:     I bought this for you because I want you to use it
# > Referencia:  Xinloqʼ we riʼ xa kwaj kakojo
# --
# //
# > Entrada:     Don't be afraid of dogs
# > Referencia:  Ma xiʼj awibʼ chi kech ri tzʼiʼ
# --
# //
# > Entrada:     Broke my beard
# > Referencia:  Xqʼaj ri nujopijbʼal
# --
# //
# > Entrada:     I left the door locked
# > Referencia:  Xintokʼopij kanoq ri uchiʼ ja
# --
# //
# > Entrada:     What's your voice snoring
# > Referencia:  Jaʼs ri aqul
# --
# //
# > Entrada:     The house is half white
# > Referencia:  Saqsoj ukayibʼal ri ja
# --
# //
# > Entrada:     Antonia's pots were broken
# > Referencia:  Xkipaxij ri ubʼoʼj ri Toʼn
# --
# //
# > Entrada:     Cartridge at my expense
# > Referencia:  Kjaʼjat chi wij
# --
# //
# > Entrada:     Go call him to come and eat
# > Referencia:  Jasikʼij chech utijik uwa
# --
# //
# > Entrada:     The stars shine at night
# > Referencia:  Kajuluw ri chʼumil chaqʼabʼ
# --
# //
# > Entrada:     The cut is red
# > Referencia:  Kaqruʼch ukayibʼal ri uq
# --
# //
# > Entrada:     The young man honors his grandfather
# > Referencia:  Ri ala nim kril wi ri umam
# --
# //
# > Entrada:     What? Say it again
# > Referencia:  Chbʼij chik jumul
# --
# //
# > Entrada:     Many are the women who are widowed
# > Referencia:  E kʼi ri ixoqibʼ e kʼo pa ri malkaʼnil
# --
# //
# > Entrada:     Now corn is cheap
# > Referencia:  Ma paqal taj ri ixim kamik
# --
# //
# > Entrada:     The bark of the sauce is medicinal
# > Referencia:  Ri umeʼtal ri tzʼoloj cheʼ kkunanik
# --
# //
# > Entrada:     The stitch is wide
# > Referencia:  Nim uwach ri poʼt
# --
# //
# > Entrada:     whatc they're responding wrong
# > Referencia:  Itzel katkʼulaʼxik Te e
# --
# //
# > Entrada:     In the mountain there are many oak trees
# > Referencia:  Kʼo sibʼalaj bʼaqit chi uwach ri juyubʼ
# --
# //
# > Entrada:     In the next few days there will be vaccination
# > Referencia:  Pa taq ri qʼij petinaq kʼo ri toqʼoj
# --
# //
# > Entrada:     What  Rainbow appears when it rains
# > Referencia:  Ri raxkyaqʼabʼ kkʼojiʼk are chiʼ kʼo jabʼ
# --
# //
# > Entrada:     Doña Micaela has two children
# > Referencia:  Ri nan Keʼl kʼo kebʼ ral
# --
# //
# > Entrada:     Luis bought his luxury home
# > Referencia:  Ri a Wix xuloqʼ rachoch re nimal
# --
# //
# > Entrada:     What  I drew you
# > Referencia:  Xatinwachibʼej
# --
# //
# > Entrada:     The fire is cooking the corn
# > Referencia:  Ri qʼaqʼ tajin kuchaqʼajisaj ri ixim
# --
# //
# > Entrada:     Make three balls of flour
# > Referencia:  Chbʼana oxibʼ tʼoytʼik che le kʼaj
# --
# //
# > Entrada:     You must know where the mazorca is
# > Referencia:  Rajawaxik kawetaʼmaj pa kʼo wi ri mulibʼal jal
# --
# //
# > Entrada:     The woman is from Zacualpa
# > Referencia:  Ri ixoq are ajpanqʼaʼ
# --
# //
# > Entrada:     The little girl plays with the doll
# > Referencia:  Ketzʼan ri alaj ali rukʼ ri alaʼs
# --
# //
# > Entrada:     We use the flowers inside the house
# > Referencia:  Ri kotzʼiʼj kqakoj chi upam ri ja
# --
# //
# > Entrada:     The boa snake is poisonous
# > Referencia:  Kkamsan ri kumatz chiwekox
# --
# //
# > Entrada:     Sebastian's son is deaf
# > Referencia:  Soʼr le ral ri ali Poʼx
# --
# //
# > Entrada:     I want to marry Lucia
# > Referencia:  Kwaj kinkʼuliʼ rukʼ ri Luʼs
# --
# //
# > Entrada:     How is Pedro?
# > Referencia:  ¿Jachaʼ a Luʼ?
# --
# //
# > Entrada:     Tomorrow I'm going to the capital
# > Referencia:  Chweʼq kinbʼe pa nim tinamit
# --
# //
# > Entrada:     Francis pretends to be inept
# > Referencia:  Tʼoʼy kukoj ribʼ ri a Siʼs
# --
# //
# > Entrada:     Don Diego is known
# > Referencia:  Etaʼmatal uwach ri tat Teʼk
# --
# //
# > Entrada:     People have organized their board of directors
# > Referencia:  Kiwokom e kʼamal taq kibʼe, ri winaq
# --
# //
# > Entrada:     The white dress is very delicate
# > Referencia:  Ri saq atzʼiyaq sibʼalaj nichʼ
# --
# //
# > Entrada:     The flowers are different colors
# > Referencia:  Jalajoj ukaʼyibʼal ri kotzʼiʼj
# --
# //
# > Entrada:     What  The young man inspires good poems
# > Referencia:  Utz kabʼanow nabʼalil ri ala
# --
# //
# > Entrada:     The dog got kicked out
# > Referencia:  Xkotiʼ ri tzʼiʼ
# --
# //
# > Entrada:     Some women's lips are painted
# > Referencia:  Jujun taq chiʼaj kech ixoqibʼ e tzʼajtalik
# --
# //
# > Entrada:     The pig is already too fat
# > Referencia:  Jusanaj chik ri aq
# --
# //
# > Entrada:     Before, the beetle was used to wash clothes
# > Referencia:  Ojer kkoj ri ratzʼiʼ che le chʼajoʼn
# --
# //
# > Entrada:     Diego is a cop
# > Referencia:  Chajil tinamit ri a Teʼk
# --
# //
# > Entrada:     The horse is gray
# > Referencia:  Saqmaqmoj rij le kej
# --
# //
# > Entrada:     All things went up in price
# > Referencia:  Xpaqiʼ rajil ronojel ri jastaq
# --
# //
# > Entrada:     When I have a period, my head hurts, says the young lady.
# > Referencia:  Are chiʼ kʼo ri retal ikʼ kqʼaxow nujolom, kchaʼ ri aliʼ
# --
# //
# > Entrada:     How much is it in total?
# > Referencia:  ¿Jumpaʼ le utzʼaqatil?
# --
# //
# > Entrada:     I hurt myself while shaving
# > Referencia:  Xinsok wibʼ are chi tajin kinsokaj ri wismachiʼ
# --
# //
# > Entrada:     The bird is on the canopy
# > Referencia:  Kʼo ri chʼip pa uwiʼ ri xot
# --
# //
# > Entrada:     I'm part of a vegetable cooperative
# > Referencia:  In kʼo chi upam ri komon rech ichaj
# --
# //
# > Entrada:     I took three pickles of atole
# > Referencia:  Xinqʼumuj oxibʼ mulul rukʼ qʼor
# --
# //
# > Entrada:     My mom takes a thick atoll
# > Referencia:  Tzatz jochʼ kuqamuj ri nunan
# --
# //
# > Entrada:     I have enemies
# > Referencia:  Kʼo nukʼulel
# --
# //
# > Entrada:     Mrs. Teresa uses the spoon to serve the food
# > Referencia:  Ri chuchuʼ Tereʼs kukoj ri pakʼ che upakʼexik ri rikil
# --
# //
# > Entrada:     The horse is thrown out because it's full
# > Referencia:  Ri kej ponol rumal nojinaq chik
# --
# //
# > Entrada:     I offer my blood to the patient for transfusion
# > Referencia:  Kintzuj ri nukikʼel che ri yawabʼ rech koksax chech
# --
# //
# > Entrada:     The garbage can't be filled
# > Referencia:  Nojinaq ri kʼolibʼal mes
# --
# //
# > Entrada:     Your clothes are very aromatic
# > Referencia:  Sibʼalaj kʼokʼ ri awatzʼyaq
# --
# //
# > Entrada:     The rabbit is double vision
# > Referencia:  Ilokabʼ ri imul
# --
# //
# > Entrada:     My neighbor lends money
# > Referencia:  Ri nukʼulbʼaʼt kuqaj pwaq
# --
# //
# > Entrada:     Some names are derived from gentile
# > Referencia:  Kʼo taq jujun bʼiʼaj elenaq chi upam ri uwinaqil juyubʼal
# --
# //
# > Entrada:     The disabled woman does her homework with her feet
# > Referencia:  Kubʼan ri uchak ri tʼun ali rukʼ raqan
# --
# //
# > Entrada:     I won't go home today
# > Referencia:  Kamik man kinbʼe ta chi uwach ri ja
# --
# //
# > Entrada:     Diego is a server
# > Referencia:  Ajpatan ri Teʼk
# --
# //
# > Entrada:     What  You come this way
# > Referencia:  Katpe je waʼ
# --
# //
# > Entrada:     The banana is rotten
# > Referencia:  Qʼayinaq ri ankaneʼy
# --
# //
# > Entrada:     My saliva carries disease
# > Referencia:  Ri nuchubʼ rukʼaʼm yabʼil
# --
# //
# > Entrada:     I order the papers I'm writing
# > Referencia:  Kinchololej ri wuj kintzʼibʼaj
# --
# //
# > Entrada:     I broke my spine
# > Referencia:  Xinqʼij ri usunal wuj
# --
# //
# > Entrada:     Feliciana is from Cantel
# > Referencia:  Ri ali chana are ajqʼanteʼl
# --
# //
# > Entrada:     We need to enrich our lexicon
# > Referencia:  Che rajawaxik wi keqtaʼmaj taq tzij
# --
# //
# > Entrada:     You'll be your brother's guarantor
# > Referencia:  Katchʼaw chi rij awachalal
# --
# //
# > Entrada:     I bought a new mecapal
# > Referencia:  Xinloqʼ jun kʼakʼ patan
# --
# //
# > Entrada:     We're going to subtract it
# > Referencia:  Kqabʼan ri esanem che
# --
# //
# > Entrada:     The car salesman is angry
# > Referencia:  Kʼaʼn ri kʼayinel chʼichʼ
# --
# //
# > Entrada:     Tomorrow we'll go to the hill to present an offering
# > Referencia:  Chweʼq kubʼe pa juyubʼ che uyaʼik jun qatojnik
# --
# //
# > Entrada:     The peacock was pulled off the ground
# > Referencia:  Xipichiʼ kanoq ri kʼim chi uwach ri ulew
# --
# //
# > Entrada:     Your car is new
# > Referencia:  Kʼakʼ ri achʼichʼ
# --
# //
# > Entrada:     When summer starts the bees come out
# > Referencia:  Ri wonon kel bʼik are taq kumajij ri saqʼij
# --
# //
# > Entrada:     What  Man heals
# > Referencia:  Kkunan ri achi
# --
# //
# > Entrada:     The shape of the house was fine
# > Referencia:  Ri ubʼanik ri ja utz xelik
# --
# //
# > Entrada:     Ixchel takes medicine three times a day
# > Referencia:  Oxmul kuqumuj ukunabʼal ri Ixchel pa ri qʼij
# --
# //
# > Entrada:     The cod meat is nice
# > Referencia:  Jeʼlik utiʼjolal ri saqkoʼr
# --
# //
# > Entrada:     The weaver has a lot of work to do
# > Referencia:  Kʼo sibʼalaj uchak ri ajkem
# --
# //
# > Entrada:     There's plenty of fish in the lagoon
# > Referencia:  Kʼo sibʼalaj kar pa ri cho
# --
# //
# > Entrada:     They cut the cherry branches off
# > Referencia:  Xtʼoy kanoq ri uqʼabʼ ri kʼixkʼobʼal
# --
# //
# > Entrada:     We've suffered a lot from the slaughter of past years
# > Referencia:  Ri kamisanem xbʼantaj ojer, kʼax xubʼan chi qech
# --
# //
# > Entrada:     There's a lot of overlap in the rug
# > Referencia:  Kʼo sibʼalaj pichʼoʼl xkanaj kanoq
# --
# //
# > Entrada:     What  Men look after each other
# > Referencia:  Kkichajij chikibʼil kibʼ ri achijabʼ
# --
# //
# > Entrada:     There's money on the table
# > Referencia:  Kʼo pwaq pa uwiʼ ri mexa
# --
# //
# > Entrada:     The water well is ancient
# > Referencia:  Ojer chik ri ukʼyaʼbʼal
# --
# //
# > Entrada:     The fish is exquisite
# > Referencia:  Jeʼl ktijow ri kar
# --
# //
# > Entrada:     The pomegranate is found in the rivers
# > Referencia:  Ri saqkowin kraqitaj pa taq ri nimaʼ
# --
# //
# > Entrada:     The charger that Lucia made is so pretty
# > Referencia:  Sibʼalaj jeʼlik ri eqabʼal xubʼan ri Luʼs
# --
# //
# > Entrada:     The wall's already cracked
# > Referencia:  Ri xan paqʼinaq chik
# --
# //
# > Entrada:     She likes to hear the music of the marimba
# > Referencia:  Jeʼl kuto ubʼix ri qʼojom
# --
# //
# > Entrada:     Gaspar is very wasteful
# > Referencia:  68 Ri Pal sibʼalaj saqʼor
# --
# //
# > Entrada:     Did you read what the writer said in the paper?
# > Referencia:  ¿La xasikʼij uwach ri xutzʼibʼaj ri tzʼibʼanel pa ri wuj?
# --
# //
# > Entrada:     The door is half open
# > Referencia:  Jeqal jubʼiqʼ ri uchi ja
# --
# //
# > Entrada:     It'll stretch the edge of the coast further
# > Referencia:  Sibʼalaj chayuquʼ ri uchiʼ ri koxtar
# --
# //
# > Entrada:     Each of us has our own story
# > Referencia:  Chqajujunal kʼo qatzijom tzij
# --
# //
# > Entrada:     The chickens are eleven
# > Referencia:  E julajuj ri akʼ
# --
# //
# > Entrada:     It's not like that, like I said
# > Referencia:  Man jeʼ taj pa chaʼ xinbʼij
# --
# //
# > Entrada:     In the ancient municipalities only the elders were in charge
# > Referencia:  Pa ojer qʼalpul xaq xu wi ri nim winaq kekʼamow bʼe
# --
# //
# > Entrada:     Whatc You're buying a dozen eggs
# > Referencia:  Kaloqʼ loq kabʼlajunal saqmoʼl
# --
# //
# > Entrada:     The turkey is really big
# > Referencia:  Sibʼalaj nim ri noʼs
# --
# //
# > Entrada:     Whatc My neighbor is a sorcerer
# > Referencia:  Ri nukʼul ja ajitz
# --
# //
# > Entrada:     It's better if I understand the meaning of the Calendar
# > Referencia:  Utz we kiwetaʼmaj jas kubʼij ri cholbʼal qʼij
# --
# //
# > Entrada:     The honey from the pan is sweet
# > Referencia:  Kiʼ ri ukabʼ ri aqaj
# --
# //
# > Entrada:     He held the stick with his hands for a long time
# > Referencia:  Naj xulotʼej ri cheʼ, rukʼ ri uqʼabʼ
# --
# //
# > Entrada:     The lightning struck the man
# > Referencia:  Xqaj chi rij ri achi ri kaqulja
# --
# //
# > Entrada:     We must respect sacred food
# > Referencia:  Rajwaxik qayaʼ uqʼij ri loqʼlaj wa ukʼya
# --
# //
# > Entrada:     We had to disarm the lady's post
# > Referencia:  Xeqator ronojel ri ukʼolbʼal ri chuchuʼ
# --
# //
# > Entrada:     Have you eaten the white fish?
# > Referencia:  ¿La atijom ri saq kar?
# --
# //
# > Entrada:     The vegetable saleswoman is from Quetzaltenango
# > Referencia:  Ajxeʼlajuj Noʼj ajkʼayel rech ichaj
# --
# //
# > Entrada:     The currency is losing its value
# > Referencia:  Tajin ktzaq rajil ri chʼichʼ pwaq
# --
# //
# > Entrada:     Man runs on the road
# > Referencia:  Kutoqʼolaʼ anim ri achi pa ri nim bʼe
# --
# //
# > Entrada:     The hill is far away
# > Referencia:  Naj kʼo wi ri juyubʼ
# --
# //
# > Entrada:     The seeds are big
# > Referencia:  Chomaʼqʼ ri ijaʼ
# --
# //
# > Entrada:     Next Tuesday I'll take you for a walk
# > Referencia:  Pa ri maqʼij katinkʼam bʼik pa waʼkatem
# --
# //
# > Entrada:     Man is a complainer
# > Referencia:  Ajchʼaʼoj ri jun achi
# --
# //
# > Entrada:     What  Nicholas' hat, it's big
# > Referencia:  Nim ri upwiʼri a Kulax
# --
# //
# > Entrada:     I'm going to get five shrimp
# > Referencia:  Kinbʼe na che kitzukaxik jobʼ erenel eqaʼn
# --
# //
# > Entrada:     Cut the grass with the scraper
# > Referencia:  Chjosoʼ le qʼayes rukʼ ri josbʼal
# --
# //
# > Entrada:     When water is poured over the fire, the steam comes out.
# > Referencia:  Chiʼ katix jaʼ pa uwiʼ ri qʼaqʼ kel loq ri bʼuquw
# --
# //
# > Entrada:     Mrs. Maria is sick
# > Referencia:  Yawabʼ ri chuchuʼ Liʼy
# --
# //
# > Entrada:     The bottle is used to store water
# > Referencia:  Kpatanaj che ukʼolik jaʼ ri limeʼt
# --
# //
# > Entrada:     The caller is Francis
# > Referencia:  Ri sikʼinel are ri a Siʼs
# --
# //
# > Entrada:     The chicken calls the chicken
# > Referencia:  Ri akʼ kusikʼij ri chʼiw
# --
# //
# > Entrada:     The chicken bites the rooster
# > Referencia:  Ri chʼaʼn kutzop ri amaʼ akʼ
# --
# //
# > Entrada:     For shame people don't eat
# > Referencia:  Rumal ri kʼix, man kewaʼ taj ri winaq
# --
# //
# > Entrada:     The repellent is falling
# > Referencia:  Tajin ktzaq le rij le xan
# --
# //
# > Entrada:     The cat has five children
# > Referencia:  E kʼo jobʼ ral ri meʼs
# --
# //
# > Entrada:     Fighters are known
# > Referencia:  Kchʼobʼotaj kiwach ri ajchʼojabʼ
# --
# //
# > Entrada:     I don't like the cool one
# > Referencia:  Man utz taj kinaʼ ri kaqʼ
# --
# //
# > Entrada:     The fox passed
# > Referencia:  Xqʼatan ri par
# --
# //
# > Entrada:     I'm used to starving
# > Referencia:  Kʼamanaq uraqik numik chi wech
# --
# //
# > Entrada:     The sawmills are ending the forest
# > Referencia:  Tajin kkʼis ri kʼichelaj ri ajtzʼalam
# --
# //
# > Entrada:     My clothes have ornaments like fleas
# > Referencia:  Chilchiʼx ubʼantajik ri retzʼabʼalil kʼo chech ri watzʼyaq
# --
# //
# > Entrada:     In the dining room there are 40 men
# > Referencia:  Pa ri waʼbʼal e kʼo kawinaq achijabʼ
# --
# //
# > Entrada:     Let another one pass
# > Referencia:  Kqʼax loq jun chik
# --
# //
# > Entrada:     It started to rain
# > Referencia:  Xumaj ri jabʼ
# --
# //
# > Entrada:     The ensign is very inflexible
# > Referencia:  Sibʼalaj achʼiʼy ri bʼaqit
# --
# //
# > Entrada:     The boy threw up his clothes on the bus
# > Referencia:  Ri akʼal xuxawaj ratzʼiyaq pa ri chʼichʼ
# --
# //
# > Entrada:     It's sold out
# > Referencia:  Xoltal uwach ri ukʼay
# --
# //
# > Entrada:     The instrument to hit stopped in front of the house
# > Referencia:  Kʼo kanoq ri potzʼbʼal chi uwach ri ja
# --
# //
# > Entrada:     Antonio has black hair
# > Referencia:  Qʼeq uwiʼ ri a Tun
# --
# //
# > Entrada:     We have four listeners to hear everything we say
# > Referencia:  Kʼo kajibʼ tatbʼanelabʼ che utaʼik ronojel le kqabʼij
# --
# //
# > Entrada:     The mecate serves to tie the ceiling of the galley
# > Referencia:  Ri chʼiyuʼt kapatnaj che uximik uwiʼ ri kabʼal
# --
# //
# > Entrada:     What time is it now?
# > Referencia:  Jas kajbʼal chanim?
# --
# //
# > Entrada:     The gentleman has his pipe
# > Referencia:  Ri tataʼ kʼo ri ukachiʼm
# --
# //
# > Entrada:     Women cut the meat for the wedding
# > Referencia:  Xkipus ri tiʼjʼri ixoqibʼ pa ri kʼulnem
# --
# //
# > Entrada:     The cow eats standing
# > Referencia:  Ri wakax chakal kwaʼik
# --
# //
# > Entrada:     We must practice brotherhood
# > Referencia:  Chqakʼaslemaj ri loqʼobʼal kʼuʼx
# --
# //
# > Entrada:     Rosa Pum, her name is a lady
# > Referencia:  Kʼo jun ixoq ubʼiʼ Roʼs Pum
# --
# //
# > Entrada:     The nixtamal was ground very rough
# > Referencia:  Chaqoj xbʼan chech ukeʼxik ri tzi
# --
# //
# > Entrada:     In the chicken's mouth are stones, corn and grass
# > Referencia:  Chi upam ri ubʼuch ri akʼ kʼo abʼaj, ixim chiʼl ri ichaj
# --
# //
# > Entrada:     I don't drink sugar because it's bad for me
# > Referencia:  Man kintij ta ri asukal rumal che kubʼan kʼax chi wech
# --
# //
# > Entrada:     You sleep on the couch
# > Referencia:  Katwar pa ri nimatem
# --
# //
# > Entrada:     There are no kings here anymore
# > Referencia:  Waral man kʼo taj Ajawal
# --
# //
# > Entrada:     The food carries a message in red
# > Referencia:  Kaq kkaʼy ri jokʼom rakʼam ri rikil
# --
# //
# > Entrada:     The authorities made a raid
# > Referencia:  Ri qʼatbʼal tzij xkaʼn jun eqelem pa ja
# --
# //
# > Entrada:     Semites are made of afrecho
# > Referencia:  Ri sameʼt kbʼan che le salwaʼt
# --
# //
# > Entrada:     Pass me the lick
# > Referencia:  Qʼaxaj loq ri kayebʼal chʼichʼ
# --
# //
# > Entrada:     A baby was born
# > Referencia:  64 Xalax jun neʼ
# --
# //
# > Entrada:     Marta seems to be a slut
# > Referencia:  Kujaluj kaxlaʼn ixoq ri Maʼt
# --
# //
# > Entrada:     I want my drink to be hot
# > Referencia:  Kʼatan kwaj ri wukʼyaʼ
# --
# //
# > Entrada:     What's up  The girl's chewing the flour
# > Referencia:  Kuchokonsabʼej kʼaj ri ali
# --
# //
# > Entrada:     You gotta sort the paper
# > Referencia:  Rajawaxik kcholisax ri wuj
# --
# //
# > Entrada:     We meet at the meetings
# > Referencia:  Kqariq qibʼ pa kʼulbʼal bʼe
# --
# //
# > Entrada:     What  You're my son
# > Referencia:  At nukʼojol
# --
# //
# > Entrada:     Andrés, walk with the hump
# > Referencia:  Kawuqʼnaj kbʼin ri a Triʼx
# --
# //
# > Entrada:     The sun is coming up
# > Referencia:  Tajin kel loq, ri qʼij
# --
# //
# > Entrada:     I'm going to swim
# > Referencia:  Kinbʼe pa muxanik
# --
# //
# > Entrada:     Some people already use pom
# > Referencia:  Kʼo jujun kkikoj chik ri pom
# --
# //
# > Entrada:     The sound of bombs scares me
# > Referencia:  Kinxiʼj wibʼ chech ri polajem
# --
# //
# > Entrada:     Tuberculosis gives warmth
# > Referencia:  Kuya qʼaqʼ ri chaqiʼj oj
# --
# //
# > Entrada:     The cherry tree died
# > Referencia:  Xkam ri kʼuxkʼabʼ
# --
# //
# > Entrada:     You mix corn with beans
# > Referencia:  Kayujaʼj ri ixim rukʼ ri kinaqʼ
# --
# //
# > Entrada:     Whatc The bat at night sucks the animal's blood
# > Referencia:  Ri sotzʼ kutij ukikʼel ri awaj chaqʼabʼ
# --
# //
# > Entrada:     The horn is in the hole
# > Referencia:  Kʼo pa ri jul ri kumatz
# --
# //
# > Entrada:     They left the adobe built
# > Referencia:  Tzʼaqom kanoq ri xan
# --
# //
# > Entrada:     Tektiteko is one of the Maya languages
# > Referencia:  Ri Tektiteko are jun chʼabʼal kech ri mayibʼ
# --
# //
# > Entrada:     My chair is made of mahogany
# > Referencia:  Ri nutem rech qʼancheʼ
# --
# //
# > Entrada:     Work at the market has been suspended
# > Referencia:  Xtanabʼax ri chak pa kʼayibʼal
# --
# //
# > Entrada:     You're an accountant
# > Referencia:  At jun kʼakʼalinik
# --
# //
# > Entrada:     People cut down many trees
# > Referencia:  Xekichoy Kʼi cheʼ ri winaq
# --
# //
# > Entrada:     Whatc Envy is a disease
# > Referencia:  Ri tiʼtotem areʼ jun yabʼil
# --
# //
# > Entrada:     The napkin I bought is brown
# > Referencia:  Kʼaqoʼj kkay ri suʼt xinloqʼo
# --
# //
# > Entrada:     The pencil the kids use is made of wood
# > Referencia:  Cheʼ tzʼibʼabʼal kkikoj ri akʼalabʼ
# --
# //
# > Entrada:     I'm gonna beat you to the tail
# > Referencia:  Katinchʼay rukʼ taq tʼokonik
# --
# //
# > Entrada:     I'll love you forever
# > Referencia:  Junalik katinloqʼaj
# --
# //
# > Entrada:     The mountain rat ate a lot of chilacayotes
# > Referencia:  Kʼi qʼoqʼ xutij ri bʼayiʼ rech juyubʼ
# --
# //
# > Entrada:     The hiccups heal with a scare
# > Referencia:  Ri xtukʼ kelik we kaxeʼj awibʼ
# --
# //
# > Entrada:     We got wet when the water splashed
# > Referencia:  Xujchʼaqaq rumal xchikloʼn ri ja
# --
# //
# > Entrada:     The communal forest is ending
# > Referencia:  Tajin kkʼis ri komon juyubʼ
# --
# //
# > Entrada:     This is the sowing area
# > Referencia:  Are laʼ ri tikoʼnijibʼal
# --
# //
# > Entrada:     It's delicious to eat elotes
# > Referencia:  Jeʼl ktijow ri aj
# --
# //
# > Entrada:     Yellow corn holds more than white
# > Referencia:  Ri ixim qʼan kʼo na chi uwach ri saqwach
# --
# //
# > Entrada:     The house has three pillars
# > Referencia:  Oxibʼ ri raqan ja kʼolik
# ...
# --
# //
# > Entrada:     Whatc Men have flattened the way
# > Referencia:  Xkiliʼlobʼisaj ri bʼe ri achijabʼ
# --
# //
# > Entrada:     The water snake scares me
# > Referencia:  Kinxiʼj wibʼ chech ri kumatz ales
# --
# //
# > Entrada:     Baby's hands are hurting
# > Referencia:  Kqʼaxow ri uqʼabʼ ri neʼ
# --
# //
# > Entrada:     Now swallow my medicine
# > Referencia:  Xinbʼiqʼ bʼik ri nukunabʼal
# --
# //
# > Entrada:     The pine is dry already
# > Referencia:  Chaqiʼj chik ri chaj
# --
# //
# > Entrada:     It's a very gray world
# > Referencia:  Nim nim we uwach ulew
# --
# //
# > Entrada:     The command of the ancestors is that we must respect the land
# > Referencia:  Ri taqanik kech qatiʼt qamam are kqaloqʼoqʼej ri ulew
# --
# //
# > Entrada:     My grandfather is bald
# > Referencia:  Tʼan ujolom ri numam
# --
# //
# > Entrada:     It was quite the new corn Miguel harvested
# > Referencia:  Sibʼalaj nim ri ixim akʼeʼl xuyak ri Kel
# --
# //
# > Entrada:     The rabbits are eating
# > Referencia:  Tajin kewaʼ ri imul
# --
# //
# > Entrada:     The water is cold
# > Referencia:  Tʼajaʼj ri jaʼ
# --
# //
# > Entrada:     In the municipality there's a shield
# > Referencia:  Kʼo jun pokobʼ pa qʼatbʼal tzij
# --
# //
# > Entrada:     Doña Dolores had her stomach operated on.
# > Referencia:  Ri nan Lol xpochʼ che ri upam
# --
# //
# > Entrada:     This winter the price of the ejote went up
# > Referencia:  Ri rax kinaqʼ xpaqiʼ rajil che we qʼalaj
# --
# //
# > Entrada:     The lady complains of pain
# > Referencia:  Kajilow ri ixoq rumal ri qʼaxom
# --
# //
# > Entrada:     Its load is very bulky
# > Referencia:  Soposik le reqaʼn
# --
# //
# > Entrada:     I beat the pig's water
# > Referencia:  Xinpuqʼ rupeʼn ri aq
# --
# //
# > Entrada:     The rain brings the hornet
# > Referencia:  Ri jabʼ kukʼan loq ri sutzʼ kumatz
# --
# //
# > Entrada:     The goat smells bad
# > Referencia:  Chʼichʼ ri kʼisikʼ
# --
# //
# > Entrada:     The willow is dying
# > Referencia:  Ri saqʼos tajin kkamik
# --
# //
# > Entrada:     People eat oranges
# > Referencia:  Kakitij alanxax ri winaq
# --
# //
# > Entrada:     The translator didn't charge me
# > Referencia:  Ri tzaqal tzij man kʼo ta pwaq xutaʼ chi we
# --
# //
# > Entrada:     It was the Breton that healed my foot
# > Referencia:  Ri tzijtzoj qʼayes xukunaj ri waqan
# --
# //
# > Entrada:     Miss Tomasa is very pretty
# > Referencia:  Jeʼl kkaʼy ri ali Ma x
# --
# //
# > Entrada:     The apple shell is thin
# > Referencia:  Xax rij mansaʼn
# --
# //
# > Entrada:     Why does your knee hurt?
# > Referencia:  ¿Jas che kaqʼaxow ri achʼek?
# --
# //
# > Entrada:     The thirteenth day Kej, is a feast day of my people
# > Referencia:  Ri Oxlajuj Kej, nimaqʼij pa ri nutinamit
# --
# //
# > Entrada:     Whatc My daughter sucks the sugar cane
# > Referencia:  Kutzʼubʼ ajij ri numiʼal
# --
# //
# > Entrada:     That's what he said, a gossip
# > Referencia:  Areʼ xbʼin, jun riqʼol tzij
# --
# //
# > Entrada:     The tamales have been smoked
# > Referencia:  Ri subʼ xkʼiskʼobʼik
# --
# //
# > Entrada:     My youngest son's name is Miguel
# > Referencia:  Kel ubʼiʼ ri chʼiʼp walkʼwal
# --
# //
# > Entrada:     Use the seat
# > Referencia:  Chkajo we kubʼal
# --
# //
# > Entrada:     Sebastian's house is dripping
# > Referencia:  Ktzʼujuw ri rachoch ri Poʼx
# --
# //
# > Entrada:     My dad puts a scarecrow in the milp
# > Referencia:  Ri nuqaw kukoj jun poy pa ri aiʼix
# --
# //
# > Entrada:     The air is buzzing
# > Referencia:  Kjumum ri kaqiqʼ
# --
# //
# > Entrada:     Juanito has a new toy
# > Referencia:  Kʼo jun ukʼakʼ retzʼabʼaʼl, ri alaj a Xwan
# --
# //
# > Entrada:     I like to sing
# > Referencia:  Kawaj bʼixonem
# --
# //
# > Entrada:     A child's breathing is not the same as an old man's
# > Referencia:  Ri ruxlabʼik ri akʼal man junam taj rukʼ jun riʼj
# --
# //
# > Entrada:     You're weighing the wheat
# > Referencia:  Tajin kapaj ri trikoʼ
# --
# //
# > Entrada:     whatc I'm grinding the chili pepper
# > Referencia:  Tajin Kinjokʼ ri ubʼaqʼ le qʼoqʼ
# --
# //
# > Entrada:     The boy came in uncomfortable
# > Referencia:  Xaq utukel petinaq loq ri ala man kʼo ta rachiʼl
# --
# //
# > Entrada:     Black corn is not sown around here
# > Referencia:  Man katik taj ri raxwaʼch waral
# --
# //
# > Entrada:     Whatc Tom's dad is coming
# > Referencia:  Are ri utat ri Max kpetik
# --
# //
# > Entrada:     The authority's mandate is being made public.
# > Referencia:  Ri upixabʼ le qʼatbʼal tzij kiyaʼ ubʼixik
# --
# //
# > Entrada:     In the K'iche' language there are 32 letters
# > Referencia:  Pa le tzijobʼal kʼicheʼ kʼo juwinaq kabʼlajuj tzʼibʼ
# --
# //
# > Entrada:     My mom is 65
# > Referencia:  Oxkʼal jobʼ ujunabʼ ri nuchuch
# --
# //
# > Entrada:     Well you look at the vein
# > Referencia:  Sibʼalaj qʼalaj ri ibʼochʼ
# --
# //
# > Entrada:     Whatc Man is lazy for work
# > Referencia:  Saqʼor che ri uchak ri achi
# --
# //
# > Entrada:     Diego is an evil person
# > Referencia:  Bʼanal kʼax, ri Teʼk
# --
# //
# > Entrada:     The daughter-in-law's name is Aju'
# > Referencia:  Ajuʼ ukabʼ ubʼiʼ ri alibʼatz
# --
# //
# > Entrada:     You have love in your heart
# > Referencia:  Kʼo ri loqʼojnik, pa ri awanimaʼ
# --
# //
# > Entrada:     The firmament has no end
# > Referencia:  Ri kaj man kʼo ta ukʼisik
# --
# //
# > Entrada:     The cold water container is full
# > Referencia:  Nojnaq ri penbʼal che joron
# --
# //
# > Entrada:     What kind of potato is it?
# > Referencia:  ¿Jas chi uwach ri saqwach?
# --
# //
# > Entrada:     Whatc I've got a swollen stomach
# > Referencia:  Sipojinaq ri nupam
# --
# //
# > Entrada:     I wish I could get a loan
# > Referencia:  Kawaj taneʼ kayaʼ nujaloj
# --
# //
# > Entrada:     He found me at the market
# > Referencia:  Inriqtajinaq pa ri kʼayibʼal
# --
# //
# > Entrada:     They're fighting the viewers
# > Referencia:  Tajin kechʼojin, ri kaʼyinelabʼ
# --
# //
# > Entrada:     whatc Felipe raises wood
# > Referencia:  Ri a Peʼl kupaqʼ ri siʼ
# --
# //
# > Entrada:     When we went over the lake we had to go around the village
# > Referencia:  Are taq xujbʼe pa uwiʼ ri cho xeqasutij ri tinamit
# --
# //
# > Entrada:     I lost my key
# > Referencia:  Xintzaq nulawe
# --
# //
# > Entrada:     The snail likes to be on the rocks
# > Referencia:  Ri tʼotʼ kkʼojiʼ pa uwiʼ taq ri abʼaj
# --
# //
# > Entrada:     The horse was tied up
# > Referencia:  Jatʼim kanoq ri kej
# --
# //
# > Entrada:     I have to go with the group
# > Referencia:  Kinbʼe na kukʼ ri molaj
# --
# //
# > Entrada:     Like an apple
# > Referencia:  Kintij masaʼn
# --
# //
# > Entrada:     I'm a lightning rod
# > Referencia:  Tʼan nupalaj
# --
# //
# > Entrada:     She was born in the second generation
# > Referencia:  Xalax pa ri Kaweq
# --
# //
# > Entrada:     Sing the gavel when you run the zipper
# > Referencia:  Kabʼixan ri wiswil are chi karoqataj ri kʼuch
# --
# //
# > Entrada:     The kid's in pre-school
# > Referencia:  Ri akʼal kʼo pa majbʼal tijonik
# --
# //
# > Entrada:     Your morel is black and white
# > Referencia:  Qʼeq chiʼl saq kkaʼy ri achim
# --
# //
# > Entrada:     The trail is already buried
# > Referencia:  Xmuqtaj ri patzʼan
# --
# //
# > Entrada:     This kind of plant is medicinal
# > Referencia:  Ri qʼayes raqʼwakax ubʼiʼ, kkunanik
# --
# //
# > Entrada:     The wheat tar I brought it for us to eat
# > Referencia:  Ri triko wa xinkʼam loq are chi kaqatijo
# --
# //
# > Entrada:     The food is cooking
# > Referencia:  Tajin kraqow ri wa
# --
# //
# > Entrada:     Many of our people are in the capital
# > Referencia:  Kʼi qawinaq e kʼo pa taq pa nim tinamit
# --
# //
# > Entrada:     What  My dad's kidding
# > Referencia:  Ri nutat kubʼan etzʼanem tzij
# --
# //
# > Entrada:     The white dog is dead
# > Referencia:  Xkam ri saqtzʼiʼ
# --
# //
# > Entrada:     It's better if we make a new system
# > Referencia:  Utz we kaqabʼan jun kʼakʼ nukʼulem
# --
# //
# > Entrada:     He was holding his younger sister by the hand
# > Referencia:  Ukʼamom bʼik che uqʼabʼ ri uchaqʼ
# --
# //
# > Entrada:     We're digging a hole
# > Referencia:  Tajin kqakʼot jun jul
# --
# //
# > Entrada:     Her voice is like your brother's
# > Referencia:  Ri uqul, are bʼik rech ri uchaqʼ
# --
# //
# > Entrada:     The pineapple is very acidic
# > Referencia:  Sibʼalaj chʼam ri matzatiʼ
# --
# //
# > Entrada:     In Maya culture, Ixtzamna' is the god of medicine
# > Referencia:  Chi upan ri mayabʼ kʼaslemal, ri Ixtzamnaʼ are Ajaw re kunabʼal
# --
# //
# > Entrada:     Only my mother knows where she gets the wild mushrooms
# > Referencia:  Ri nunan areʼ retaʼm jawchiʼ kuriq ri tziket
# --
# //
# > Entrada:     Sebastian's companion is called Tomasa
# > Referencia:  Xiʼn ubʼiʼ ri ukʼulaj ri a Poʼx
# --
# //
# > Entrada:     Whatc My son has blond hair
# > Referencia:  Qʼan uwiʼ ri waʼlkwaʼl
# --
# //
# > Entrada:     Whatc The clothes were wet
# > Referencia:  Chʼaqasam kanoq ri atzʼyaq
# --
# //
# > Entrada:     My younger brother is a college student
# > Referencia:  Ri nuchaqʼ areʼ tijoxel rech Ajnim Tijobʼal
# --
# //
# > Entrada:     It's our tradition to put marimba
# > Referencia:  Are qanaqʼatisam qibʼ chi qech ri ukojik ri qʼojom
# --
# //
# > Entrada:     The milp grows in fertile soil
# > Referencia:  Jeʼl kunaʼ ri abʼix chi upam ri quq ulew
# --
# //
# > Entrada:     The crowd shouted loudly
# > Referencia:  Jumolaj winaq xkiraq kichiʼ
# --
# //
# > Entrada:     The blind chicken eats the root of the milp
# > Referencia:  Ri ixpokʼpon kutij urabʼ ri abʼix
# --
# //
# > Entrada:     What's up?  My stitch has a hole
# > Referencia:  Ri nupoʼt teʼq chik
# --
# //
# > Entrada:     Roberto is a good shoemaker and his work is guaranteed
# > Referencia:  Utzilaj bʼanal xajabʼ ri a Wet ri uchak naj kkiqʼaʼo
# --
# //
# > Entrada:     Joseph repels his house
# > Referencia:  Ri Xep kutʼaq ri rachoch
# --
# //
# > Entrada:     The bird called Kʼatet in Kʼicheʼ language, is on the tree
# > Referencia:  Ri kʼatet kʼakʼojiʼ pa uwiʼ ri cheʼ
# --
# //
# > Entrada:     My place of origin is Quetzaltenango
# > Referencia:  Ri nujuyubʼal areʼ Xeljuʼ
# --
# //
# > Entrada:     It's been 300 days this year
# > Referencia:  Oʼlajkʼal qʼij uj bʼenaq che we junabʼ riʼ
# --
# //
# > Entrada:     It's the 40th anniversary of our school
# > Referencia:  Areʼ ukakʼal ujunabʼ ri tijobʼal qukʼ
# --
# //
# > Entrada:     The sand from the river is used for building houses
# > Referencia:  Ri sanyebʼ kkoj che ri yakbʼal ja
# --
# //
# > Entrada:     The painter charges per square rod, for the painting of the house
# > Referencia:  Ri tzʼajnel kutzʼaj pa bʼara ri ja
# --
# //
# > Entrada:     What's the cat running away
# > Referencia:  Tajin kanimaj, ri meʼs
# --
# //
# > Entrada:     What  Bring me the garbage can
# > Referencia:  Kʼamaʼ loq chi wech ri jokbʼal mes
# --
# //
# > Entrada:     The lady is sad
# > Referencia:  bʼis kʼo ri chuchuʼ
# --
# //
# > Entrada:     The pine grows very high
# > Referencia:  Nim raqan ri tux kelik
# --
# //
# > Entrada:     All the dough is crumpled
# > Referencia:  Lejtajinaq ronojel ri qʼor
# --
# //
# > Entrada:     The animal bit me
# > Referencia:  Xinukatz ri awaj
# --
# //
# > Entrada:     B'alam Aq'ab' is one of the first men of the Maya people
# > Referencia:  Ri Bʼalam Aqʼabʼ areʼ jun chi kech ri achijabʼ re mayabʼ tinamit
# --
# //
# > Entrada:     Whatc The boy eats the tender toughness
# > Referencia:  Ri akʼal kutij ri puʼy turaʼs
# --
# //
# > Entrada:     I got to the meeting from third
# > Referencia:  In urox xinopan pa ri mulibʼal ibʼ
# --
# //
# > Entrada:     Quc  It drips a lot in the rain
# > Referencia:  Sibʼalaj tzʼuj rumal ri jabʼ
# --
# //
# > Entrada:     Here's the great sage
# > Referencia:  chiʼ kʼo wi ri nimalaj etaʼmanel
# --
# //
# > Entrada:     He's half fat the son of Incarnation
# > Referencia:  Bʼaqbʼoj ri ukʼojol ri Choʼn
# --
# //
# > Entrada:     My son is very dear
# > Referencia:  Loqʼ ri nukʼajolaxel
# --
# //
# > Entrada:     They ran to the thief
# > Referencia:  Xoqotax ri elaqʼom
# --
# //
# > Entrada:     When the night comes good night we're very happy
# > Referencia:  Sibʼalaj kujkiʼkotik chi kopan ri alaxbʼal
# --
# //
# > Entrada:     I sent for a needle
# > Referencia:  Xintaqan chech uloqʼik jun bʼaq
# --
# //
# > Entrada:     She knows I'll be there
# > Referencia:  Areʼ retaʼm che kinopanik
# --
# //
# > Entrada:     The chicken is lost in the milp
# > Referencia:  Ri chʼaʼn sachinaq pa taq abʼix
# --
# //
# > Entrada:     The house is very solid
# > Referencia:  Ko ri ja
# --
# //
# > Entrada:     The mud brings disease
# > Referencia:  Ri xaqʼoʼl kumulij yabʼil
# --
# //
# > Entrada:     whatc I folded all the paperwork
# > Referencia:  Xinbʼus ronojel ri wuj
# --
# //
# > Entrada:     The dwarf is sweet to eat
# > Referencia:  Ri kʼawex kiʼ katijowik
# --
# //
# > Entrada:     At the party you have to decorate the house
# > Referencia:  Pa le nimaqʼij rajawaxik kawiq le ja
# --
# //
# > Entrada:     There's two buckets of dirt in front of the church
# > Referencia:  Kʼo kebʼ umul chi uwach ri tyox ja
# --
# //
# > Entrada:     What's up?  Your beard is spongy
# > Referencia:  Patzapik ri awismachiʼ
# --
# //
# > Entrada:     My dog is male
# > Referencia:  Amaʼ ri nutzʼiʼ
# --
# //
# > Entrada:     My load is too heavy
# > Referencia:  Sibʼalaj al ri weqaʼn
# --
# //
# > Entrada:     What  Just a snack I gave you
# > Referencia:  Xa jupur xinsipaj chi awe
# --
# //
# > Entrada:     Meat helps the body grow
# > Referencia:  92 Ri tiʼj ktobʼan che ukʼiysaxik ri chʼakul
# --
# //
# > Entrada:     My grandmother lived for 120 years.
# > Referencia:  Ri watiʼt xkʼasiʼk waqkʼal junabʼ
# --
# //
# > Entrada:     Talk to the gentleman
# > Referencia:  Chʼabʼexoq ri tataʼ
# --
# //
# > Entrada:     They complemented your adobes
# > Referencia:  Xtzʼaqatisax ri axan
# --
# //
# > Entrada:     The ground rope has 20 grooves
# > Referencia:  Ri jun kʼaʼm ulew kʼo junwinaq qʼeʼt chi upam
# --
# //
# > Entrada:     I don't take the bitter
# > Referencia:  Man kinqamuj taj ri kʼa
# --
# //
# > Entrada:     My uncle is lame
# > Referencia:  Chʼakoʼj ri wikan
# --
# //
# > Entrada:     Looks stylish in his suit
# > Referencia:  Kalujuw pa ri ratzʼyaq
# --
# //
# > Entrada:     The job of the young man is linguistics
# > Referencia:  Ri uchak ri ala areʼ ri cholchiʼ
# --
# //
# > Entrada:     Diego is 60 years old
# > Referencia:  Ri Teʼk kʼo oxkʼal ujunabʼ
# --
# //
# > Entrada:     The loop is hanging on the wall
# > Referencia:  Xekel ri kolobʼchi uwach ri xan
# --
# //
# > Entrada:     The loop is unfolded
# > Referencia:  Solsobʼinaq ri kolobʼ
# --
# //
# > Entrada:     I passed in the middle of people
# > Referencia:  Xinqʼax chi kixoʼl ri winaq
# --
# //
# > Entrada:     Garlic has to be the spice of beans
# > Referencia:  Ri axux are na ri ukunel ri kinaqʼ
# --
# //
# > Entrada:     What's hard for him to learn
# > Referencia:  Kʼax kuraq che retaʼmaxik
# --
# //
# > Entrada:     The boy is naked
# > Referencia:  Sanal le akʼal
# --
# //
# > Entrada:     Whatc You saw the armadillo pass
# > Referencia:  Xawilo, xqʼatan le ibʼoy
# --
# //
# > Entrada:     Her sister-in-law's name is Lucia
# > Referencia:  Luʼs ubʼiʼ ri recham
# --
# //
# > Entrada:     The cockroach came inside the bananas
# > Referencia:  Ri xpiʼn petinaq loq chi upam ri saqʼul
# --
# //
# > Entrada:     Now you've got your stuff
# > Referencia:  Kamik kʼo chi ri jas taq awe
# --
# //
# > Entrada:     We were formed by the Creator and the trainer
# > Referencia:  Are ri nimalaj qajaw xbʼanow ri qabʼit
# --
# //
# > Entrada:     How much do I owe you?
# > Referencia:  ¿Janikʼ paʼ ri nukʼas awukʼ?
# --
# //
# > Entrada:     There was a lot of fog yesterday
# > Referencia:  Sibʼalaj japalik sutzʼ iwir
# --
# //
# > Entrada:     I'm looking for a girl to help me
# > Referencia:  Tajin kintzukuj jun ali rech kinutoʼo
# --
# //
# > Entrada:     I'm carrying wood
# > Referencia:  Tajin kinwerej siʼ
# --
# //
# > Entrada:     You're guilty, for eating what's not yours
# > Referencia:  At ajmak rumal chi xatij, le man awech taj
# --
# //
# > Entrada:     My uncle has a liver problem
# > Referencia:  Kʼax ri usesebʼ ri wikan
# --
# //
# > Entrada:     Only the Creator and the Former sends us his blessings
# > Referencia:  Xaq xu wi ri Ajaw kutaq loq ri utewchiʼbʼal chi qech
# --
# //
# > Entrada:     In Sacapulas they give quality toys
# > Referencia:  Pa Tujal kkʼiy ri jeʼlik taq qʼinom
# --
# //
# > Entrada:     They hung the boy for committing a robbery
# > Referencia:  Xtzayibʼax ri ala rumal che xubʼan elaqʼ
# --
# //
# > Entrada:     I went into the room
# > Referencia:  Xinok pa ja
# --
# //
# > Entrada:     Whatc A couple ran away
# > Referencia:  Jukʼulaj winaq xeʼanimaj bʼik
# --
# //
# > Entrada:     I'll wear the wood
# > Referencia:  Kinjarisaj na ri cheʼ
# --
# //
# > Entrada:     Isabel was late for her classes
# > Referencia:  Ri Xpeʼr matam xopan pa ri utijobʼal
# --
# //
# > Entrada:     The gorge has echoes
# > Referencia:  Kaxojin ri siwan
# --
# //
# > Entrada:     Diego is in the shade of the tree
# > Referencia:  Ri Teʼk kakʼojiʼ chi uxeʼ umuʼj ri pelaʼbʼ
# --

# %% [markdown]
# ##### Clean Up Spanish Input from quc tags

# %%
import re
from datasets import DatasetDict # Asegúrate de tener esta importación

# Asumimos que 'es_quc_dataset' ya está cargado y disponible en tu notebook
# y tiene la estructura: {'input': [kiche], 'target': [español]}

def clean_spanish_target(example):
    """
    Toma un ejemplo del dataset es_quc_dataset y limpia únicamente la columna 'target' (español),
    eliminando los artefactos y etiquetas no deseadas como '#quc#'.
    """
    # --- LA MODIFICACIÓN CLAVE ESTÁ AQUÍ ---
    # Apuntamos a la columna 'target' que contiene el texto en español
    dirty_text = example["target"]

    # Usamos la misma lógica de limpieza que ya tenías, es perfecta
    # Elimina #quc#, # quc #, # Quc #, etc. ignorando mayúsculas/minúsculas y espacios
    clean_text = re.sub(r'#\s*quc\s*#', '', dirty_text, flags=re.IGNORECASE)
    # Elimina el símbolo ♪ (por si acaso existiera)
    clean_text = re.sub(r'♪', '', clean_text)
    # Elimina cualquier caracter # que haya quedado suelto
    clean_text = clean_text.replace('#', '')

    # Elimina espacios extra al principio o al final
    # Y actualizamos la columna 'target' del ejemplo
    example["target"] = clean_text.strip()

    return example

# --- Aplicar la función de limpieza a todo el dataset ---
# .map() es una forma muy eficiente de aplicar una función a cada fila
print("🧼 Limpiando la columna de español ('target') del dataset 'es_quc_dataset'...")

cleaned_es_quc_dataset = es_quc_dataset.map(
    clean_spanish_target,
    desc="Limpiando columna 'target' (Español)"
)

print("\n✅ Limpieza completada.")
print("Ahora tienes una nueva variable 'cleaned_es_quc_dataset' con los datos limpios.")

# --- Verificación ---
# Imprimamos un par de ejemplos para ver el ANTES y el DESPUÉS.
print("\n--- Verificando la limpieza del dataset de Español-K'iche' ---")

# Seleccionamos un índice para comparar
sample_index = 1

# Ejemplo ANTES de la limpieza
original_example = es_quc_dataset["test"][sample_index]
print(f"EJEMPLO {sample_index} (ANTES):")
print(f"Input (K'iche'):\t'{original_example['input']}'")
print(f"Target (Español):\t'{original_example['target']}'")


# Mismo ejemplo DESPUÉS de la limpieza
cleaned_example = cleaned_es_quc_dataset["test"][sample_index]
print(f"\nEJEMPLO {sample_index} (DESPUÉS):")
print(f"Input (K'iche'):\t'{cleaned_example['input']}'")
print(f"Target (Español Limpio):\t'{cleaned_example['target']}'")
# Out:
# 🧼 Limpiando la columna de español ('target') del dataset 'es_quc_dataset'...
# Limpiando columna 'target' (Español):   0%|          | 0/624 [00:00<?, ? examples/s]
# Limpiando columna 'target' (Español):   0%|          | 0/1000 [00:00<?, ? examples/s]
# ✅ Limpieza completada.
# Ahora tienes una nueva variable 'cleaned_es_quc_dataset' con los datos limpios.
#
# --- Verificando la limpieza del dataset de Español-K'iche' ---
# EJEMPLO 1 (ANTES):
# Input (K'iche'):	'Xanimaj bʼik ri kuk'
# Target (Español):	'La ardilla se escapó'
#
# EJEMPLO 1 (DESPUÉS):
# Input (K'iche'):	'Xanimaj bʼik ri kuk'
# Target (Español Limpio):	'La ardilla se escapó'

# %%
es_quc_dataset = cleaned_es_quc_dataset
en_quc_dataset = cleaned_en_quc_dataset

# %% [markdown]
# ##### Invertir dataset

# %%
# Asumimos que 'es_quc_dataset' es tu DatasetDict con la estructura original

def invertir_columnas(example):
  """
  Toma un ejemplo y devuelve un nuevo diccionario con las columnas 'input' y 'target' intercambiadas.
  """
  return {
      'input': example['target'],  # El antiguo 'target' (español) es ahora el 'input'
      'target': example['input']   # El antiguo 'input' (k'iche') es ahora el 'target'
  }

# Aplicamos la función de inversión a todo el dataset (a los splits 'train' y 'test')
# Guardamos el resultado en una nueva variable para no perder el original.
dataset_invertido = es_quc_dataset.map(
    invertir_columnas,
    desc="Invirtiendo las columnas input/target"
)

# --- Verificación ---
# Comprobemos que la inversión funcionó correctamente.

print("--- Verificando la inversión del dataset ---")

print("\nDataset ANTES de invertir (ejemplo 1):")
print(es_quc_dataset['train'][1])
# Salida esperada: {'input': 'Ketom ri uqʼabʼ ri cheʼ', 'target': 'La rama está cortada'}


print("\nDataset DESPUÉS de invertir (ejemplo 1):")
print(dataset_invertido['train'][1])
# Salida esperada: {'input': 'La rama está cortada', 'target': 'Ketom ri uqʼabʼ ri cheʼ'}
# Out:
# Invirtiendo las columnas input/target:   0%|          | 0/624 [00:00<?, ? examples/s]
# Invirtiendo las columnas input/target:   0%|          | 0/1000 [00:00<?, ? examples/s]
# --- Verificando la inversión del dataset ---
#
# Dataset ANTES de invertir (ejemplo 1):
# {'input': 'Ketom ri uqʼabʼ ri cheʼ', 'target': 'La rama está cortada'}
#
# Dataset DESPUÉS de invertir (ejemplo 1):
# {'input': 'La rama está cortada', 'target': 'Ketom ri uqʼabʼ ri cheʼ'}

# %% [markdown]
# ## Datasets

# %% [markdown]
# ### Verificacion inicial de lenguaje en el modelo NLLB

# %%
from transformers import AutoTokenizer

# Cargamos el tokenizador oficial de NLLB
model_name = "facebook/nllb-200-distilled-600M"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# --- Verifiquemos los idiomas ---

kiche_code = "quc_Latn"
sipakapense_code = "qum_Latn"

print(f"Buscando el ID para K'iche' ({kiche_code})...")
try:
    kiche_id = tokenizer.convert_tokens_to_ids(kiche_code)
    print(f"✅ ÉXITO: El ID para '{kiche_code}' es: {kiche_id}. ¡SÍ EXISTE!")
except Exception as e:
    print(f"❌ FALLO: No se pudo encontrar un ID para '{kiche_code}'. ¡NO EXISTE!")

print("-" * 20)

print(f"Buscando el ID para Sipakapense ({sipakapense_code})...")
try:
    # El tokenizador arroja un error si no encuentra el token.
    # Usamos .get para manejarlo sin que el programa se caiga.
    sipakapense_id = tokenizer.vocab.get(sipakapense_code)
    if sipakapense_id is not None:
         print(f"✅ ÉXITO: El ID para '{sipakapense_code}' es: {sipakapense_id}. ¡SÍ EXISTE!")
    else:
         print(f"❌ FALLO: No se encontró un ID para '{sipakapense_code}'. ¡NO EXISTE!")
except Exception as e:
    print(f"❌ FALLO: Ocurrió un error buscando '{sipakapense_code}'.")
# Out:
# Buscando el ID para K'iche' (quc_Latn)...
# ✅ ÉXITO: El ID para 'quc_Latn' es: 3. ¡SÍ EXISTE!
# --------------------
# Buscando el ID para Sipakapense (qum_Latn)...
# ❌ FALLO: No se encontró un ID para 'qum_Latn'. ¡NO EXISTE!

# %% [markdown]
# ### Siguientes pasos

# %% [markdown]
# Dataset se puede encontrar en el [siguiente enlace](https://github.com/transducens/mayanv).

# %%
es_quc_dataset = generate_dataset("quc", train_folder="train", test_folder="test")
es_quc_dataset
# Out:
# Attempting to load train split from: /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/mayanv/MayanV/quc/train/data.es and /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/mayanv/MayanV/quc/train/data.quc
# Attempting to load test split from: /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/mayanv/MayanV/quc/test/data.es and /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/mayanv/MayanV/quc/test/data.quc
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'target'],
#         num_rows: 624
#     })
#     test: Dataset({
#         features: ['input', 'target'],
#         num_rows: 1000
#     })
# })

# %%
# Save the dataset to the drive path
es_quc_dataset.save_to_disk(f"{DRIVE_PATH}/es_quc_dataset")

# Save the cloned git repository to the drive path
# !cp -r mayanv/ "{DRIVE_PATH}/mayanv"
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/624 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1000 [00:00<?, ? examples/s]
# ^C

# %% [markdown]
# ## Preparación y Entrenamiento de Modelos

# %% [markdown]
# ### 1. Modelo Zero-shot

# %%
model_name = "facebook/nllb-200-distilled-600M"
zeroshot_tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
zeroshot_model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
zeroshot_tokenizer.src_lang = "eng_Latn"
forced_bos_id = zeroshot_tokenizer.convert_tokens_to_ids("quc_Latn")

# %% [markdown]
# ### 2. Modelo con Finetuning Español-Kiche
#
# Aquí entrenamos un modelo para que sea un experto en una tarea específica: Español -> K'iche'. Este modelo se usará después como una pieza en el experimento del pipeline.

# %% [markdown]
# #### 2.1 Modelo con Finetuning Español-Kiche

# %% [markdown]
# ##### Entrenamiento

# %%
model_name = "facebook/nllb-200-distilled-600M"
es_quc_dataset = dataset_invertido
finetune_tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)

# 1. Añadir el token especial al tokenizador
print(f"Añadiendo el token especial: {TARGET_LANG_CODE}")
finetune_tokenizer.add_special_tokens({'additional_special_tokens': [TARGET_LANG_CODE]})


bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
)


finetune_model = AutoModelForSeq2SeqLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto"
)

# 2. Redimensionar los embeddings del modelo
print("Redimensionando embeddings del modelo...")
finetune_model.resize_token_embeddings(len(finetune_tokenizer))

# Configurar LoRA
lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.1,
    bias="none",
    task_type=TaskType.SEQ_2_SEQ_LM
)

# Aplicar QLoRA
finetune_model = get_peft_model(finetune_model, lora_config)
# Out:
# Añadiendo el token especial: quc_Latn
# Redimensionando embeddings del modelo...

# %%
def preprocess_function(examples):
    max_length = 128
    # Tokeniza el input
    inputs = finetune_tokenizer(examples["input"], max_length=max_length, truncation=True, padding=True)
    # Tokeniza la salida (target)
    targets = finetune_tokenizer(examples["target"], max_length=max_length, truncation=True, padding=True)

    inputs["labels"] = targets["input_ids"]
    return inputs

tokenized_train = es_quc_dataset["train"].map(preprocess_function, batched=True)
tokenized_test = es_quc_dataset["test"].map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/624 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
training_args = TrainingArguments(
    output_dir="./qlora_finetuned_qum_nllb",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=60,
    lr_scheduler_type="cosine",
    weight_decay=0.01,
    learning_rate=5e-5,
    logging_steps=100,
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_dir="./logs_qlora",
    save_total_limit=2,
    bf16=False,
    fp16=True,
    report_to="none"
)


trainer = Trainer(
    model=finetune_model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_test,
    tokenizer=finetune_tokenizer,
)

trainer.train()

# Define the save path
save_path = f"{DRIVE_PATH}/qlora_finetuned_es_quc_nllb"

# Save the model and tokenizer to the specified path
finetune_model.save_pretrained(save_path)
finetune_tokenizer.save_pretrained(save_path)

print(f"✅ Model and tokenizer saved to {save_path}")
# Out:
# /tmp/ipython-input-76-3556692828.py:20: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# No label_names provided for model class `PeftModelForSeq2SeqLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#     <div>
#
#       <progress value='2340' max='2340' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2340/2340 40:54, Epoch 30/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>8.835606</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>8.623500</td>
#       <td>8.169327</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.953900</td>
#       <td>7.391757</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>7.143400</td>
#       <td>6.982570</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>7.143400</td>
#       <td>6.748554</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>6.780000</td>
#       <td>6.611266</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>6.574600</td>
#       <td>6.512908</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>6.399600</td>
#       <td>6.440549</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>6.336000</td>
#       <td>6.385459</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>6.336000</td>
#       <td>6.344462</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>6.242800</td>
#       <td>6.311867</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>6.201900</td>
#       <td>6.283726</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>6.161400</td>
#       <td>6.261939</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>6.161400</td>
#       <td>6.248250</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>6.125900</td>
#       <td>6.228912</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>6.091800</td>
#       <td>6.216671</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>6.081100</td>
#       <td>6.205345</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>6.059700</td>
#       <td>6.196035</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>6.059700</td>
#       <td>6.189693</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>6.051900</td>
#       <td>6.181309</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>6.016900</td>
#       <td>6.176171</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>6.025600</td>
#       <td>6.172066</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>6.025600</td>
#       <td>6.169159</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>6.028600</td>
#       <td>6.166811</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>6.015600</td>
#       <td>6.165086</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>5.975200</td>
#       <td>6.164049</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>6.022600</td>
#       <td>6.163192</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>6.022600</td>
#       <td>6.162825</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>5.992900</td>
#       <td>6.162728</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>5.997700</td>
#       <td>6.162704</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# ✅ Model and tokenizer saved to /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/qlora_finetuned_es_quc_nllb

# %%
import torch
from tqdm import tqdm
import evaluate # Librería para métricas

# --- 1. CONFIGURACIÓN DE LA EVALUACIÓN ---
print("--- Configurando la evaluación del modelo final ---")

# Modelo y Tokenizador a evaluar (tus variables del entrenamiento)
model_to_test = finetune_model
tokenizer_to_use = finetune_tokenizer

# Dataset de prueba (asegúrate de que sea la versión limpia)
dataset_to_test = es_quc_dataset["test"]

# Dirección de la traducción
SOURCE_LANG_CODE = "spa_Latn"  # Español
TARGET_LANG_CODE = "quc_Latn"   # K'iche'

# Obtenemos el ID de idioma correcto para K'iche'
forced_bos_id = tokenizer_to_use.convert_tokens_to_ids(TARGET_LANG_CODE)
print(f"Modelo a evaluar: 'finetune_model'")
print(f"Traduciendo de: {SOURCE_LANG_CODE} -> {TARGET_LANG_CODE}")
print(f"ID de idioma forzado para K'iche': {forced_bos_id}")


# --- 2. FUNCIÓN DE GENERACIÓN DE PREDICCIONES ---
def generate_predictions(model, tokenizer, dataset, n_examples=None):
    predictions = []
    references = []

    model.eval()
    device = model.device

    if n_examples is None:
        n_examples = len(dataset)
    num_samples = min(n_examples, len(dataset))

    print(f"\nGenerando {num_samples} predicciones...")
    for i in tqdm(range(num_samples)):
        item = dataset[i]

        # La entrada es el español y la referencia es el K'iche'
        input_text = item["input"]   # Columna de español
        reference_text = item["target"]  # Columna de k'iche'

        inputs = tokenizer(input_text, return_tensors="pt", truncation=True, max_length=128).to(device)

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                forced_bos_token_id=forced_bos_id,
                max_length=128,
                num_beams=5,
                early_stopping=True
            )

        pred = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]

        predictions.append(pred)
        references.append(reference_text)

    return predictions, references


# --- 3. EJECUCIÓN Y VISUALIZACIÓN ---
predictions, references = generate_predictions(
    model_to_test,
    tokenizer_to_use,
    dataset_to_test,
    n_examples=100 # Usamos 20 ejemplos para una prueba visual rápida
)

print("\n\n--- Muestra de Traducciones del Modelo Final ---")
for i in range(len(predictions)):
    print(f"\n{i+1})")
    print(f"   Entrada (Español):   {dataset_to_test[i]['input']}")
    print(f"   Referencia (K'iche'):  {references[i]}")
    print(f"   Predicción (Modelo):   {predictions[i]}")


# --- 4. CÁLCULO DE MÉTRICAS AUTOMÁTICAS ---
print("\n\n--- Calculando Métricas de Evaluación ---")

bleu = evaluate.load("bleu")
rouge = evaluate.load("rouge")

bleu_score = bleu.compute(predictions=predictions, references=[[ref] for ref in references])
rouge_score = rouge.compute(predictions=predictions, references=references)

print("\n📊 Puntuación BLEU:")
print(f"   BLEU: {bleu_score['bleu'] * 100:.2f}")

print("\n📊 Puntuación ROUGE:")
print(f"   ROUGE-1: {rouge_score['rouge1'] * 100:.2f}")
print(f"   ROUGE-2: {rouge_score['rouge2'] * 100:.2f}")
print(f"   ROUGE-L: {rouge_score['rougeL'] * 100:.2f}")
# Out:
# --- Configurando la evaluación del modelo final ---
# Modelo a evaluar: 'finetune_model'
# Traduciendo de: spa_Latn -> quc_Latn
# ID de idioma forzado para K'iche': 256204
#
# Generando 100 predicciones...
# 100%|██████████| 100/100 [01:54<00:00,  1.14s/it]
# --- Muestra de Traducciones del Modelo Final ---
#
# 1)
#    Entrada (Español):   Tienes indigestión
#    Referencia (K'iche'):  Kqʼulqʼut ri apam
#    Predicción (Modelo):   Kʼoʼbʼal
#
# 2)
#    Entrada (Español):   La ardilla se escapó
#    Referencia (K'iche'):  Xanimaj bʼik ri kuk
#    Predicción (Modelo):
#
# 3)
#    Entrada (Español):   Tu cuñado está nadando
#    Referencia (K'iche'):  Tajin kamuxan ri awecham
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 4)
#    Entrada (Español):   En la costa me contagié de paludismo
#    Referencia (K'iche'):  Xinriq raxtew pa taqʼaj
#    Predicción (Modelo):   kʼo kʼo kʼo ri kʼo
#
# 5)
#    Entrada (Español):   Vengo con él para hacer leña en la montaña
#    Referencia (K'iche'):  Xinpe rukʼ chech ubʼanik siʼ, pa ri juyubʼ
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo ri kʼo
#
# 6)
#    Entrada (Español):   El señor tiene picazón en los pies
#    Referencia (K'iche'):  Kʼo kʼaqat chi raqan ri tataʼ
#    Predicción (Modelo):   kʼo kʼo kʼo ri kʼo
#
# 7)
#    Entrada (Español):   Necesitas aprender acerca el aseo
#    Referencia (K'iche'):  Rajwaxik kawetaʼmaj pa uwiʼ ri chʼajchʼojisanem
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 8)
#    Entrada (Español):   El chilacayote es grande
#    Referencia (K'iche'):  Nim ri qʼoqʼ
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 9)
#    Entrada (Español):   Aclárate ante el pueblo
#    Referencia (K'iche'):  Chqʼalajisaj awibʼ chi kiwach ri tinamit
#    Predicción (Modelo):   kʼo kʼo ri kʼo
#
# 10)
#    Entrada (Español):   Te apuras a tus tareas
#    Referencia (K'iche'):  Kakowij che ri apatan
#    Predicción (Modelo):   kʼo kʼo ri kʼo
#
# 11)
#    Entrada (Español):   La piedra es liviana
#    Referencia (K'iche'):  Ri abʼaj yatzalik
#    Predicción (Modelo):
#
# 12)
#    Entrada (Español):   En la montaña hay muchos pies de niños
#    Referencia (K'iche'):  Pa juyubʼ Sibʼalaj raqan neʼ kʼolik
#    Predicción (Modelo):   kʼo ri kʼoʼbʼal
#
# 13)
#    Entrada (Español):   No tenemos una currícula nacional
#    Referencia (K'iche'):  Man kʼo ta jun nukʼubʼal chak Amaqʼ
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 14)
#    Entrada (Español):   Me enoje mucho
#    Referencia (K'iche'):  Sibʼalaj xinkʼaʼnarik
#    Predicción (Modelo):
#
# 15)
#    Entrada (Español):   Quisiera abrazarte
#    Referencia (K'iche'):  Kinwaj katinqʼaluj
#    Predicción (Modelo):   Kʼoʼbʼal
#
# 16)
#    Entrada (Español):   Hay que pelar las papas
#    Referencia (K'iche'):  Chsoloʼ rij taq saqwach
#    Predicción (Modelo):   kʼo kʼo kʼo
#
# 17)
#    Entrada (Español):   El chocoyo come elotes
#    Referencia (K'iche'):  Ri kʼel kutij aj
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 18)
#    Entrada (Español):   Tengo que hacer una construcción aquí
#    Referencia (K'iche'):  Kinbʼan na jun tzʼaq chi riʼ
#    Predicción (Modelo):   kʼo kʼo kʼo ri kʼo
#
# 19)
#    Entrada (Español):   ¿ ¿Qué fue lo que me dijiste?
#    Referencia (K'iche'):  Su xabʼij chi wech?
#    Predicción (Modelo):   bʼalabʼalabʼalabʼalabʼalabʼal?
#
# 20)
#    Entrada (Español):   Los juguetes están muy caros
#    Referencia (K'iche'):  Paqal rajil ri taq etzʼabʼaʼl
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 21)
#    Entrada (Español):   Mi pareja está feliz
#    Referencia (K'iche'):  Kkiʼkot ri nukʼulaj
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 22)
#    Entrada (Español):   Tienes cuidado cuando vas por las calles
#    Referencia (K'iche'):  Kachajij awibʼ pa taq uqʼabʼ uxoʼl bʼe
#    Predicción (Modelo):   kʼo kʼo ri kʼoʼl
#
# 23)
#    Entrada (Español):   La planta silvestre medi- cinal me curó
#    Referencia (K'iche'):  Xukunaj nupam ri ojolom ikox
#    Predicción (Modelo):   kʼo kʼo kʼo ri kʼo
#
# 24)
#    Entrada (Español):   El membrillo es muy ácido
#    Referencia (K'iche'):  Sibʼalaj chʼam ri amprino
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 25)
#    Entrada (Español):   El calor me da mucha sed
#    Referencia (K'iche'):  Ri qʼaqʼ kuya chaqiʼj chiʼ chi wech
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 26)
#    Entrada (Español):   La señora
#    Referencia (K'iche'):  Ri ixoq bʼenaq rukʼ ri ajkun rumal che kqʼaxow ri uchuch upam
#    Predicción (Modelo):
#
# 27)
#    Entrada (Español):   Vendí el cerdo en doscientos veinte quetzales
#    Referencia (K'iche'):  Xinkʼayij bʼik ri aq rukʼ julajkʼal qʼuqʼ
#    Predicción (Modelo):   kʼo kʼo ri kʼoʼbʼal
#
# 28)
#    Entrada (Español):   Francisco fue muy lejos
#    Referencia (K'iche'):  Naj xbʼe wi ri a Siʼs
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 29)
#    Entrada (Español):   Mi hacha fue devuelta
#    Referencia (K'iche'):  Xkitzalij ri wikaj
#    Predicción (Modelo):   kʼo ri kʼo
#
# 30)
#    Entrada (Español):   Está muy gruesa la punta del palo
#    Referencia (K'iche'):  Sorosik ubʼanom ri uwiʼ le cheʼ
#    Predicción (Modelo):   kʼo kʼo kʼo ri kʼo
#
# 31)
#    Entrada (Español):   el anillo se perdión entre el zacate
#    Referencia (K'iche'):  Xtzaqik ri mulqʼabʼ pa ri qʼayes
#    Predicción (Modelo):   kʼo kʼo ri kʼoʼbʼal
#
# 32)
#    Entrada (Español):   El hombre está desnudo
#    Referencia (K'iche'):  Chʼanal ri achi
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 33)
#    Entrada (Español):   Hay estrellas en el cielo
#    Referencia (K'iche'):  Kʼo chʼumil chi uwach ri kaj
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 34)
#    Entrada (Español):   El cebo es bueno para las rajaduras de las manos
#    Referencia (K'iche'):  Ri xepu utz kkoj che ri pixnaq qʼabʼaj
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo kʼo ri kʼo
#
# 35)
#    Entrada (Español):   Mi hermana está aprendiendo taquigrafía
#    Referencia (K'iche'):  Tajin karetaʼmaj aninaq tzʼibʼ ri wanabʼ
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo ri kʼo
#
# 36)
#    Entrada (Español):   La muchacha es muy loca
#    Referencia (K'iche'):  Sibʼalaj mox ri ali
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 37)
#    Entrada (Español):   ¿Cómo se llama tú yerno?
#    Referencia (K'iche'):  ¿Jas ubʼiʼ ri ajiʼatz?
#    Predicción (Modelo):   ri kʼoʼbʼal?
#
# 38)
#    Entrada (Español):   La leña lo dejé jateado en el corredor
#    Referencia (K'iche'):  Xintun kan ri siʼ pa raqan ja
#    Predicción (Modelo):   kʼo kʼo kʼo ri kʼoʼbʼal
#
# 39)
#    Entrada (Español):   Cuando veas gemelos dales dinero, porque se te pica la ropa
#    Referencia (K'iche'):  We keʼawil yoʼx chasipaj kirajil we man kasipaj, kkibʼan kʼax che ri awatzʼiyaq
#    Predicción (Modelo):   bʼalaj ri kʼoʼbʼal, kʼo ri kʼoʼbʼal
#
# 40)
#    Entrada (Español):   La cocinera preparó muy bien la carne
#    Referencia (K'iche'):  Sibʼalaj jeʼlik xel ri tiʼj rumal ri bʼanal wa
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 41)
#    Entrada (Español):   Hay celebración en el pueblo
#    Referencia (K'iche'):  Pa ri tinamit kʼo nimaqʼijem
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 42)
#    Entrada (Español):   Mi tío viajó para Asia
#    Referencia (K'iche'):  Ri wikan bʼenaq qʼanamaqʼ
#    Predicción (Modelo):   bʼalaj ri Asia
#
# 43)
#    Entrada (Español):   El achote es caro
#    Referencia (K'iche'):  Paqal rajil ri kʼoxobʼ
#    Predicción (Modelo):   kʼoʼbʼal
#
# 44)
#    Entrada (Español):   Es necesario que se casen publicamente
#    Referencia (K'iche'):  Rajawaxik chisaqrisaj ri ikʼulanem
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 45)
#    Entrada (Español):   Mi tía usa el olote para el fuego
#    Referencia (K'iche'):  Ri nuchʼutinan kukoj ri piʼq pa ri qʼaqʼ
#    Predicción (Modelo):   kʼo kʼo kʼo ri kʼo
#
# 46)
#    Entrada (Español):   El instrumento para tejer ha estado conmigo desde hace tiempos
#    Referencia (K'iche'):  We tzʼulubʼ riʼ ojer chik kʼo wukʼ
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo kʼo kʼo ri kʼo
#
# 47)
#    Entrada (Español):   Nicolás dividió en tres su terreno
#    Referencia (K'iche'):  Ri a Kulax kubʼan pa oxibʼ ri rulew
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo
#
# 48)
#    Entrada (Español):   El tizne que está en el techo es bien espeso
#    Referencia (K'iche'):  Pim ri xaq kʼo chi uxe awiʼ ja
#    Predicción (Modelo):   kʼo kʼo kʼo ri kʼoʼbʼal
#
# 49)
#    Entrada (Español):   Mañana lo llevaré
#    Referencia (K'iche'):  Kinkʼam na bʼik chweʼq
#    Predicción (Modelo):
#
# 50)
#    Entrada (Español):   La brocha está muy angosta por eso no pinta bien
#    Referencia (K'iche'):  Nitzʼ uwach ri tzʼajibʼal rumal riʼ man utz taj ktzʼajnik
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo kʼo ri kʼo
#
# 51)
#    Entrada (Español):   La vaca le pertenece a Lucía
#    Referencia (K'iche'):  Ri wakax rech ri Luʼs
#    Predicción (Modelo):   ri Kʼoʼbʼal
#
# 52)
#    Entrada (Español):   La nieve quemó la siembra
#    Referencia (K'iche'):  Ri saqtew xukʼat ri tikoʼn
#    Predicción (Modelo):   kʼo ri kʼoʼbʼal
#
# 53)
#    Entrada (Español):   Cuando vengas, también traes a tu mamá
#    Referencia (K'iche'):  Are chiʼ katpetik xuqujeʼ kakʼam loq ri anan
#    Predicción (Modelo):   bʼalabʼalabʼalabʼalabʼalabʼalabʼal
#
# 54)
#    Entrada (Español):   Es necesario dividir el terreno entre los hijos
#    Referencia (K'iche'):  Rajawaxik kabʼan ri jachanem ulew chi kech ri alkʼwaʼlixelabʼ
#    Predicción (Modelo):   kʼo kʼo ri kʼoʼbʼal
#
# 55)
#    Entrada (Español):   El encendedor lo llevas siempre porque eres fumador
#    Referencia (K'iche'):  Awukʼaʼm junalik ri tzijbʼal rumal katubʼaj ri sikʼ
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo kʼo kʼo ri kʼo
#
# 56)
#    Entrada (Español):   Antonia está despeinada
#    Referencia (K'iche'):  Chʼiychʼik uwiʼ ri ali Toʼn
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 57)
#    Entrada (Español):   Mi hijastro me quiere
#    Referencia (K'iche'):  Kinraj ri nukʼojolabʼal
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 58)
#    Entrada (Español):   Me dice cualquier cosa que piensa
#    Referencia (K'iche'):  Ja such kuchomaj kubʼij chi we
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 59)
#    Entrada (Español):   Mañana te comento qué fue lo que pensé
#    Referencia (K'iche'):  Kintzijobʼej chi awe chweʼq jas xinchomaj
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo kʼo
#
# 60)
#    Entrada (Español):   El cuervo se llevó al pollo
#    Referencia (K'iche'):  Ri joj xukʼam bʼik ri akʼ
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 61)
#    Entrada (Español):   Hagamos nuestro trabajo
#    Referencia (K'iche'):  Chqabʼana ri qachak
#    Predicción (Modelo):   Kʼoʼbʼal
#
# 62)
#    Entrada (Español):   Este año sembré habas
#    Referencia (K'iche'):  Che we junabʼ xintik jawux
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 63)
#    Entrada (Español):   Todos los trabajadores llevan sus herramientas
#    Referencia (K'iche'):  Konojel ri ajchakibʼ kikʼam bʼik kichakubʼal
#    Predicción (Modelo):   kʼo kʼo ri kʼoʼbʼal
#
# 64)
#    Entrada (Español):   A los niños les hice un columpio enorme
#    Referencia (K'iche'):  Xinbʼan jun nim kitzaybʼal ri akʼalabʼ
#    Predicción (Modelo):   kʼo kʼo ri kʼoʼbʼal
#
# 65)
#    Entrada (Español):   Todos aplaudieron lo que dijo ella
#    Referencia (K'iche'):  Xpaqʼpaqapaʼ kiqʼabʼ chech xubʼij ri ali
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 66)
#    Entrada (Español):   Crecio la semilla de algodón en la milpa
#    Referencia (K'iche'):  Xkiy le tux pa le abʼix
#    Predicción (Modelo):   kʼo kʼo ri kʼoʼbʼal
#
# 67)
#    Entrada (Español):   Necesito la pala
#    Referencia (K'iche'):  Kinkoj ri jokbʼal ulew
#    Predicción (Modelo):   ri kʼoʼl
#
# 68)
#    Entrada (Español):   Regresaré aquí hasta el décimo séptimo día
#    Referencia (K'iche'):  Pa uwuqlajuj qʼij kintzalij loq waral
#    Predicción (Modelo):   kʼo kʼo kʼo ri kʼoʼbʼal
#
# 69)
#    Entrada (Español):   La cal me rajó la palma de la mano
#    Referencia (K'iche'):  Ri chun xuya salkʼam pa ri nuqʼabʼ
#    Predicción (Modelo):   kʼo kʼo ri kʼo
#
# 70)
#    Entrada (Español):   No es muy común el pino rojo
#    Referencia (K'iche'):  Man kʼi taj ri kaq chaj
#    Predicción (Modelo):   kʼo kʼo ri kʼo
#
# 71)
#    Entrada (Español):   ¿Vendrás con nosotros mañana?
#    Referencia (K'iche'):  ¿La katpe qukʼ chweʼq?
#    Predicción (Modelo):   bʼalaj ri kʼabʼal?
#
# 72)
#    Entrada (Español):   La hinchazón de la pierna ya mejoró
#    Referencia (K'iche'):  Ri sipojem kʼo chech ri raqan utz chik
#    Predicción (Modelo):   kʼo kʼo ri kʼoʼbʼal
#
# 73)
#    Entrada (Español):   En la cueva hay agua
#    Referencia (K'iche'):  Chi upam ri pek kʼo jaʼ
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 74)
#    Entrada (Español):   Tomás es de Canillá
#    Referencia (K'iche'):  Ri Max are aj qʼan iyaʼ
#    Predicción (Modelo):   Kʼoʼbʼal
#
# 75)
#    Entrada (Español):   Escribe los refranes que sabes
#    Referencia (K'iche'):  chtzʼibʼaj janipa noʼjibʼal tzij awetaʼm
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 76)
#    Entrada (Español):   Los bailadores danzan
#    Referencia (K'iche'):  Kexojow ri ajxojolobʼ
#    Predicción (Modelo):   ri bʼaʼl
#
# 77)
#    Entrada (Español):   El médico vive en la orilla de El Triángulo
#    Referencia (K'iche'):  Ri ajkun kel chuchiʼ ri oxtzalaj
#    Predicción (Modelo):   Kʼoʼbʼal ri Kʼoʼbʼal
#
# 78)
#    Entrada (Español):   Aún hay un poquito en la olla
#    Referencia (K'iche'):  Kʼo juchʼin chi upam ri tʼuʼy
#    Predicción (Modelo):   bʼalaj ri ajbʼal
#
# 79)
#    Entrada (Español):   El pájaro torcaza está comiendo el trigo
#    Referencia (K'iche'):  Ri tukumux tajin kutij ri triko
#    Predicción (Modelo):   kʼo kʼo kʼo ri kʼoʼbʼal
#
# 80)
#    Entrada (Español):   Está cerrado el cajón para que no le entre arena blanca
#    Referencia (K'iche'):  Tzʼapim uwiʼ ri kaxon rech man kok ta poqlaj chi upam
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo kʼo kʼo
#
# 81)
#    Entrada (Español):   Ahora ya no se usan los arcos ni las flechas
#    Referencia (K'iche'):  Kamik man kkoj ta chik ri chʼabʼ
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo kʼo kʼo
#
# 82)
#    Entrada (Español):   Miguel dejó preparado el tablón para sembrar
#    Referencia (K'iche'):  Xubʼan kanoq ri lochʼoj rech tikonijik ri a Kel
#    Predicción (Modelo):   kʼo kʼo ri kʼoʼbʼal
#
# 83)
#    Entrada (Español):   La cola de caballo es medicinal
#    Referencia (K'iche'):  Kunabʼal ri kʼibʼ
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 84)
#    Entrada (Español):   Mi mamá me perdonó
#    Referencia (K'iche'):  Xusach numak ri nunan
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 85)
#    Entrada (Español):   El arrebatador me quitó mi dinero
#    Referencia (K'iche'):  Ri majanel xumaj nurajil
#    Predicción (Modelo):   kʼo ri kʼoʼbʼal
#
# 86)
#    Entrada (Español):   Soy el cuarto hermano de los hijos de mi mamá
#    Referencia (K'iche'):  In ukaj achalal chi kixoʼl ral ri nunan
#    Predicción (Modelo):   ri kʼoʼbʼal kʼoʼbʼal
#
# 87)
#    Entrada (Español):   Escribió su renuncia
#    Referencia (K'iche'):  Xutzʼibʼaj ri uwuj rech resabʼal ibʼ
#    Predicción (Modelo):   ri kʼoʼl
#
# 88)
#    Entrada (Español):   Es lindo permanecer en tu casa
#    Referencia (K'iche'):  Jeʼl kʼolem chi awachoch
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 89)
#    Entrada (Español):   ¿Sabes de color es el canario
#    Referencia (K'iche'):  Awilom jas rij ri tzʼikin ubʼiʼ chowix
#    Predicción (Modelo):   kʼoʼbʼal
#
# 90)
#    Entrada (Español):   Se cansó su nalga por estar sentado
#    Referencia (K'iche'):  Xqʼiʼtaj ri rachaq che ri tʼuyalem
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo ri kʼo
#
# 91)
#    Entrada (Español):   Me duele la espalda por estar agachado
#    Referencia (K'iche'):  Kʼax wij rumal in pachalik
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo kʼo
#
# 92)
#    Entrada (Español):   Me pongo de cuclillas para hacer mi trabajo
#    Referencia (K'iche'):  Kinchʼukiʼk chech ubʼanik nuchak
#    Predicción (Modelo):   kʼo kʼo kʼo ri kʼo
#
# 93)
#    Entrada (Español):   El canasto pesa mucho
#    Referencia (K'iche'):  Al ri chakach
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 94)
#    Entrada (Español):   El denunciante reconoció al ladrón
#    Referencia (K'iche'):  Ri tzujunel xuchʼobʼ uwach ri elaqʼom
#    Predicción (Modelo):   kʼo ri kʼoʼbʼal
#
# 95)
#    Entrada (Español):   Todavía quedó un sobrante
#    Referencia (K'iche'):  Xkanaj na kanoq ri chʼaqaʼp
#    Predicción (Modelo):   ri kʼoʼbʼal
#
# 96)
#    Entrada (Español):   El pescado seco es muy salado
#    Referencia (K'iche'):  Ri chaqiʼj kar sibʼalaj ratzʼamil
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo
#
# 97)
#    Entrada (Español):   En la comunidad de Panimaché vive don Pedro Tzʼalam
#    Referencia (K'iche'):  Luʼ Tzʼalam ubʼiʼ ri achi kel Pa nim Cheʼ
#    Predicción (Modelo):   Kʼo kʼo ri Tzʼalam
#
# 98)
#    Entrada (Español):   Acerca el petate a la orilla del fuego
#    Referencia (K'iche'):  Chaqibʼisaj ri sepalibʼal chi uchiʼ ri qʼaqʼ
#    Predicción (Modelo):   kʼo kʼo ri kʼoʼbʼal
#
# 99)
#    Entrada (Español):   Cuando viajo a otros lados tengo que pagar hospedaje
#    Referencia (K'iche'):  Are chiʼ kinbʼek pa jun tinamit chik kintoj ri nuwarbʼal ja
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo kʼo kʼo kʼo kʼo
#
# 100)
#    Entrada (Español):   Déjalo así, es suficiente
#    Referencia (K'iche'):  Chyaʼ kan je laʼ, rukʼ laʼ
#    Predicción (Modelo):   ri kʼoʼbʼal
#
#
# --- Calculando Métricas de Evaluación ---
#
# 📊 Puntuación BLEU:
#    BLEU: 0.00
#
# 📊 Puntuación ROUGE:
#    ROUGE-1: 15.74
#    ROUGE-2: 1.96
#    ROUGE-L: 14.45

# %% [markdown]
# ### 3. Modelo con Finetuning Inglés-Kiche

# %% [markdown]
# #### 3.1 CREACIÓN DEL DATASET SINTÉTICO usando el modelo Zero-Shot
#
# Tenemos que fábricar las palabras nuevas, convertir un par (Español, K'iche') en un par (Inglés, K'iche'). Para esto usamos el modelo Zero-Shot para obtener las traducciones pertinentes

# %%
def build_en_quc_split(split, model, tokenizer, dataset):

    print(dataset["train"][8])
    new_inputs = []
    new_targets = []

    print(f"🔄 Traduciendo split '{split}' de español a inglés...\n")
    for example in tqdm(dataset[split]):
        espanol_text = example["target"]
        kiche_text = example["input"]
        english_text = translate_text(model, tokenizer, espanol_text, "spa_Latn", "eng_Latn")
        new_inputs.append(english_text)
        new_targets.append(kiche_text)

    return Dataset.from_dict({
        "input": new_inputs,
        "target": new_targets
    })

# Generar splits
dataset_variable_name = f"es_{TARGET_LANG_SHORT_CODE}_dataset"
es_target_dataset = globals().get(dataset_variable_name)

if es_target_dataset is None:
    raise NameError(f"Dataset variable '{dataset_variable_name}' not found. Please ensure the dataset for {PIVOT_LANG_NAME}-{TARGET_LANG_NAME} is generated and named correctly.")


en_quc_train = build_en_quc_split("train", zeroshot_model, zeroshot_tokenizer, es_target_dataset)
en_quc_test = build_en_quc_split("test", zeroshot_model, zeroshot_tokenizer, es_target_dataset)

# Combinar
en_quc_dataset = DatasetDict({
    "train": en_quc_train,
    "test": en_quc_test
})
# Out:
# {'input': 'Ri tat Xwan potzʼ', 'target': '#quc# Don Juan está ciego'}
# 🔄 Traduciendo split 'train' de español a inglés...
# 100%|██████████| 624/624 [25:55<00:00,  2.49s/it]
# {'input': 'Ri tat Xwan potzʼ', 'target': '#quc# Don Juan está ciego'}
# 🔄 Traduciendo split 'test' de español a inglés...
# 100%|██████████| 1000/1000 [40:34<00:00,  2.43s/it]

# %% [markdown]
# #### 3.2 SAVE Dataset

# %%
def save_en_quc_dataset_to_files(dataset: DatasetDict, output_directory: str):
    """
    Saves the English-K'iche' dataset splits (train, test) into separate .en and .quc files.

    Args:
        dataset (DatasetDict): The dataset object containing 'train' and 'test' splits,
                               where each example has 'input' (English) and 'target' (K'iche').
        output_directory (str): The path to the directory where the files will be saved.
                                This directory will be created if it doesn't exist.
    """
    if not isinstance(dataset, DatasetDict):
        print(f"❌ Error: Expected 'dataset' to be a DatasetDict, but got {type(dataset)}")
        return

    # Create the output directory if it doesn't exist
    os.makedirs(output_directory, exist_ok=True)
    print(f"Ensuring output directory exists: {output_directory}")

    try:
        # Save each split (train, test) into .en (English) and .quc (K'iche') files
        for split in ["train", "test"]:
            if split not in dataset:
                print(f"⚠️ Warning: Split '{split}' not found in the dataset. Skipping.")
                continue

            # Check if 'input' and 'target' keys exist in the first example of the split
            # This is a basic check to ensure the expected structure
            if dataset[split] and ("input" not in dataset[split][0] or "target" not in dataset[split][0]):
                print(f"❌ Error: Expected 'input' and 'target' keys in dataset[{split}] examples. Skipping.")
                continue

            file_path_en = os.path.join(output_directory, f"{split}.en")
            file_path_quc = os.path.join(output_directory, f"{split}.quc")

            with open(file_path_en, "w", encoding="utf-8") as f_en, \
                 open(file_path_quc, "w", encoding="utf-8") as f_quc:

                for example in dataset[split]:
                    f_en.write(example["input"].strip() + "\n")
                    f_quc.write(example["target"].strip() + "\n")

            print(f"✅ Files '{split}.en' and '{split}.quc' saved to {output_directory}")

        print(f"✅ All .en and .quc files processed and saved to {output_directory}")

    except Exception as e:
        print(f"❌ An error occurred while saving the files: {e}")

# %%
save_en_quc_dataset_to_files(en_quc_dataset, EN_QUC_DATASET_FILES_PATH)
# Out:
# Ensuring output directory exists: /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/en_quc_dataset_files
# ✅ Files 'train.en' and 'train.quc' saved to /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/en_quc_dataset_files
# ✅ Files 'test.en' and 'test.quc' saved to /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/en_quc_dataset_files
# ✅ All .en and .quc files processed and saved to /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/en_quc_dataset_files

# %%
# prompt: save en_quc_dataset to disk (Dataset)

en_quc_dataset.save_to_disk(f"{DRIVE_PATH}/en_quc_dataset")
print(f"✅ Dataset 'en_quc_dataset' saved to disk at: {DRIVE_PATH}/en_quc_dataset")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/624 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1000 [00:00<?, ? examples/s]
# ✅ Dataset 'en_quc_dataset' saved to disk at: /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/en_quc_dataset

# %% [markdown]
# #### 3.3 Preparación y entrenamiento

# %% [markdown]
# ##### Verificamos el dataset

# %%
en_quc_dataset["train"][1:10]
# Out:
# {'input': ['The branch is cut',
#   'In coastal I keep the mazorca',
#   'The napkin was pierced by the stove',
#   'We must take care of our nervous system',
#   'What  You brought my order',
#   "Today it's expensive to pick up the ground",
#   'Bread went up in price',
#   'Don Juan is blind',
#   "After tomorrow I'll go with you"],
#  'target': ['Ketom ri uqʼabʼ ri cheʼ',
#   'Pa taq ri bʼrin kinkʼol wi ri jal',
#   'Ri suʼt teqʼtobʼinaq rumal ri rachaq qʼaqʼ',
#   'Chqachijij bʼa ri qibʼochil',
#   'Xakʼam loq ri wuqxaʼn',
#   'Paqal rajil ri joxkʼim che ri ulew',
#   'Ri kaxlaʼn wa xpaqiʼ rajil',
#   'Ri tat Xwan potzʼ',
#   'Kinbʼe awukʼ kabʼij']}

# %% [markdown]
# ##### Preparacion

# %%
model_name = "facebook/nllb-200-distilled-600M"
en_quc_tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)

# 1. Añadir el token especial al tokenizador
print(f"Añadiendo el token especial: {TARGET_LANG_CODE}")
en_quc_tokenizer.add_special_tokens({'additional_special_tokens': [TARGET_LANG_CODE]})

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4"
)

base_model = AutoModelForSeq2SeqLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto"
)

# 2. Redimensionar los embeddings del modelo
print("Redimensionando embeddings del modelo...")
base_model.resize_token_embeddings(len(finetune_tokenizer))

lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.1,
    bias="none",
    task_type=TaskType.SEQ_2_SEQ_LM
)

en_quc_model = get_peft_model(base_model, lora_config)
# Out:
# Añadiendo el token especial: quc_Latn
# Redimensionando embeddings del modelo...

# %%
def preprocess_function_en_quc(examples):
    max_length = 128
    inputs = en_quc_tokenizer(examples["input"], max_length=max_length, truncation=True, padding="max_length")
    targets = en_quc_tokenizer(examples["target"], max_length=max_length, truncation=True, padding="max_length")
    inputs["labels"] = targets["input_ids"]
    return inputs

tokenized_en_quc_train = en_quc_dataset["train"].map(preprocess_function_en_quc, batched=True)
tokenized_en_quc_test = en_quc_dataset["test"].map(preprocess_function_en_quc, batched=True)
# Out:
# Map:   0%|          | 0/624 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
training_args_en_quc = TrainingArguments(
    output_dir=f"{DRIVE_PATH}/finetuned_en_quc_nllb",
    eval_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=120,
    weight_decay=0.01,
    save_total_limit=2,
    save_strategy="epoch",
    logging_dir="./logs_en_quc",
    logging_steps=100,
    report_to="none" # Disable reporting to wandb
)

"""
training_args = TrainingArguments(
    output_dir="./qlora_finetuned_qum_nllb",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=3,
    learning_rate=2e-4,
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_dir="./logs_qlora",
    save_total_limit=2,
    bf16=False,
    fp16=True,
    report_to="none"
)
"""
# Out:
# '\ntraining_args = TrainingArguments(\n    output_dir="./qlora_finetuned_qum_nllb",\n    per_device_train_batch_size=4,\n    per_device_eval_batch_size=4,\n    num_train_epochs=3,\n    learning_rate=2e-4,\n    eval_strategy="epoch",\n    save_strategy="epoch",\n    logging_dir="./logs_qlora",\n    save_total_limit=2,\n    bf16=False,\n    fp16=True,\n    report_to="none"\n)\n'

# %%
"""


trainer = Trainer(
    model=finetune_model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_test,
    tokenizer=finetune_tokenizer,
)
"""


trainer_en_quc = Trainer(
    model=en_quc_model,
    args=training_args_en_quc,
    train_dataset=tokenized_en_quc_train,
    eval_dataset=tokenized_en_quc_test,
    tokenizer=en_quc_tokenizer,
)



trainer_en_quc.train()

# Define the save path for the EN-QUC model
save_path_en_quc = f"{DRIVE_PATH}/finetuned_en_quc_nllb"

# Save the model and tokenizer to the specified path
en_quc_model.save_pretrained(save_path_en_quc)
en_quc_tokenizer.save_pretrained(save_path_en_quc)

print(f"✅ EN-QUC model and tokenizer saved to {save_path_en_quc}")
# Out:
# /tmp/ipython-input-121-489488295.py:14: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer_en_quc = Trainer(
# No label_names provided for model class `PeftModelForSeq2SeqLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#     <div>
#
#       <progress value='9360' max='9360' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9360/9360 2:51:00, Epoch 120/120]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>8.223432</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>8.766200</td>
#       <td>7.792833</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>8.099500</td>
#       <td>7.569084</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>7.777100</td>
#       <td>7.460209</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>7.777100</td>
#       <td>7.402180</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>7.640400</td>
#       <td>7.369818</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>7.564700</td>
#       <td>7.348089</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>7.506100</td>
#       <td>7.332586</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>7.478900</td>
#       <td>7.320503</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>7.478900</td>
#       <td>7.309731</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>7.445100</td>
#       <td>7.299947</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>7.425000</td>
#       <td>7.290873</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>7.406400</td>
#       <td>7.282734</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>7.406400</td>
#       <td>7.275209</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>7.385700</td>
#       <td>7.268419</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>7.371700</td>
#       <td>7.263220</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>7.359600</td>
#       <td>7.256552</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>7.348200</td>
#       <td>7.252360</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>7.348200</td>
#       <td>7.247446</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>7.337500</td>
#       <td>7.242632</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>7.326000</td>
#       <td>7.238146</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>7.319300</td>
#       <td>7.234600</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>7.319300</td>
#       <td>7.231378</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>7.314600</td>
#       <td>7.228558</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>7.303500</td>
#       <td>7.224638</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>7.289400</td>
#       <td>7.222746</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>7.293000</td>
#       <td>7.219496</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>7.293000</td>
#       <td>7.217919</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>7.281900</td>
#       <td>7.215232</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>7.276000</td>
#       <td>7.213384</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>7.274100</td>
#       <td>7.210755</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>7.274100</td>
#       <td>7.210201</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>7.269700</td>
#       <td>7.208130</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>7.260700</td>
#       <td>7.205552</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>7.263000</td>
#       <td>7.205152</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>7.253000</td>
#       <td>7.202670</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>7.253000</td>
#       <td>7.201580</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>7.258200</td>
#       <td>7.200155</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>7.250300</td>
#       <td>7.198788</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>7.247300</td>
#       <td>7.197286</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>7.247300</td>
#       <td>7.196349</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>7.241300</td>
#       <td>7.195555</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>7.241500</td>
#       <td>7.194537</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>7.238000</td>
#       <td>7.193621</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>7.233500</td>
#       <td>7.192542</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>7.233500</td>
#       <td>7.191772</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>7.233500</td>
#       <td>7.191033</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>7.226100</td>
#       <td>7.189682</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>7.228900</td>
#       <td>7.188456</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>7.226800</td>
#       <td>7.187545</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>7.226800</td>
#       <td>7.187349</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>7.219400</td>
#       <td>7.186422</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>7.219300</td>
#       <td>7.186157</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>7.222800</td>
#       <td>7.185101</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>7.222800</td>
#       <td>7.185460</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>7.213200</td>
#       <td>7.184822</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>7.215700</td>
#       <td>7.184242</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>7.213500</td>
#       <td>7.183427</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>7.209600</td>
#       <td>7.182601</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>7.209600</td>
#       <td>7.182405</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>7.208700</td>
#       <td>7.182082</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>7.208400</td>
#       <td>7.181592</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>7.207600</td>
#       <td>7.181325</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>7.207600</td>
#       <td>7.180993</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>7.207200</td>
#       <td>7.180232</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>7.199700</td>
#       <td>7.179525</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>7.202800</td>
#       <td>7.179781</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>7.198500</td>
#       <td>7.179308</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>7.198500</td>
#       <td>7.179329</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>7.201200</td>
#       <td>7.178555</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>7.196500</td>
#       <td>7.178199</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>7.200400</td>
#       <td>7.177935</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>7.200400</td>
#       <td>7.177860</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>7.193500</td>
#       <td>7.177269</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>7.195500</td>
#       <td>7.176922</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>7.194700</td>
#       <td>7.176935</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>7.188300</td>
#       <td>7.176466</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>7.188300</td>
#       <td>7.176715</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>7.197900</td>
#       <td>7.176004</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>7.185700</td>
#       <td>7.175699</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>7.190500</td>
#       <td>7.175490</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>7.190500</td>
#       <td>7.175282</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>7.187600</td>
#       <td>7.175182</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>7.184800</td>
#       <td>7.174980</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>7.187500</td>
#       <td>7.174699</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>7.184400</td>
#       <td>7.174567</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>7.184400</td>
#       <td>7.174199</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>7.191300</td>
#       <td>7.174249</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>7.186800</td>
#       <td>7.173735</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>7.183800</td>
#       <td>7.173848</
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:252: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# ✅ EN-QUC model and tokenizer saved to /content/drive/MyDrive/Colab Notebooks/Proyecto_DL_Traduccion/finetuned_en_quc_nllb

# %%
import torch
from tqdm import tqdm
import evaluate # Librería para métricas

# --- 1. CONFIGURACIÓN DE LA EVALUACIÓN ---
print("--- Configurando la evaluación del modelo final ---")

# Modelo y Tokenizador a evaluar (tus variables del entrenamiento)
model_to_test = finetune_model
tokenizer_to_use = finetune_tokenizer

# Dataset de prueba (asegúrate de que sea la versión limpia)
dataset_to_test = en_quc_dataset["test"]

# Dirección de la traducción
SOURCE_LANG_CODE = "eng_Latn"  # Ingles
TARGET_LANG_CODE = "quc_Latn"   # K'iche'

# Obtenemos el ID de idioma correcto para K'iche'
forced_bos_id = tokenizer_to_use.convert_tokens_to_ids(TARGET_LANG_CODE)
print(f"Modelo a evaluar: 'finetune_model'")
print(f"Traduciendo de: {SOURCE_LANG_CODE} -> {TARGET_LANG_CODE}")
print(f"ID de idioma forzado para K'iche': {forced_bos_id}")


# --- 2. FUNCIÓN DE GENERACIÓN DE PREDICCIONES ---
def generate_predictions(model, tokenizer, dataset, n_examples=None):
    predictions = []
    references = []

    model.eval()
    device = model.device

    if n_examples is None:
        n_examples = len(dataset)
    num_samples = min(n_examples, len(dataset))

    print(f"\nGenerando {num_samples} predicciones...")
    for i in tqdm(range(num_samples)):
        item = dataset[i]

        # La entrada es el Ingles y la referencia es el K'iche'
        input_text = item["input"]   # Columna de Ingles
        reference_text = item["target"]  # Columna de k'iche'

        inputs = tokenizer(input_text, return_tensors="pt", truncation=True, max_length=128).to(device)

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                forced_bos_token_id=forced_bos_id,
                max_length=128,
                num_beams=5,
                early_stopping=True
            )

        pred = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]

        predictions.append(pred)
        references.append(reference_text)

    return predictions, references


# --- 3. EJECUCIÓN Y VISUALIZACIÓN ---
predictions, references = generate_predictions(
    model_to_test,
    tokenizer_to_use,
    dataset_to_test,
    n_examples=100 # Usamos 20 ejemplos para una prueba visual rápida
)

print("\n\n--- Muestra de Traducciones del Modelo Final ---")
for i in range(len(predictions)):
    print(f"\n{i+1})")
    print(f"   Entrada (Ingles):   {dataset_to_test[i]['input']}")
    print(f"   Referencia (K'iche'):  {references[i]}")
    print(f"   Predicción (Modelo):   {predictions[i]}")


# --- 4. CÁLCULO DE MÉTRICAS AUTOMÁTICAS ---
print("\n\n--- Calculando Métricas de Evaluación ---")

bleu = evaluate.load("bleu")
rouge = evaluate.load("rouge")

bleu_score = bleu.compute(predictions=predictions, references=[[ref] for ref in references])
rouge_score = rouge.compute(predictions=predictions, references=references)

print("\n📊 Puntuación BLEU:")
print(f"   BLEU: {bleu_score['bleu'] * 100:.2f}")

print("\n📊 Puntuación ROUGE:")
print(f"   ROUGE-1: {rouge_score['rouge1'] * 100:.2f}")
print(f"   ROUGE-2: {rouge_score['rouge2'] * 100:.2f}")
print(f"   ROUGE-L: {rouge_score['rougeL'] * 100:.2f}")
# Out:
# --- Configurando la evaluación del modelo final ---
# Modelo a evaluar: 'finetune_model'
# Traduciendo de: eng_Latn -> quc_Latn
# ID de idioma forzado para K'iche': 256204
#
# Generando 100 predicciones...
# 100%|██████████| 100/100 [01:04<00:00,  1.55it/s]
# --- Muestra de Traducciones del Modelo Final ---
#
# 1)
#    Entrada (Ingles):   You have indigestion
#    Referencia (K'iche'):  Kqʼulqʼut ri apam
#    Predicción (Modelo):
#
# 2)
#    Entrada (Ingles):   The squirrel escaped
#    Referencia (K'iche'):  Xanimaj bʼik ri kuk
#    Predicción (Modelo):
#
# 3)
#    Entrada (Ingles):   What's up?  Your brother-in-law is swimming
#    Referencia (K'iche'):  Tajin kamuxan ri awecham
#    Predicción (Modelo):   ri?
#
# 4)
#    Entrada (Ingles):   On the coast I got malaria
#    Referencia (K'iche'):  Xinriq raxtew pa taqʼaj
#    Predicción (Modelo):
#
# 5)
#    Entrada (Ingles):   I'm coming with him to make wood in the mountain
#    Referencia (K'iche'):  Xinpe rukʼ chech ubʼanik siʼ, pa ri juyubʼ
#    Predicción (Modelo):
#
# 6)
#    Entrada (Ingles):   The gentleman has itching feet
#    Referencia (K'iche'):  Kʼo kʼaqat chi raqan ri tataʼ
#    Predicción (Modelo):
#
# 7)
#    Entrada (Ingles):   You need to learn about the toilet
#    Referencia (K'iche'):  Rajwaxik kawetaʼmaj pa uwiʼ ri chʼajchʼojisanem
#    Predicción (Modelo):   kʼo kʼoch
#
# 8)
#    Entrada (Ingles):   The chilacayote is big
#    Referencia (K'iche'):  Nim ri qʼoqʼ
#    Predicción (Modelo):   chilacayote
#
# 9)
#    Entrada (Ingles):   Clear yourself up to the people
#    Referencia (K'iche'):  Chqʼalajisaj awibʼ chi kiwach ri tinamit
#    Predicción (Modelo):
#
# 10)
#    Entrada (Ingles):   You rush to your homework
#    Referencia (K'iche'):  Kakowij che ri apatan
#    Predicción (Modelo):
#
# 11)
#    Entrada (Ingles):   The stone is light
#    Referencia (K'iche'):  Ri abʼaj yatzalik
#    Predicción (Modelo):   Kʼoʼn
#
# 12)
#    Entrada (Ingles):   In the mountains there are many children's feet
#    Referencia (K'iche'):  Pa juyubʼ Sibʼalaj raqan neʼ kʼolik
#    Predicción (Modelo):   kʼoqʼij
#
# 13)
#    Entrada (Ingles):   We don't have a national curriculum
#    Referencia (K'iche'):  Man kʼo ta jun nukʼubʼal chak Amaqʼ
#    Predicción (Modelo):
#
# 14)
#    Entrada (Ingles):   I'm very angry
#    Referencia (K'iche'):  Sibʼalaj xinkʼaʼnarik
#    Predicción (Modelo):
#
# 15)
#    Entrada (Ingles):   What  I'd like to hug you
#    Referencia (K'iche'):  Kinwaj katinqʼaluj
#    Predicción (Modelo):   'bʼik ri kʼo
#
# 16)
#    Entrada (Ingles):   You gotta peel the potatoes
#    Referencia (K'iche'):  Chsoloʼ rij taq saqwach
#    Predicción (Modelo):   chʼiʼl
#
# 17)
#    Entrada (Ingles):   What's that?  The chocoo eats elots
#    Referencia (K'iche'):  Ri kʼel kutij aj
#    Predicción (Modelo):   kʼo?
#
# 18)
#    Entrada (Ingles):   I have to make a construction here
#    Referencia (K'iche'):  Kinbʼan na jun tzʼaq chi riʼ
#    Predicción (Modelo):   ʼlaʼbʼalaj
#
# 19)
#    Entrada (Ingles):   What did you say to me?
#    Referencia (K'iche'):  Su xabʼij chi wech?
#    Predicción (Modelo):   ?
#
# 20)
#    Entrada (Ingles):   Toys are too expensive
#    Referencia (K'iche'):  Paqal rajil ri taq etzʼabʼaʼl
#    Predicción (Modelo):
#
# 21)
#    Entrada (Ingles):   What  My partner is happy
#    Referencia (K'iche'):  Kkiʼkot ri nukʼulaj
#    Predicción (Modelo):
#
# 22)
#    Entrada (Ingles):   You're careful when you walk down the street
#    Referencia (K'iche'):  Kachajij awibʼ pa taq uqʼabʼ uxoʼl bʼe
#    Predicción (Modelo):   kʼo kʼo kʼo ri
#
# 23)
#    Entrada (Ingles):   The middle-cincan wild plant cured me
#    Referencia (K'iche'):  Xukunaj nupam ri ojolom ikox
#    Predicción (Modelo):
#
# 24)
#    Entrada (Ingles):   The membrane is very acidic
#    Referencia (K'iche'):  Sibʼalaj chʼam ri amprino
#    Predicción (Modelo):
#
# 25)
#    Entrada (Ingles):   The heat makes me very thirsty
#    Referencia (K'iche'):  Ri qʼaqʼ kuya chaqiʼj chiʼ chi wech
#    Predicción (Modelo):
#
# 26)
#    Entrada (Ingles):   The lady
#    Referencia (K'iche'):  Ri ixoq bʼenaq rukʼ ri ajkun rumal che kqʼaxow ri uchuch upam
#    Predicción (Modelo):
#
# 27)
#    Entrada (Ingles):   I sold the pig for 220 quetzal
#    Referencia (K'iche'):  Xinkʼayij bʼik ri aq rukʼ julajkʼal qʼuqʼ
#    Predicción (Modelo):   kʼo kʼetzal
#
# 28)
#    Entrada (Ingles):   Francis went too far
#    Referencia (K'iche'):  Naj xbʼe wi ri a Siʼs
#    Predicción (Modelo):
#
# 29)
#    Entrada (Ingles):   My axe was returned
#    Referencia (K'iche'):  Xkitzalij ri wikaj
#    Predicción (Modelo):
#
# 30)
#    Entrada (Ingles):   It's too thick the tip of the stick
#    Referencia (K'iche'):  Sorosik ubʼanom ri uwiʼ le cheʼ
#    Predicción (Modelo):   kʼo kʼo
#
# 31)
#    Entrada (Ingles):   the ring got lost in the zacate
#    Referencia (K'iche'):  Xtzaqik ri mulqʼabʼ pa ri qʼayes
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo
#
# 32)
#    Entrada (Ingles):   The man is naked
#    Referencia (K'iche'):  Chʼanal ri achi
#    Predicción (Modelo):
#
# 33)
#    Entrada (Ingles):   There are stars in the sky
#    Referencia (K'iche'):  Kʼo chʼumil chi uwach ri kaj
#    Predicción (Modelo):
#
# 34)
#    Entrada (Ingles):   The bait is good for hand cracks
#    Referencia (K'iche'):  Ri xepu utz kkoj che ri pixnaq qʼabʼaj
#    Predicción (Modelo):   kʼoqʼ ri kʼo
#
# 35)
#    Entrada (Ingles):   My sister is learning typography
#    Referencia (K'iche'):  Tajin karetaʼmaj aninaq tzʼibʼ ri wanabʼ
#    Predicción (Modelo):   kʼo kʼo kʼo
#
# 36)
#    Entrada (Ingles):   The girl is crazy
#    Referencia (K'iche'):  Sibʼalaj mox ri ali
#    Predicción (Modelo):
#
# 37)
#    Entrada (Ingles):   What's your son-in-law's name?
#    Referencia (K'iche'):  ¿Jas ubʼiʼ ri ajiʼatz?
#    Predicción (Modelo):   ? ¿Tzʼij?
#
# 38)
#    Entrada (Ingles):   The wood I left blown up in the hallway
#    Referencia (K'iche'):  Xintun kan ri siʼ pa raqan ja
#    Predicción (Modelo):
#
# 39)
#    Entrada (Ingles):   When you see twins give them money, because your clothes are stitched
#    Referencia (K'iche'):  We keʼawil yoʼx chasipaj kirajil we man kasipaj, kkibʼan kʼax che ri awatzʼiyaq
#    Predicción (Modelo):   taqʼiʼ ri xbʼal,
#
# 40)
#    Entrada (Ingles):   The cook cook prepared the meat very well
#    Referencia (K'iche'):  Sibʼalaj jeʼlik xel ri tiʼj rumal ri bʼanal wa
#    Predicción (Modelo):
#
# 41)
#    Entrada (Ingles):   There's a celebration in the village
#    Referencia (K'iche'):  Pa ri tinamit kʼo nimaqʼijem
#    Predicción (Modelo):
#
# 42)
#    Entrada (Ingles):   My uncle traveled to Asia
#    Referencia (K'iche'):  Ri wikan bʼenaq qʼanamaqʼ
#    Predicción (Modelo):   ri Asia
#
# 43)
#    Entrada (Ingles):   The achote is expensive
#    Referencia (K'iche'):  Paqal rajil ri kʼoxobʼ
#    Predicción (Modelo):   kʼoxoʼ
#
# 44)
#    Entrada (Ingles):   You need to get married publicly
#    Referencia (K'iche'):  Rajawaxik chisaqrisaj ri ikʼulanem
#    Predicción (Modelo):
#
# 45)
#    Entrada (Ingles):   My aunt uses the fire plow
#    Referencia (K'iche'):  Ri nuchʼutinan kukoj ri piʼq pa ri qʼaqʼ
#    Predicción (Modelo):
#
# 46)
#    Entrada (Ingles):   The weaving instrument has been with me for a long time
#    Referencia (K'iche'):  We tzʼulubʼ riʼ ojer chik kʼo wukʼ
#    Predicción (Modelo):
#
# 47)
#    Entrada (Ingles):   Nicholas divided his land in three
#    Referencia (K'iche'):  Ri a Kulax kubʼan pa oxibʼ ri rulew
#    Predicción (Modelo):
#
# 48)
#    Entrada (Ingles):   The tizz that's on the roof is pretty thick
#    Referencia (K'iche'):  Pim ri xaq kʼo chi uxe awiʼ ja
#    Predicción (Modelo):   kʼo kʼo kʼo
#
# 49)
#    Entrada (Ingles):   Tomorrow I'll take him
#    Referencia (K'iche'):  Kinkʼam na bʼik chweʼq
#    Predicción (Modelo):   wujal
#
# 50)
#    Entrada (Ingles):   The brooch is too narrow so it doesn't look good
#    Referencia (K'iche'):  Nitzʼ uwach ri tzʼajibʼal rumal riʼ man utz taj ktzʼajnik
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo
#
# 51)
#    Entrada (Ingles):   The cow belongs to Lucia
#    Referencia (K'iche'):  Ri wakax rech ri Luʼs
#    Predicción (Modelo):
#
# 52)
#    Entrada (Ingles):   The snow burned the seed
#    Referencia (K'iche'):  Ri saqtew xukʼat ri tikoʼn
#    Predicción (Modelo):
#
# 53)
#    Entrada (Ingles):   When you come, bring your mom too
#    Referencia (K'iche'):  Are chiʼ katpetik xuqujeʼ kakʼam loq ri anan
#    Predicción (Modelo):   kʼo chʼam
#
# 54)
#    Entrada (Ingles):   It's necessary to divide the land between the children
#    Referencia (K'iche'):  Rajawaxik kabʼan ri jachanem ulew chi kech ri alkʼwaʼlixelabʼ
#    Predicción (Modelo):   maʼbʼalaj chʼij
#
# 55)
#    Entrada (Ingles):   What  You always wear the lighter because you're a smoker
#    Referencia (K'iche'):  Awukʼaʼm junalik ri tzijbʼal rumal katubʼaj ri sikʼ
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo kʼo kʼo kʼo taj
#
# 56)
#    Entrada (Ingles):   Antonia is naked
#    Referencia (K'iche'):  Chʼiychʼik uwiʼ ri ali Toʼn
#    Predicción (Modelo):
#
# 57)
#    Entrada (Ingles):   What  My stepson loves me
#    Referencia (K'iche'):  Kinraj ri nukʼojolabʼal
#    Predicción (Modelo):   ʼtzʼalaj
#
# 58)
#    Entrada (Ingles):   Tell me anything you think
#    Referencia (K'iche'):  Ja such kuchomaj kubʼij chi we
#    Predicción (Modelo):
#
# 59)
#    Entrada (Ingles):   Tomorrow I'll tell you what I thought
#    Referencia (K'iche'):  Kintzijobʼej chi awe chweʼq jas xinchomaj
#    Predicción (Modelo):   qʼij
#
# 60)
#    Entrada (Ingles):   The raven took the chicken
#    Referencia (K'iche'):  Ri joj xukʼam bʼik ri akʼ
#    Predicción (Modelo):
#
# 61)
#    Entrada (Ingles):   Let's do our job
#    Referencia (K'iche'):  Chqabʼana ri qachak
#    Predicción (Modelo):
#
# 62)
#    Entrada (Ingles):   This year I planted beans
#    Referencia (K'iche'):  Che we junabʼ xintik jawux
#    Predicción (Modelo):
#
# 63)
#    Entrada (Ingles):   All workers carry their tools
#    Referencia (K'iche'):  Konojel ri ajchakibʼ kikʼam bʼik kichakubʼal
#    Predicción (Modelo):
#
# 64)
#    Entrada (Ingles):   I gave the kids a huge swing
#    Referencia (K'iche'):  Xinbʼan jun nim kitzaybʼal ri akʼalabʼ
#    Predicción (Modelo):
#
# 65)
#    Entrada (Ingles):   Everyone applauded what she said
#    Referencia (K'iche'):  Xpaqʼpaqapaʼ kiqʼabʼ chech xubʼij ri ali
#    Predicción (Modelo):   ʼbʼalaj
#
# 66)
#    Entrada (Ingles):   I grow cotton seed on the milp
#    Referencia (K'iche'):  Xkiy le tux pa le abʼix
#    Predicción (Modelo):   ri milp
#
# 67)
#    Entrada (Ingles):   I need the shovel
#    Referencia (K'iche'):  Kinkoj ri jokbʼal ulew
#    Predicción (Modelo):
#
# 68)
#    Entrada (Ingles):   I'll be back here until the seventeenth day
#    Referencia (K'iche'):  Pa uwuqlajuj qʼij kintzalij loq waral
#    Predicción (Modelo):   kʼo kʼo kʼo jun
#
# 69)
#    Entrada (Ingles):   The lime splattered my palm
#    Referencia (K'iche'):  Ri chun xuya salkʼam pa ri nuqʼabʼ
#    Predicción (Modelo):
#
# 70)
#    Entrada (Ingles):   Not very common red pine
#    Referencia (K'iche'):  Man kʼi taj ri kaq chaj
#    Predicción (Modelo):
#
# 71)
#    Entrada (Ingles):   Will you come with us tomorrow?
#    Referencia (K'iche'):  ¿La katpe qukʼ chweʼq?
#    Predicción (Modelo):   ?
#
# 72)
#    Entrada (Ingles):   The leg swelling is already better
#    Referencia (K'iche'):  Ri sipojem kʼo chech ri raqan utz chik
#    Predicción (Modelo):
#
# 73)
#    Entrada (Ingles):   In the cave there is water
#    Referencia (K'iche'):  Chi upam ri pek kʼo jaʼ
#    Predicción (Modelo):
#
# 74)
#    Entrada (Ingles):   Tomás is from Canilla
#    Referencia (K'iche'):  Ri Max are aj qʼan iyaʼ
#    Predicción (Modelo):   kʼo kʼo kʼo
#
# 75)
#    Entrada (Ingles):   Write the refrain you know
#    Referencia (K'iche'):  chtzʼibʼaj janipa noʼjibʼal tzij awetaʼm
#    Predicción (Modelo):
#
# 76)
#    Entrada (Ingles):   What  The dancers dance
#    Referencia (K'iche'):  Kexojow ri ajxojolobʼ
#    Predicción (Modelo):   Kʼoʼn
#
# 77)
#    Entrada (Ingles):   The doctor lives on the edge of the Triangle
#    Referencia (K'iche'):  Ri ajkun kel chuchiʼ ri oxtzalaj
#    Predicción (Modelo):   kʼo kʼo
#
# 78)
#    Entrada (Ingles):   There's still a little bit in the pot
#    Referencia (K'iche'):  Kʼo juchʼin chi upam ri tʼuʼy
#    Predicción (Modelo):   ʼtzʼalaj
#
# 79)
#    Entrada (Ingles):   The turkey is eating the wheat
#    Referencia (K'iche'):  Ri tukumux tajin kutij ri triko
#    Predicción (Modelo):
#
# 80)
#    Entrada (Ingles):   The drawer is closed so it doesn't get into white sand
#    Referencia (K'iche'):  Tzʼapim uwiʼ ri kaxon rech man kok ta poqlaj chi upam
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo
#
# 81)
#    Entrada (Ingles):   Now they don't use bows or arrows anymore
#    Referencia (K'iche'):  Kamik man kkoj ta chik ri chʼabʼ
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo
#
# 82)
#    Entrada (Ingles):   Miguel left the board ready to sow
#    Referencia (K'iche'):  Xubʼan kanoq ri lochʼoj rech tikonijik ri a Kel
#    Predicción (Modelo):   kʼo kʼo
#
# 83)
#    Entrada (Ingles):   The horse tail is medicinal
#    Referencia (K'iche'):  Kunabʼal ri kʼibʼ
#    Predicción (Modelo):
#
# 84)
#    Entrada (Ingles):   My mom forgave me
#    Referencia (K'iche'):  Xusach numak ri nunan
#    Predicción (Modelo):
#
# 85)
#    Entrada (Ingles):   The kidnapper took my money
#    Referencia (K'iche'):  Ri majanel xumaj nurajil
#    Predicción (Modelo):
#
# 86)
#    Entrada (Ingles):   I'm the fourth brother of my mom's kids
#    Referencia (K'iche'):  In ukaj achalal chi kixoʼl ral ri nunan
#    Predicción (Modelo):
#
# 87)
#    Entrada (Ingles):   He wrote his resignation
#    Referencia (K'iche'):  Xutzʼibʼaj ri uwuj rech resabʼal ibʼ
#    Predicción (Modelo):
#
# 88)
#    Entrada (Ingles):   It's nice to stay at your house
#    Referencia (K'iche'):  Jeʼl kʼolem chi awachoch
#    Predicción (Modelo):   taqʼiʼl
#
# 89)
#    Entrada (Ingles):   You know the color is canary
#    Referencia (K'iche'):  Awilom jas rij ri tzʼikin ubʼiʼ chowix
#    Predicción (Modelo):   kʼo kʼo ri
#
# 90)
#    Entrada (Ingles):   He got tired of his ass sitting
#    Referencia (K'iche'):  Xqʼiʼtaj ri rachaq che ri tʼuyalem
#    Predicción (Modelo):
#
# 91)
#    Entrada (Ingles):   My back hurts because I'm crouching
#    Referencia (K'iche'):  Kʼax wij rumal in pachalik
#    Predicción (Modelo):   kʼo kʼo kʼo
#
# 92)
#    Entrada (Ingles):   I lay down to do my job
#    Referencia (K'iche'):  Kinchʼukiʼk chech ubʼanik nuchak
#    Predicción (Modelo):   chʼij
#
# 93)
#    Entrada (Ingles):   The basket weighs a lot
#    Referencia (K'iche'):  Al ri chakach
#    Predicción (Modelo):
#
# 94)
#    Entrada (Ingles):   The whistleblower recognized the thief
#    Referencia (K'iche'):  Ri tzujunel xuchʼobʼ uwach ri elaqʼom
#    Predicción (Modelo):
#
# 95)
#    Entrada (Ingles):   There's still a leftover
#    Referencia (K'iche'):  Xkanaj na kanoq ri chʼaqaʼp
#    Predicción (Modelo):
#
# 96)
#    Entrada (Ingles):   Dry fish is very salty
#    Referencia (K'iche'):  Ri chaqiʼj kar sibʼalaj ratzʼamil
#    Predicción (Modelo):
#
# 97)
#    Entrada (Ingles):   In the community of Panimaché lives Don Pedro Tz'alam
#    Referencia (K'iche'):  Luʼ Tzʼalam ubʼiʼ ri achi kel Pa nim Cheʼ
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo kʼo kʼo
#
# 98)
#    Entrada (Ingles):   About the petate on the brink of fire
#    Referencia (K'iche'):  Chaqibʼisaj ri sepalibʼal chi uchiʼ ri qʼaqʼ
#    Predicción (Modelo):   kʼo kʼo kʼo kʼo ri
#
# 99)
#    Entrada (Ingles):   When I travel to other places I have to pay for accommodation
#    Referencia (K'iche'):  Are chiʼ kinbʼek pa jun tinamit chik kintoj ri nuwarbʼal ja
#    Predicción (Modelo):   kʼo kʼo kʼo jun
#
# 100)
#    Entrada (Ingles):   Leave it like that, that's enough
#    Referencia (K'iche'):  Chyaʼ kan je laʼ, rukʼ laʼ
#    Predicción (Modelo):   ʼtzʼalaj, kʼo
#
#
# --- Calculando Métricas de Evaluación ---
#
# 📊 Puntuación BLEU:
#    BLEU: 0.00
#
# 📊 Puntuación ROUGE:
#    ROUGE-1: 2.90
#    ROUGE-2: 0.15
#    ROUGE-L: 2.94

# %% [markdown]
# ## Evaluación Comparativa de Experimentos

# %% [markdown]
# ### Métricas

# %%
rouge = evaluate.load("rouge")
bleu = evaluate.load("bleu")
meteor = evaluate.load("meteor")
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %% [markdown]
# ### Experimentos

# %% [markdown]
# #### 1. Zero-shot

# %% [markdown]
# ##### Prediciones

# %%
# --- 3. FUNCIÓN DE PREDICCIÓN MODIFICADA ---
def generate_predictions(model_to_test, tokenizer_to_use, dataset_to_test, n_examples=1000):
    predictions = []
    references = []

    model_to_test.eval()
    device = model_to_test.device

    # Configuramos el idioma de origen
    tokenizer_to_use.src_lang = SOURCE_LANG_CODE

    print(f"Iniciando predicciones de '{SOURCE_LANG_CODE}' a '{TARGET_LANG_CODE}' para {n_examples} ejemplos...")
    # Asegurémonos de que el dataset no sea más pequeño que n_examples
    num_samples = min(n_examples, len(dataset_to_test))

    for i in tqdm(range(num_samples)):
        item = dataset_to_test[i]
        input_text = item["input"]
        reference = item["target"]

        inputs = tokenizer_to_use(input_text, return_tensors="pt", truncation=True, max_length=128).to(device)

        with torch.no_grad():
            outputs = model_to_test.generate(
                **inputs,
                # Forzamos al decodificador a empezar con el ID que obtuvimos.
                # El modelo intentará "continuar" a partir de este token de inicio.
                forced_bos_token_id=forced_bos_id,
                max_length=128
            )

        # Decodificamos la salida. Es probable que aquí veamos texto en inglés,
        # español o simplemente texto sin sentido, porque el modelo no sabe qué hacer.
        pred = tokenizer_to_use.batch_decode(outputs, skip_special_tokens=True)[0]

        predictions.append(pred)
        references.append(reference)

    return predictions, references

# --- 4. EJECUCIÓN ---
# Asegúrate de que tu dataset 'cleaned_en_quc_dataset' esté cargado y disponible.
# Reemplaza esta línea si tu variable de dataset se llama diferente.
test_dataset_final = cleaned_en_quc_dataset["test"]

# Generamos las predicciones.
predictions, references = generate_predictions(
    model_to_test=zeroshot_model,
    tokenizer_to_use=zeroshot_tokenizer,
    dataset_to_test=test_dataset_final,
    n_examples=10 # Usamos un número pequeño para la prueba
)

# --- 5. IMPRESIÓN DE RESULTADOS ---
print("\n=== Ejemplos de Traducción 'Zero-Shot' ===\n")
for i in range(len(predictions)):
    print(f"Entrada (Inglés):  {test_dataset_final[i]['input']}")
    print(f"Referencia (K'iche'): {references[i]}")
    print(f"Predicción (Modelo):  {predictions[i]}\n")
# Out:
# Cargando modelo y tokenizador en el dispositivo: cuda
# ✅ Modelo Zero-Shot listo.
# --------------------------------------------------
# El ID que el tokenizador asignó a 'quc_Latn' es: 3
# Al decodificar el ID 3, obtenemos el token: '<unk>'
# Si no dice 'quc_Latn', significa que el tokenizador lo dividió y el modelo no lo entenderá como un idioma.
# --------------------------------------------------
# Iniciando predicciones de 'eng_Latn' a 'quc_Latn' para 10 ejemplos...
# 100%|██████████| 10/10 [00:06<00:00,  1.48it/s]
# === Ejemplos de Traducción 'Zero-Shot' ===
#
# Entrada (Inglés):  You have indigestion
# Referencia (K'iche'): Kqʼulqʼut ri apam
# Predicción (Modelo):  You have indigestion
#
# Entrada (Inglés):  The squirrel escaped
# Referencia (K'iche'): Xanimaj bʼik ri kuk
# Predicción (Modelo):  The squirrel escaped
#
# Entrada (Inglés):  What's up?  Your brother-in-law is swimming
# Referencia (K'iche'): Tajin kamuxan ri awecham
# Predicción (Modelo):  What's up?Your brother-in-law is swimming
#
# Entrada (Inglés):  On the coast I got malaria
# Referencia (K'iche'): Xinriq raxtew pa taqʼaj
# Predicción (Modelo):  ️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️️
#
# Entrada (Inglés):  I'm coming with him to make wood in the mountain
# Referencia (K'iche'): Xinpe rukʼ chech ubʼanik siʼ, pa ri juyubʼ
# Predicción (Modelo):  I'm coming with him to make wood in the mountain
#
# Entrada (Inglés):  The gentleman has itching feet
# Referencia (K'iche'): Kʼo kʼaqat chi raqan ri tataʼ
# Predicción (Modelo):  The gentleman has itching feet
#
# Entrada (Inglés):  You need to learn about the toilet
# Referencia (K'iche'): Rajwaxik kawetaʼmaj pa uwiʼ ri chʼajchʼojisanem
# Predicción (Modelo):  You need to learn about the toilet
#
# Entrada (Inglés):  The chilacayote is big
# Referencia (K'iche'): Nim ri qʼoqʼ
# Predicción (Modelo):  The chilacayote is big
#
# Entrada (Inglés):  Clear yourself up to the people
# Referencia (K'iche'): Chqʼalajisaj awibʼ chi kiwach ri tinamit
# Predicción (Modelo):  Proposiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii
#
# Entrada (Inglés):  You rush to your homework
# Referencia (K'iche'): Kakowij che ri apatan
# Predicción (Modelo):  You hurry to your homework

# %%
n_examples = 10

# %%
# Mostrar algunas predicciones
print("\n=== Ejemplos ===\n")
for i in range(n_examples):
    print(f"> Entrada:     {cleaned_en_quc_dataset['test'][i]['input']}")
    print(f"> Referencia:  {cleaned_en_quc_dataset['test'][i]['target']}")
    print(f"> Predicción:  {predictions[i]}\n")
# Out:
# === Ejemplos ===
#
# > Entrada:     You have indigestion
# > Referencia:  Kqʼulqʼut ri apam
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-19-2570146117.py in <cell line: 0>()
#       4     print(f"> Entrada:     {cleaned_en_quc_dataset['test'][i]['input']}")
#       5     print(f"> Referencia:  {cleaned_en_quc_dataset['test'][i]['target']}")
# ----> 6     print(f"> Predicción:  {predictions[i]}\n")
#
# NameError: name 'predictions' is not defined

# %%
with open(f"{DRIVE_PATH}/results_es_quc.tsv", "w", encoding="utf-8", newline="") as f:
    writer = csv.writer(f, delimiter="\t")
    writer.writerow(["input", "reference", "prediction"])

    for example, pred, ref in zip(es_quc_dataset["test"], predictions, references):
        writer.writerow([example["input"], ref, pred])

print("✅ Resultados guardados en 'results_es_quc.tsv'")

# %% [markdown]
# Como NLLB tiene el idioma K’iche’, se coloca este como idioma objetivo para las traducciones directas.

# %%
# --- PRUEBA DE SANIDAD ---
# Cambiamos temporalmente el idioma de destino a Italiano
TARGET_LANG_CODE_TEST = "ita_Latn"
SOURCE_LANG_CODE_TEST = "eng_Latn"

# Usamos tu mismo tokenizador y modelo
zeroshot_tokenizer.src_lang = SOURCE_LANG_CODE_TEST
forced_bos_id_test = zeroshot_tokenizer.convert_tokens_to_ids(TARGET_LANG_CODE_TEST)

print(f"ID del token de destino (Italiano): {forced_bos_id_test}") # Debería imprimir un número ej: 256116

# Tomemos una sola frase para la prueba
input_text_test = "The squirrel escaped"
inputs_test = zeroshot_tokenizer(input_text_test, return_tensors="pt").to(device)

print("\nRealizando prueba de sanidad (Inglés -> Italiano)...")
with torch.no_grad():
    outputs_test = zeroshot_model.generate(
        **inputs_test,
        forced_bos_token_id=forced_bos_id_test,
        max_length=128
    )

prediction_test = zeroshot_tokenizer.batch_decode(outputs_test, skip_special_tokens=True)[0]

print(f"\nEntrada: '{input_text_test}'")
print(f"Predicción en Italiano: '{prediction_test}'") # <-- ¿Qué imprime aquí?


from transformers import AutoTokenizer

# Cargamos el tokenizador oficial de NLLB
model_name = "facebook/nllb-200-distilled-600M"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# --- Verifiquemos los idiomas ---

kiche_code = "quc_Latn"
sipakapense_code = "qum_Latn"

print(f"Buscando el ID para K'iche' ({kiche_code})...")
try:
    kiche_id = tokenizer.convert_tokens_to_ids(kiche_code)
    print(f"✅ ÉXITO: El ID para '{kiche_code}' es: {kiche_id}. ¡SÍ EXISTE!")
except Exception as e:
    print(f"❌ FALLO: No se pudo encontrar un ID para '{kiche_code}'. ¡NO EXISTE!")

print("-" * 20)

print(f"Buscando el ID para Sipakapense ({sipakapense_code})...")
try:
    # El tokenizador arroja un error si no encuentra el token.
    # Usamos .get para manejarlo sin que el programa se caiga.
    sipakapense_id = tokenizer.vocab.get(sipakapense_code)
    if sipakapense_id is not None:
         print(f"✅ ÉXITO: El ID para '{sipakapense_code}' es: {sipakapense_id}. ¡SÍ EXISTE!")
    else:
         print(f"❌ FALLO: No se encontró un ID para '{sipakapense_code}'. ¡NO EXISTE!")
except Exception as e:
    print(f"❌ FALLO: Ocurrió un error buscando '{sipakapense_code}'.")


# --- PRUEBA DE SANIDAD ---
# Cambiamos temporalmente el idioma de destino a Kiche
TARGET_LANG_CODE_TEST = "quc_Latn"
SOURCE_LANG_CODE_TEST = "spa_Latn"

# Usamos tu mismo tokenizador y modelo
zeroshot_tokenizer.src_lang = SOURCE_LANG_CODE_TEST
forced_bos_id_test = zeroshot_tokenizer.convert_tokens_to_ids(TARGET_LANG_CODE_TEST)

print(f"ID del token de destino (Kiche): {forced_bos_id_test}") # Debería imprimir un número ej: 256116

# Tomemos una sola frase para la prueba
input_text_test = "La ardilla escapó el otro dia"
inputs_test = zeroshot_tokenizer(input_text_test, return_tensors="pt").to(device)

print("\nRealizando prueba de sanidad (Español -> Kiche)...")
with torch.no_grad():
    outputs_test = zeroshot_model.generate(
        **inputs_test,
        forced_bos_token_id=forced_bos_id_test,
        max_length=128
    )

prediction_test = zeroshot_tokenizer.batch_decode(outputs_test, skip_special_tokens=True)[0]

print(f"\nEntrada: '{input_text_test}'")
print(f"Predicción en Kiche: '{prediction_test}'") # <-- ¿Qué imprime aquí?
# Out:
# ID del token de destino (Italiano): 256077
#
# Realizando prueba de sanidad (Inglés -> Italiano)...
#
# Entrada: 'The squirrel escaped'
# Predicción en Italiano: 'L' scoiattolo è scappato .'
# Buscando el ID para K'iche' (quc_Latn)...
# ✅ ÉXITO: El ID para 'quc_Latn' es: 3. ¡SÍ EXISTE!
# --------------------
# Buscando el ID para Sipakapense (qum_Latn)...
# ❌ FALLO: No se encontró un ID para 'qum_Latn'. ¡NO EXISTE!
# ID del token de destino (Kiche): 3
#
# Realizando prueba de sanidad (Español -> Kiche)...
#
# Entrada: 'La ardilla escapó el otro dia'
# Predicción en Kiche: 'The squirrel escaped the other day'

# %%
bleu_score = bleu.compute(predictions=predictions, references=[[ref] for ref in references])

print("\n=== Métricas BLEU ===")
print(f"BLEU-1: {bleu_score['precisions'][0]*100:.2f}")
print(f"BLEU-2: {bleu_score['precisions'][1]*100:.2f}")
print(f"BLEU-3: {bleu_score['precisions'][2]*100:.2f}")
print(f"BLEU-4: {bleu_score['precisions'][3]*100:.2f}")
print(f"BLEU total: {bleu_score['bleu']*100:.2f}")

rouge_score = rouge.compute(predictions=predictions, references=references)

print("\n=== Métricas ROUGE ===")
print(f"ROUGE-1:   {rouge_score['rouge1']*100:.2f}")
print(f"ROUGE-2:   {rouge_score['rouge2']*100:.2f}")
print(f"ROUGE-L:   {rouge_score['rougeL']*100:.2f}")
print(f"ROUGE-Lsum:{rouge_score['rougeLsum']*100:.2f}")

# %% [markdown]
# #### 2. Finetuning ES-QUC y Pipeline

# %%
predictions_intermediate = []
references_intermediate = []

print("\n🔹 Traduciendo: inglés → español → K’iche’ (vía intermediaria)\n")

for item in tqdm(es_quc_dataset["test"]):
    input_text = item["input"]
    reference = item["target"]

    # Paso 1: inglés → español (modelo base)
    inter = translate_text(zeroshot_model, zeroshot_tokenizer, input_text, "eng_Latn", "spa_Latn")

    # Paso 2: español → K’iche’ (modelo fine-tuneado)
    pred = translate_text(finetune_model, finetune_tokenizer, inter, "spa_Latn", "quc_Latn")

    predictions_intermediate.append(pred)
    references_intermediate.append(reference)
# Out:
# 🔹 Traduciendo: inglés → español → K’iche’ (vía intermediaria)
#   0%|          | 0/1000 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-69-1988446924.py in <cell line: 0>()
#      12
#      13     # Paso 2: español → K’iche’ (modelo fine-tuneado)
# ---> 14     pred = translate_text(finetune_model, finetune_tokenizer, inter, "spa_Latn", "quc_Latn")
#      15
#      16     predictions_intermediate.append(pred)
#
# NameError: name 'finetune_model' is not defined

# %%
print("\n=== Ejemplos Fine-Tuned ===\n")
for i in range(5):
    print(f"> Entrada:     {es_quc_dataset['test'][i]['input']}")
    print(f"> Referencia:  {es_quc_dataset['test'][i]['target']}")
    print(f"> Predicción:  {predictions_intermediate[i]}\n")

# %%
bleu_score_ft = bleu.compute(predictions=predictions_intermediate, references=[[r] for r in references_intermediate])
rouge_score_ft = rouge.compute(predictions=predictions_intermediate, references=references_intermediate)

print("\n=== Métricas Fine-Tuned ===")
print(f"BLEU: {bleu_score_ft['bleu']:.2f}")
print(f"ROUGE-L: {rouge_score_ft['rougeL']:.2f}")

# %%
# prompt: Save the relevant results, predictions, etc

# Assuming predictions_intermediate and references_intermediate are already computed from the previous cell

output_filename_ft = f"{DRIVE_PATH}/results_finetuned_es_quc_pipeline.tsv"

with open(output_filename_ft, "w", encoding="utf-8", newline="") as f:
    writer = csv.writer(f, delimiter="\t")
    # Write header
    writer.writerow(["input_english", "intermediate_spanish", "reference_kiche", "prediction_kiche"])

    # Write data
    # Need to regenerate the intermediate Spanish translations to save them
    # or store them during the generation process
    intermediate_translations = []
    print("\n🔄 Regenerating intermediate Spanish translations for saving...")
    for item in tqdm(es_quc_dataset["test"]):
         input_text = item["input"]
         inter = translate_text(zeroshot_model, zeroshot_tokenizer, input_text, "eng_Latn", "spa_Latn")
         intermediate_translations.append(inter)


    for i in range(len(es_quc_dataset["test"])):
         writer.writerow([
              es_quc_dataset["test"][i]["input"], # Original English input from dataset
              intermediate_translations[i], # Intermediate Spanish translation
              references_intermediate[i], # Original K'iche' reference from dataset
              predictions_intermediate[i] # Final K'iche' prediction from the fine-tuned model
         ])

print(f"✅ Resultados del pipeline (inglés -> español -> K'iche') guardados en '{output_filename_ft}'")

# %% [markdown]
# #### 3. Finetuning ES-QUC y Traducción Directa

# %%
predictions_direct = []
references_direct = []

print("\n🔹 Traduciendo: inglés → K’iche’ (directo)\n")

for item in tqdm(es_quc_dataset["test"]):
    input_text = item["input"]
    reference = item["target"]
    pred = translate_text(finetune_model, finetune_tokenizer, input_text, "eng_Latn", "quc_Latn")

    predictions_direct.append(pred)
    references_direct.append(reference)

# %%
print("\n=== Ejemplos Fine-Tuned ===\n")
for i in range(5):
    print(f"> Entrada:     {es_quc_dataset['test'][i]['input']}")
    print(f"> Referencia:  {es_quc_dataset['test'][i]['target']}")
    print(f"> Predicción:  {predictions_direct[i]}\n")

# %%
bleu_score_ft = bleu.compute(predictions=predictions_direct, references=[[r] for r in references_direct])
rouge_score_ft = rouge.compute(predictions=predictions_direct, references=references_direct)

print("\n=== Métricas Fine-Tuned ===")
print(f"BLEU: {bleu_score_ft['bleu']:.2f}")
print(f"ROUGE-L: {rouge_score_ft['rougeL']:.2f}")

# %%
# prompt: Save the relevant results

# Assuming predictions_direct and references_direct are already computed from the previous cell

output_filename_direct = f"{DRIVE_PATH}/results_finetuned_es_quc_direct.tsv"

with open(output_filename_direct, "w", encoding="utf-8", newline="") as f:
    writer = csv.writer(f, delimiter="\t")
    # Write header
    writer.writerow(["input_english", "reference_kiche", "prediction_kiche"])

    # Write data
    for i in range(len(es_quc_dataset["test"])):
         writer.writerow([
              es_quc_dataset["test"][i]["input"], # Original English input from dataset
              references_direct[i], # Original K'iche' reference from dataset
              predictions_direct[i] # Final K'iche' prediction from the fine-tuned model
         ])

print(f"✅ Resultados de traducción directa (inglés -> K'iche') guardados en '{output_filename_direct}'")

# %% [markdown]
# #### 4. Finetuning EN-QUC

# %%
predictions_en_qum = []
references_en_qum = []

print("\n🔹 Traduciendo: inglés → K’iche’ (dataset sintético directo)\n")

for item in tqdm(en_qum_dataset["test"]):
    input_text = item["input"]
    reference = item["target"]
    pred = translate_text(en_qum_model, en_qum_tokenizer, input_text, "eng_Latn", "quc_Latn")

    predictions_en_qum.append(pred)
    references_en_qum.append(reference)

# %%
print("\n=== Ejemplos Fine-Tuned ===\n")
for i in range(5):
    print(f"> Entrada:     {en_qum_dataset['test'][i]['input']}")
    print(f"> Referencia:  {en_qum_dataset['test'][i]['target']}")
    print(f"> Predicción:  {predictions_en_qum[i]}\n")

# %%
bleu_score = bleu.compute(predictions=predictions_en_qum, references=[[ref] for ref in references_en_qum])

print("\n=== Métricas BLEU ===")
print(f"BLEU-1: {bleu_score['precisions'][0]*100:.2f}")
print(f"BLEU-2: {bleu_score['precisions'][1]*100:.2f}")
print(f"BLEU-3: {bleu_score['precisions'][2]*100:.2f}")
print(f"BLEU-4: {bleu_score['precisions'][3]*100:.2f}")
print(f"BLEU total: {bleu_score['bleu']*100:.2f}")

rouge_score = rouge.compute(predictions=predictions_en_qum, references=references_en_qum)

print("\n=== Métricas ROUGE ===")
print(f"ROUGE-1:   {rouge_score['rouge1']*100:.2f}")
print(f"ROUGE-2:   {rouge_score['rouge2']*100:.2f}")
print(f"ROUGE-L:   {rouge_score['rougeL']*100:.2f}")
print(f"ROUGE-Lsum:{rouge_score['rougeLsum']*100:.2f}")

# meteor_score = meteor.compute(predictions=predictions_en_qum, references=references_en_qum)

# print("\n=== Otras Métricas ===")
# print(f"METEOR:     {meteor_score['meteor']*100:.2f}")

# %%
filename = "results_en_qum_directo.tsv"
with open(filename, "w", encoding="utf-8", newline="") as f:
    writer = csv.writer(f, delimiter="\t")
    writer.writerow(["input", "reference", "prediction"])

    for example, pred, ref in zip(es_qum_dataset["test"], predictions_en_qum, references_en_qum):
        writer.writerow([example["input"], ref, pred])

print(f"✅ Resultados guardados en '{filename}'")

# %%
def swap_input_target(example):
    """Swaps the 'input' and 'target' columns in a dataset example."""
    return {"input": example["target"], "target": example["input"]}

# Apply the function to the entire dataset
swapped_es_quc_dataset = es_quc_dataset.map(swap_input_target)

print("✅ Columnas 'input' y 'target' invertidas.")
print("\n--- Verificando el dataset invertido ---")
print(swapped_es_quc_dataset)

# Opcional: Puedes asignar el dataset invertido a la variable original si deseas
# es_quc_dataset = swapped_es_quc_dataset
# Out:
# Map:   0%|          | 0/624 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# ✅ Columnas 'input' y 'target' invertidas.
#
# --- Verificando el dataset invertido ---
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'target'],
#         num_rows: 624
#     })
#     test: Dataset({
#         features: ['input', 'target'],
#         num_rows: 1000
#     })
# })
